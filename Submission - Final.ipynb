# %% [markdown]
# <div class="alert alert-success">
# <h1> AUTOMATIC TICKET CLASSIFICATION - CASE STUDY</h1>
#
# <h2>Submitted by: Praveersinh Parmar & Ketaki Samanta</h2>
# </div>

# %% [markdown]
# ## Problem Statement
#
# You need to build a model that is able to classify customer complaints based on the products/services. By doing so, you can segregate these tickets into their relevant categories and, therefore, help in the quick resolution of the issue.
#
# You will be doing topic modelling on the <b>.json</b> data provided by the company. Since this data is not labelled, you need to apply NMF to analyse patterns and classify tickets into the following five clusters based on their products/services:
#
# * Credit card / Prepaid card
#
# * Bank account services
#
# * Theft/Dispute reporting
#
# * Mortgages/loans
#
# * Others
#
#
# With the help of topic modelling, you will be able to map each ticket onto its respective department/category. You can then use this data to train any supervised model such as logistic regression, decision tree or random forest. Using this trained model, you can classify any new customer complaint support ticket into its relevant department.

# %% [markdown]
# # 📝 Tasks to be performed:
#
# 1. **Data loading and understanding**
#
#
# 2. **Data Cleaning**
#
#
# 3. **Data preprocessing**
#
#
# 4. **Data Visualization (EDA)**
#
#
# 5. **Feature extraction**
#
#
# 6. **Topic modelling**
#
#
# 7. **Model building**
#
#
# 8. **Model inference**

# %% [markdown]
# # 📚 Importing the necessary libraries

# %%
# Libraries for data loading and manipulation
import pandas as pd
import numpy as np
import json
import pickle


# Libraries for data visualization and EDA
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS


# Libraries for text preprocessing
import re, nltk, spacy, string
nlp = spacy.load("en_core_web_sm")
# from subprocess import check_output
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.decomposition import NMF
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize


# Libraries for machine learning models
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier


# Libraries for evaluating models
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, f1_score, classification_report

# %%
# Suppress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
## Set limits for displaying rows and columns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # `Task 1`: Data Loading 🚚 and Understanding 💡
#
# ### 💠 The data is in JSON format, so first we convert it to a dataframe.

# %%
# Opening JSON file 
f = open('complaints-2021-05-14_08_16.json',)
  
# Returns JSON object as a dictionary 
data = json.load(f)

# Create a dataframe out of dictionary 
df = pd.json_normalize(data)

# %%
# Inspect the dataframe to understand the given data
df.head()
# Out:
#                 _index      _type      _id  _score   _source.tags  \
# 0  complaint-public-v2  complaint  3211475     0.0           None
# 1  complaint-public-v2  complaint  3229299     0.0  Servicemember
# 2  complaint-public-v2  complaint  3199379     0.0           None
# 3  complaint-public-v2  complaint  2673060     0.0           None
# 4  complaint-public-v2  complaint  3203545     0.0           None
#
#   _source.zip_code _source.complaint_id                       _source.issue  \
# 0            90301              3211475   Attempts to collect debt not owed
# 1            319XX              3229299     Written notification about debt
# 2            77069              3199379  Other features, terms, or problems
# 3            48066              2673060      Trouble during payment process
# 4            10473              3203545                    Fees or interest
#
#        _source.date_received _source.state _source.consumer_disputed  \
# 0  2019-04-13T12:00:00-05:00            CA                       N/A
# 1  2019-05-01T12:00:00-05:00            GA                       N/A
# 2  2019-04-02T12:00:00-05:00            TX                       N/A
# 3  2017-09-13T12:00:00-05:00            MI                       N/A
# 4  2019-04-05T12:00:00-05:00            NY                       N/A
#
#                _source.product _source.company_response       _source.company  \
# 0              Debt collection  Closed with explanation  JPMORGAN CHASE & CO.
# 1              Debt collection  Closed with explanation  JPMORGAN CHASE & CO.
# 2  Credit card or prepaid card  Closed with explanation  JPMORGAN CHASE & CO.
# 3                     Mortgage  Closed with explanation  JPMORGAN CHASE & CO.
# 4  Credit card or prepaid card  Closed with explanation  JPMORGAN CHASE & CO.
#
#   _source.submitted_via _source.date_sent_to_company  \
# 0                   Web    2019-04-13T12:00:00-05:00
# 1                   Web    2019-05-01T12:00:00-05:00
# 2                   Web    2019-04-02T12:00:00-05:00
# 3                   Web    2017-09-14T12:00:00-05:00
# 4              Referral    2019-04-05T12:00:00-05:00
#
#   _source.company_public_response                         _source.sub_product  \
# 0                            None                            Credit card debt
# 1                            None                            Credit card debt
# 2                            None  General-purpose credit card or charge card
# 3                            None                  Conventional home mortgage
# 4                            None  General-purpose credit card or charge card
#
#   _source.timely  \
# 0            Yes
# 1            Yes
# 2            Yes
# 3            Yes
# 4            Yes
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                               _source.complaint_what_happened  \
# 0
# 1  Good morning my name is XXXX XXXX and I appreciate it if you could help me put a stop to Chase Bank cardmember services. \nIn 2018 I wrote to Chase asking for debt verification and what they sent me a statement which is not acceptable. I am asking the bank to validate the debt. Instead I been receiving mail every month from them attempting to collect a debt. \nI have a right to know this information as a consumer. \n\nChase account # XXXX XXXX XXXX XXXX Thanks in advance for your help.
# 2                                                                                                                                         I upgraded my XXXX XXXX card in XX/XX/2018 and was told by the agent who did the upgrade my anniversary date would not change. It turned the agent was giving me the wrong information in order to upgrade the account. XXXX   changed my anniversary date from XX/XX/XXXX to XX/XX/XXXX without my consent! XXXX has the recording of the agent who was misled me.
# 3
# 4
#
#                                   _source.sub_issue  \
# 0                                 Debt is not yours
# 1  Didn't receive enough information to verify debt
# 2             Problem with rewards from credit card
# 3                                              None
# 4                         Charged too much interest
#
#   _source.consumer_consent_provided
# 0              Consent not provided
# 1                  Consent provided
# 2                  Consent provided
# 3              Consent not provided
# 4                               N/A

# %%
# View the dimensions of dataframe
df.shape
# Out:
# (78313, 22)

# %% [markdown]
# ### 📌 The dataset has 78,313 customer complaints and 22 features.
# ### 📌 The customer complaint is in "`_source.complaint_what_happened`" column

# %%
# Print the column names
list(df.columns)
# Out:
# ['_index',
#  '_type',
#  '_id',
#  '_score',
#  '_source.tags',
#  '_source.zip_code',
#  '_source.complaint_id',
#  '_source.issue',
#  '_source.date_received',
#  '_source.state',
#  '_source.consumer_disputed',
#  '_source.product',
#  '_source.company_response',
#  '_source.company',
#  '_source.submitted_via',
#  '_source.date_sent_to_company',
#  '_source.company_public_response',
#  '_source.sub_product',
#  '_source.timely',
#  '_source.complaint_what_happened',
#  '_source.sub_issue',
#  '_source.consumer_consent_provided']

# %% [markdown]
# ### 📌 We will have to rename the column names since they have changed due to normalization of JSON.

# %%
# View the info of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78313 entries, 0 to 78312
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _index                             78313 non-null  object
#  1   _type                              78313 non-null  object
#  2   _id                                78313 non-null  object
#  3   _score                             78313 non-null  float64
#  4   _source.tags                       10900 non-null  object
#  5   _source.zip_code                   71556 non-null  object
#  6   _source.complaint_id               78313 non-null  object
#  7   _source.issue                      78313 non-null  object
#  8   _source.date_received              78313 non-null  object
#  9   _source.state                      76322 non-null  object
#  10  _source.consumer_disputed          78313 non-null  object
#  11  _source.product                    78313 non-null  object
#  12  _source.company_response           78313 non-null  object
#  13  _source.company                    78313 non-null  object
#  14  _source.submitted_via              78313 non-null  object
#  15  _source.date_sent_to_company       78313 non-null  object
#  16  _source.company_public_response    4 non-null      object
#  17  _source.sub_product                67742 non-null  object
#  18  _source.timely                     78313 non-null  object
#  19  _source.complaint_what_happened    78313 non-null  object
#  20  _source.sub_issue                  32016 non-null  object
#  21  _source.consumer_consent_provided  77305 non-null  object
# dtypes: float64(1), object(21)
# memory usage: 13.1+ MB

# %% [markdown]
# ### 📌 There are many columns with missing values.
# ### 📌 There is only one numerical column: `score`.

# %%
# View statistical info of the numerical column
df.describe()
# Out:
#         _score
# count  78313.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %% [markdown]
# ### 📌 The `score` column has all values as 0.0

# %%
# Inspect the number of missing values
df.isna().sum(0)
# Out:
# _index                                   0
# _type                                    0
# _id                                      0
# _score                                   0
# _source.tags                         67413
# _source.zip_code                      6757
# _source.complaint_id                     0
# _source.issue                            0
# _source.date_received                    0
# _source.state                         1991
# _source.consumer_disputed                0
# _source.product                          0
# _source.company_response                 0
# _source.company                          0
# _source.submitted_via                    0
# _source.date_sent_to_company             0
# _source.company_public_response      78309
# _source.sub_product                  10571
# _source.timely                           0
# _source.complaint_what_happened          0
# _source.sub_issue                    46297
# _source.consumer_consent_provided     1008
# dtype: int64

# %% [markdown]
# ### 📌 There are a lot of missing values. However, they are in columns that will not be required in model building, so we leave them untreated.

# %% [markdown]
# # `Task 2`: Data Cleaning 🧹

# %% [markdown]
# ### 💠 First, we rename the column headers

# %%
# Remove the leading underscores from all column names
df.columns = [re.sub('^_', '', col) for col in df.columns]
list(df.columns)
# Out:
# ['index',
#  'type',
#  'id',
#  'score',
#  'source.tags',
#  'source.zip_code',
#  'source.complaint_id',
#  'source.issue',
#  'source.date_received',
#  'source.state',
#  'source.consumer_disputed',
#  'source.product',
#  'source.company_response',
#  'source.company',
#  'source.submitted_via',
#  'source.date_sent_to_company',
#  'source.company_public_response',
#  'source.sub_product',
#  'source.timely',
#  'source.complaint_what_happened',
#  'source.sub_issue',
#  'source.consumer_consent_provided']

# %%
## Remove 'source' from column names beginning with 'source.'
df.columns = [re.sub(r"^\bsource\b\.", "", col) for col in df.columns]
list(df.columns)
# Out:
# ['index',
#  'type',
#  'id',
#  'score',
#  'tags',
#  'zip_code',
#  'complaint_id',
#  'issue',
#  'date_received',
#  'state',
#  'consumer_disputed',
#  'product',
#  'company_response',
#  'company',
#  'submitted_via',
#  'date_sent_to_company',
#  'company_public_response',
#  'sub_product',
#  'timely',
#  'complaint_what_happened',
#  'sub_issue',
#  'consumer_consent_provided']

# %%
# View dataframe with corrected column names
df.head()
# Out:
#                  index       type       id  score           tags zip_code  \
# 0  complaint-public-v2  complaint  3211475    0.0           None    90301
# 1  complaint-public-v2  complaint  3229299    0.0  Servicemember    319XX
# 2  complaint-public-v2  complaint  3199379    0.0           None    77069
# 3  complaint-public-v2  complaint  2673060    0.0           None    48066
# 4  complaint-public-v2  complaint  3203545    0.0           None    10473
#
#   complaint_id                               issue              date_received  \
# 0      3211475   Attempts to collect debt not owed  2019-04-13T12:00:00-05:00
# 1      3229299     Written notification about debt  2019-05-01T12:00:00-05:00
# 2      3199379  Other features, terms, or problems  2019-04-02T12:00:00-05:00
# 3      2673060      Trouble during payment process  2017-09-13T12:00:00-05:00
# 4      3203545                    Fees or interest  2019-04-05T12:00:00-05:00
#
#   state consumer_disputed                      product  \
# 0    CA               N/A              Debt collection
# 1    GA               N/A              Debt collection
# 2    TX               N/A  Credit card or prepaid card
# 3    MI               N/A                     Mortgage
# 4    NY               N/A  Credit card or prepaid card
#
#           company_response               company submitted_via  \
# 0  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 1  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 2  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 3  Closed with explanation  JPMORGAN CHASE & CO.           Web
# 4  Closed with explanation  JPMORGAN CHASE & CO.      Referral
#
#         date_sent_to_company company_public_response  \
# 0  2019-04-13T12:00:00-05:00                    None
# 1  2019-05-01T12:00:00-05:00                    None
# 2  2019-04-02T12:00:00-05:00                    None
# 3  2017-09-14T12:00:00-05:00                    None
# 4  2019-04-05T12:00:00-05:00                    None
#
#                                   sub_product timely  \
# 0                            Credit card debt    Yes
# 1                            Credit card debt    Yes
# 2  General-purpose credit card or charge card    Yes
# 3                  Conventional home mortgage    Yes
# 4  General-purpose credit card or charge card    Yes
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 0
# 1  Good morning my name is XXXX XXXX and I appreciate it if you could help me put a stop to Chase Bank cardmember services. \nIn 2018 I wrote to Chase asking for debt verification and what they sent me a statement which is not acceptable. I am asking the bank to validate the debt. Instead I been receiving mail every month from them attempting to collect a debt. \nI have a right to know this information as a consumer. \n\nChase account # XXXX XXXX XXXX XXXX Thanks in advance for your help.
# 2                                                                                                                                         I upgraded my XXXX XXXX card in XX/XX/2018 and was told by the agent who did the upgrade my anniversary date would not change. It turned the agent was giving me the wrong information in order to upgrade the account. XXXX   changed my anniversary date from XX/XX/XXXX to XX/XX/XXXX without my consent! XXXX has the recording of the agent who was misled me.
# 3
# 4
#
#                                           sub_issue consumer_consent_provided
# 0                                 Debt is not yours      Consent not provided
# 1  Didn't receive enough information to verify debt          Consent provided
# 2             Problem with rewards from credit card          Consent provided
# 3                                              None      Consent not provided
# 4                         Charged too much interest                       N/A

# %% [markdown]
# ### 💠 Next, we remove the complaint rows that are blank

# %%
# Counting number of rows with blank under complaints column 
len(df[df['complaint_what_happened'] == ""])
# Out:
# 57241

# %% [markdown]
# ### 📌 57,241 rows in the data have blanks under complaints column.
# ### 💠 To remove the rows containing blanks, we first replace them by NaNs and then remove missing values.

# %%
# Assign nan in place of blanks in the complaints column
df['complaint_what_happened'].replace("", np.nan, inplace=True)

#Remove all rows where complaints column is nan
df.dropna(subset=['complaint_what_happened'], inplace=True)

# Again counting number of rows with blank under complaints column 
len(df[df['complaint_what_happened'] == ""])
# Out:
# 0

# %%
## View the shape of modified dataframe
df.shape
# Out:
# (21072, 22)

# %% [markdown]
# ### 📌 We have removed 78,313 - 21,072  =  57,241 rows that contained blank under complaints column

# %% [markdown]
# # `Task 3`: Data Preprocessing 🛠️

# %% [markdown]
# ### 💠 Now, we prepare the text for topic modeling
#
# ### 💠 Here, we do the following preprocessing on the text of complaints:
#
# - Make the text lowercase
# - Remove text in square brackets
# - Remove punctuation
# - Remove words containing numbers

# %%
## View first five rows of complaint column
df['complaint_what_happened'].head()
# Out:
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Good morning my name is XXXX XXXX and I appreciate it if you could help me put a stop to Chase Bank cardmember services. \nIn 2018 I wrote to Chase asking for debt verification and what they sent me a statement which is not acceptable. I am asking the bank to validate the debt. Instead I been receiving mail every month from them attempting to collect a debt. \nI have a right to know this information as a consumer. \n\nChase account # XXXX XXXX XXXX XXXX Thanks in advance for your help.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                I upgraded my XXXX XXXX card in XX/XX/2018 and was told by the agent who did the upgrade my anniversary date would not change. It turned the agent was giving me the wrong information in order to upgrade the account. XXXX   changed my anniversary date from XX/XX/XXXX to XX/XX/XXXX without my consent! XXXX has the recording of the agent who was misled me.
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Chase Card was reported on XX/XX/2019. However, fraudulent application have been submitted my identity without my consent to fraudulently obtain services. Do not extend credit without verifying the identity of the applicant.
# 11    On XX/XX/2018, while trying to book a XXXX  XXXX  ticket, I came across an offer for {$300.00} to be applied towards the ticket if I applied for a rewards card. I put in my information for the offer and within less than a minute, was notified via the screen that a decision could not be made. I immediately contacted XXXX and was referred to Chase Bank. I then immediately contacted Chase bank within no more than 10minutes of getting the notification on the screen and I was told by the Chase representative I spoke with that my application was denied but she could not state why. I asked for more information about the XXXX  offer and she explained that even if I had been approved, the credit offer only gets applied after the first account statement and could not be used to purchase the ticket. I then explicitly told her I was glad I got denied and I was ABSOLUTELY no longer interested in the account. I asked that the application be withdrawn and the representative obliged. This all happened no later than 10mins after putting in the application on XX/XX/2018. Notwithstanding my explicit request not to proceed with the application and contrary to what I was told by the Chase representative, Chase did in fact go ahead to open a credit account in my name on XX/XX/2018. This is now being reported in my Credit Report and Chase has refused to correct this information on my credit report even though they went ahead to process an application which I did not consent to and out of their error.
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     my grand son give me check for {$1600.00} i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase 2 times they told him i should call not him to verify the check owner he is out the country most the time  date happen XX/XX/2018 check number XXXX claim number is XXXX with chase
# Name: complaint_what_happened, dtype: object

# %%
# Function here to clean the text and remove all the unnecessary elements.
def clean_text(text):
    '''This function 
        - makes the given text lowercase
        - removes text in square brackets
        - removes punctuation and 
        - removes words containing numbers.
    :param text: text to be cleaned
    :return: cleaned text
    '''
    
    # Make the text lowercase
    text = text.lower()
    
    # Remove text in square brackets
    text = re.sub(r'\[.*?\]', '', text)
    
    # Remove punctuation
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    
    # Remove words containing numbers
    text = re.sub(r'\w*\d\w*', '', text)
    
    return text

# %%
# Apply the above function to complaint column and make a new dataframe containing text-cleaned complaints
df_clean = pd.DataFrame(df['complaint_what_happened'].apply(lambda x: clean_text(x)))

# View first five rows of text-cleaned dataframe
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase

# %% [markdown]
# ### 💠 After performing cleaning operations, we do the following:
#
# - Lemmatize the texts
# - Use POS tags to get relevant words from the texts.

# %%
#Write your function to Lemmatize the texts
def lemmatizer(text):     
    """
    This function lemmatizes the given input text.
    :param text: given text
    :return: lemmatized text
    """
    
    # Initialize empty list to store lemmas
    sent = []
    
    # Extract lemmas of given text and add to the list 'sent'
    doc = nlp(text)
    for word in doc:
        sent.append(word.lemma_)
        
    # return string converted form of the list of lemmas
    return " ".join(sent)

# %%
# Add a column for lemmatized complaints to the dataframe
df_clean["lemmatized_complaint"] =  df_clean.apply(lambda x: lemmatizer(x['complaint_what_happened']), axis=1)

# View the dataframe
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase

# %% [markdown]
# ### 📌 Note that spaCy gives `-PRON-` as the pos tag of any personal pronoun.
#
# <br>
#
#
# ### 💠 Now, we will use `Chunking` to extract singular nouns from the lemmatized complaints
# ### 💠 We extract only nouns because we are interested in finding `topics`, which are mostly nouns.

# %%
# Extract singular nouns
def get_singular_nouns(text):
    """
    This function extracts the singular nouns from given text
    :param: input text
    :return: extracted nouns from the input text
    """
    
    # Create a textblob object
    blob = TextBlob(text)
    
    # extract words with tags 'NN', join them and return
    return ' '.join([ word for (word,tag) in blob.tags if tag == "NN"])

# Apply the function to create a new column containing only singular nouns 
# We don't have plural nouns as the text is already lemmatized
df_clean["complaint_POS_removed"] =  df_clean.apply(lambda x: get_singular_nouns(x['lemmatized_complaint']), axis=1)

# View the dataframe
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                              complaint_POS_removed
# 1                                                                                                                                                                                                                                                                 morning -PRON- name -PRON- stop bank cardmember service ask debt verification statement i bank debt mail month attempt debt i right information consumer chase account thank advance -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                           i card agent upgrade date agent information order account change date xxxxxxxx consent recording agent
# 10                                                                                                                                                                                                                                                                                                                                                                                      card report application identity consent service credit identity applicant
# 11  try book xxxx ticket i offer ticket card i information offer minute screen decision xxxx bank i chase bank notification screen i chase representative i application state i ask information xxxx offer -PRON- credit offer account statement use ticket i account i application representative oblige put application explicit request application chase chase fact credit account name report credit report chase information credit report application error
# 14                                                                                                                                                                                                                                                                son check deposit -PRON- chase account fund chase bank account money son check money chase bank refuse money son call chase time i check owner country time date check number claim number chase

# %% [markdown]
# # `Task 4`: Data Visualization (EDA) 📊

# %% [markdown]
# ### 💠 Here, we do the following steps of Exploratory Data Analysis (EDA) to get familiar with the data.
#
# -   Visualise the data according to the 'Complaint' character length
# -   Using a word cloud find the top 40 words by frequency among all the articles after processing the text
# -   Find the top unigrams, bigrams and trigrams by frequency among all the complaints after processing the text.

# %%
# Create list of lengths of pre-processed complaints
doc_lens = [len(d) for d in df_clean['complaint_POS_removed']]
doc_lens[:5]
# Out:
# [192, 102, 74, 446, 192]

# %%
# Plot the data according to character length of complaints
plt.figure(figsize=(10,6))
plt.hist(doc_lens, edgecolor='black', bins = 50)
plt.title('Distribution of Complaint character length', fontsize=25)
plt.ylabel('Number of Complaint', fontsize=20)
plt.xlabel('Complaint character length', fontsize=20)
sns.despine()
plt.show()

# %% [markdown]
# ### 📌 The distribution of word counts is skewed a little positie but overall it is a pretty mormal distribution.
# ### 💠 Now, we plot the top 40 words by frequency using a word cloud

# %%
#Using a word cloud, we plot the top 40 words by frequency among all the articles after processing the text
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='lemonchiffon',
                          stopwords=stopwords,
                          max_words=40,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(df_clean['complaint_POS_removed']))

fig = plt.figure(figsize=(20,15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
#Removing -PRON- from the text corpus
df_clean['complaint_POS_removed'] = df_clean['complaint_POS_removed'].str.replace('-PRON-', '')

# %% [markdown]
# ### 💠 Next, we find the top unigrams, bigrams and trigrams by frequency among all the complaints after processing the text.

# %%
# We now find the top 30 unigram frequency among the complaints in the cleaned dataframe(df_clean). 
def get_top_n_words(corpus, n=None):
    """
    This function takes a corpus of words (text) and returns the top n words(unigrams) among the words in the corpus according 
    to their frequency of occurence.
    :param corpus: input text
    :param n: number of top words(unigrams) to find
    :return: list of tuples with two elements each: the word and its frequency
    """
    vec = CountVectorizer(stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# Top 30 unigrams by frequency among all the complaints
common_words = get_top_n_words(df_clean['complaint_POS_removed'].values.astype('U'), 30)
df2 = pd.DataFrame(common_words, columns = ['unigram' , 'count'])

# Plot the top 30 unigrams
plt.figure(figsize=(15,6))
sns.barplot(x='unigram', y='count', data=df2, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Top 30 unigrams in the Complaint text after removing stop words and lemmatization", fontsize=20)
plt.show()

# %%
# View top 10 unigrams
df2.head(10)
# Out:
#    unigram  count
# 0    chase  49982
# 1  account  47138
# 2     xxxx  34192
# 3   credit  34141
# 4     card  29072
# 5     bank  28387
# 6  payment  21148
# 7     time  15903
# 8   charge  15537
# 9      day  12932

# %%
# We now find the top 30 bigram frequency among the complaints in the cleaned dataframe(df_clean). 
def get_top_n_bigram(corpus, n=None):
    """
    This function takes a corpus of words (text) and returns the top n bigrams among the words in the corpus according 
    to their frequency of occurence.
    :param corpus: input text
    :param n: number of top bigrams to find
    :return: list of tuples with two elements each: the bigram and its frequency
    """
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# Top 30 bigrams by frequency among all the complaints
common_words = get_top_n_bigram(df_clean['complaint_POS_removed'].values.astype('U'), 30)
df3 = pd.DataFrame(common_words, columns = ['bigram' , 'count'])

# Plot the top 30 bigrams
plt.figure(figsize=(15,6))
sns.barplot(x='bigram', y='count', data=df3, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Top 30 bigrams in the Complaint text after removing stop words and lemmatization", fontsize=20)
plt.show()

# %%
#Print the top 10 words in the bigram frequency
df3.head(10)
# Out:
#              bigram  count
# 0       credit card  12771
# 1     credit report   3963
# 2         xxxx xxxx   3479
# 3        chase bank   3359
# 4  customer service   3076
# 5      chase credit   2946
# 6      bank account   2769
# 7     account chase   2689
# 8     chase account   2477
# 9   account account   2300

# %%
# We now find the top 30 trigram frequency among the complaints in the cleaned dataframe(df_clean). 
def get_top_n_trigram(corpus, n=None):
    """
    This function takes a corpus of words (text) and returns the top n trigrams among the words in the corpus according 
    to their frequency of occurence.
    :param corpus: input text
    :param n: number of top trigrams to find
    :return: list of tuples with two elements each: the trigram and its frequency
    """
    vec = CountVectorizer(ngram_range=(3, 3), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %%
# Top 30 trigrams by frequency among all the complaints
common_words = get_top_n_trigram(df_clean['complaint_POS_removed'].values.astype('U'), 30)
df4 = pd.DataFrame(common_words, columns = ['trigram' , 'count'])

# Plot the top 30 unigrams
plt.figure(figsize=(15,6))
sns.barplot(x='trigram', y='count', data=df4, palette="coolwarm")
plt.xticks(rotation=90)
plt.title("Top 30 trigrams in the Complaint text after removing stop words and lemmatization", fontsize=20)
plt.show()

# %%
# Print the top 10 words in the trigram frequency
df4.head(10)
# Out:
#                    trigram  count
# 0        chase credit card   2021
# 1      credit card account   1027
# 2      credit card company    988
# 3        credit card chase    647
# 4       credit card credit    496
# 5    inquiry credit report    489
# 6       charge credit card    459
# 7   chase customer service    409
# 8      account credit card    387
# 9  credit reporting agency    384

# %% [markdown]
# ### 📌 The personal details of customer has been masked in the dataset with `xxxx`.
# ### 💠 We will remove the masked text as this will be of no use for our analysis.

# %%
# Remove masks 'xxxx' from complaints
df_clean['complaint_POS_removed'] = df_clean['complaint_POS_removed'].str.replace('xxxx','')

# %%
# View final pre-processed data
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            complaint_POS_removed
# 1                                                                                                                                                                                                                                                                 morning  name  stop bank cardmember service ask debt verification statement i bank debt mail month attempt debt i right information consumer chase account thank advance  help
# 2                                                                                                                                                                                                                                                                                                                                                 i card agent upgrade date agent information order account change date  consent recording agent
# 10                                                                                                                                                                                                                                                                                                                                                                    card report application identity consent service credit identity applicant
# 11  try book  ticket i offer ticket card i information offer minute screen decision  bank i chase bank notification screen i chase representative i application state i ask information  offer  credit offer account statement use ticket i account i application representative oblige put application explicit request application chase chase fact credit account name report credit report chase information credit report application error
# 14                                                                                                                                                                                                                                                    son check deposit  chase account fund chase bank account money son check money chase bank refuse money son call chase time i check owner country time date check number claim number chase

# %% [markdown]
# # `Task 5`: Feature Extraction ✨

# %% [markdown]
# ### 💠 Now, we convert the raw texts to a matrix of TF-IDF features
#
# ***Note***: Here, we use following parameters of TfidfVectorizer:-
#
# **`max_df`** is used for removing terms that appear too frequently, also known as "corpus-specific stop words"
# max_df = 0.95 means "ignore terms that appear in more than 95% of the complaints"
#
# **`min_df`** is used for removing terms that appear too infrequently
# min_df = 2 means "ignore terms that appear in less than 2 complaints"

# %%
# Initialize the TfidfVectorizer 
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %% [markdown]
# ### 💠 Next, we create a document term matrix using fit_transform
#
# - The contents of a document term matrix are tuples of (complaint_id,token_id) tf-idf score:
# - The tuples that are not there have a tf-idf score of 0

# %%
# Create the Document Term Matrix by transforming the complaints column present in df_clean.
dtm = tfidf.fit_transform(df_clean['complaint_POS_removed'])

# %% [markdown]
# # `Task 6`: Topic Modelling 🏷️

# %% [markdown]
# ### 💠 We now perform Topic Modelling using NMF
#
# - `Non-Negative Matrix Factorization (NMF)` is an unsupervised technique so there are no labeling of topics that the model will be trained on. The way it works is that, NMF decomposes (or factorizes) high-dimensional vectors into a lower-dimensional representation. These lower-dimensional vectors are non-negative which also means their coefficients are non-negative.
#
#
#
# - We will perform the following steps:
#
#     * Find the best number of clusters/topics
#     * Apply the best number to create word clusters/topics
#     * Inspect & validate the correction of each cluster for each complaint
#     * Correct the labels if needed
#     * Map the clusters to topics/cluster names

# %% [markdown]
# ### 💠 To select best number of Topics, we will use `Coherence Model`
#
# - With the Coherence Model we will see how to automatically select the best number of topics.

# %%
# Use Coherence model to find best number of topics
from gensim.corpora.dictionary import Dictionary
from gensim.models.nmf import Nmf
from gensim.models.coherencemodel import CoherenceModel
from operator import itemgetter

# Use Gensim's NMF to get the best num of topics via coherence score
texts = df_clean['complaint_POS_removed']
dataset = [d.split() for d in texts]

# Create a dictionary
# In gensim a dictionary is a mapping between words and their integer id
dictionary = Dictionary(dataset)

# Filter out extremes to limit the number of features
dictionary.filter_extremes(
    no_below=3,
    no_above=0.85,
    keep_n=5000
)

# Create the bag-of-words format (list of (token_id, token_count))
corpus = [dictionary.doc2bow(text) for text in dataset]

# Create a list of the topic numbers we want to try
topic_nums = list(np.arange(5, 10, 1))

# Run the nmf model and calculate the coherence score
# for each number of topics
coherence_scores = []

for num in topic_nums:
    nmf = Nmf(
        corpus=corpus,
        num_topics=num,
        id2word=dictionary,
        chunksize=2000,
        passes=5,
        kappa=.1,
        minimum_probability=0.01,
        w_max_iter=300,
        w_stop_condition=0.0001,
        h_max_iter=100,
        h_stop_condition=0.001,
        eval_every=10,
        normalize=True,
        random_state=42
    )
    
    # Run the coherence model to get the score
    cm = CoherenceModel(
        model=nmf,
        texts=texts,
        dictionary=dictionary,
        coherence='c_v'
    )
    
    coherence_scores.append(round(cm.get_coherence(), 5))

# Get the number of topics with the highest coherence score
scores = list(zip(topic_nums, coherence_scores))
best_num_topics = sorted(scores, key=itemgetter(1), reverse=True)[0][0]

print(best_num_topics)
# Out:
# 5

# %% [markdown]
# ###  💠 Manual Topic Modeling
#
# - With the Coherence Model we got the **best number of topics = 5**.
#
# - The hard work is already done at this point so all we need to do is run the model.
#
# - The only parameter that is required is the number of components i.e. the number of topics we want.
# - This is the most crucial step in the whole topic modeling process and will greatly affect how good your final topics are.

# %%
# Load nmf_model with the n_components set to 5
nmf_model = NMF(n_components=5, random_state=40)

# %%
# Fit the model on document term matrix
nmf_model.fit(dtm)

# View the number of features
len(tfidf.get_feature_names())
# Out:
# 7404

# %%
# Print the top word of a sample component
single_topic = nmf_model.components_[0]
single_topic.argsort()
top_word_indices = single_topic.argsort()[-10:]
for index in top_word_indices:
    print(tfidf.get_feature_names()[index])
# Out:
# number
# day
# branch
# deposit
# fund
# chase
# money
# check
# bank
# account

# %%
# Print the Top 15 words for each of the topics
for index,topic in enumerate(nmf_model.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['customer', 'transfer', 'claim', 'transaction', 'business', 'number', 'day', 'branch', 'deposit', 'fund', 'chase', 'money', 'check', 'bank', 'account']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['balance', 'year', 'letter', 'application', 'debt', 'information', 'limit', 'company', 'score', 'account', 'chase', 'inquiry', 'report', 'card', 'credit']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['error', 'year', 'chase', 'account', 'credit', 'date', 'auto', 'time', 'pay', 'day', 'fee', 'statement', 'month', 'balance', 'payment']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['company', 'statement', 'time', 'refund', 'service', 'fraud', 'claim', 'purchase', 'merchant', 'dispute', 'transaction', 'chase', 'fee', 'card', 'charge']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['sale', 'foreclosure', 'bank', 'house', 'document', 'time', 'rate', 'letter', 'year', 'property', 'modification', 'chase', 'home', 'mortgage', 'loan']

# %%
# Create the best topic for each complaint in terms of integer value 0,1,2,3 & 4

topic_results = nmf_model.transform(dtm)
topic_results[0].round(2)
topic_results[0].argmax()
topic_results.argmax(axis=1)
# Out:
# array([0, 1, 1, ..., 3, 2, 2])

# %%
# Create a new 'Topic' column and assign the best topic to each of the complaints

df_clean['Topic'] = topic_results.argmax(axis=1)

# View the feature matrix
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            complaint_POS_removed  \
# 1                                                                                                                                                                                                                                                                 morning  name  stop bank cardmember service ask debt verification statement i bank debt mail month attempt debt i right information consumer chase account thank advance  help
# 2                                                                                                                                                                                                                                                                                                                                                 i card agent upgrade date agent information order account change date  consent recording agent
# 10                                                                                                                                                                                                                                                                                                                                                                    card report application identity consent service credit identity applicant
# 11  try book  ticket i offer ticket card i information offer minute screen decision  bank i chase bank notification screen i chase representative i application state i ask information  offer  credit offer account statement use ticket i account i application representative oblige put application explicit request application chase chase fact credit account name report credit report chase information credit report application error
# 14                                                                                                                                                                                                                                                    son check deposit  chase account fund chase bank account money son check money chase bank refuse money son call chase time i check owner country time date check number claim number chase
#
#     Topic
# 1       0
# 2       1
# 10      1
# 11      1
# 14      0

# %%
# Print the first 5 Complaint for each of the Topics
df_clean5 = df_clean.groupby('Topic').head(5)

df_clean5.sort_values('Topic')
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           with out notice jp morgan chase restricted my account by my debit card tuesday  on thursday  i went into a branch after being advised by a customer service representative that my account would actually be closed i went into the branch to see how i can remove the funds that are in there currently in as well as if my direct ...
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              purchase amount i charge transaction dispute case bank charge account i sunday credit charge monday i charge credit debt card monday  bank nevada  account activity i fraud  account i i dispute department place dispute case charge  i  charge credit account day dispute department monday  credit account accuse make dispute claim escalation manager decision account i customer chase year character dispute agent i character slander i  account chase i report account chase checking account i record closure chase i nothing file dispute claim charge dispute case past
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          payment online retailer use pay  chase website i website confirmation product response inquiry regard order contact chase information transaction refund retailer bank chase message explain way transaction contact  information recipient message response restate email  transfer mention website scam expertise team order regard refund request  consumer online support team i number list email situation transfer claim department i  transaction chase information i transfer agent call script contact number opportunity information question  word phrase i information i i call  automate system  bank i bank app transaction i menu customer service agent tell information transaction chase s system i bank app transaction stay line everything i well understanding situation call chase i time agent try information bank information  information i situation claim department  information i i i nothing  nature transaction type transaction chase information recipient email address inputte recipient banking information system phone call ask transaction use  responsibility regard matter process feel chase policy regard type transaction help information situation transaction way money way business chase s advertising victimize way i member customer service team
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               concern bank charge fee i balance fee balance transaction need order charge overdraft fee call guideline bank fault money  document chase refund way  refund place
# 43                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             send email today title information regard change account title ad communication force  bind arbitration something part contract  method information consequence problem chase account chase email require  letter information enclose order secure loss time money malpractice chase
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    loan modification chase runaround payment doc
# 73                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        chase branch reinstatement amount bank order foreclosure property executive ms trustee rule regulation payoff order foreclosure sale date family resident  i  time ask reinstatement amount foreclosure resort chapter bankruptcy filing i  assistant chase foreclosure trustee quality sense harass family default claim explain complaint  complaint d submit product mortgage issue foreclosure thank
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         loan title contact time resolution time tell nothing move state i registration state i title i car i car
# 99                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               name  payment day i time loan modification loss mitigation assistance help loan forbearance option i  issue refinance  dti debt time credit score
#
#      Topic
# 1        0
# 14       0
# 17       0
# 24       0
# 27       0
# 2        1
# 10       1
# 11       1
# 15       1
# 23       1
# 82       2
# 58       2
# 167      2
# 20       2
# 141      2
# 32       3
# 40       3
# 45       3
# 21       3
# 30       3
# 43       4
# 57       4
# 73       4
# 81       4
# 99       4

# %% [markdown]
# ### 📌 After looking carefully at the first 5 complaints for each topics, we can assign names to topics as below
# - `Topic 0`: **Bank Account services**
# - `Topic 1`: **Credit card or prepaid card**
# - `Topic 2`: **Others**
# - `Topic 3`: **Theft/Dispute Reporting**
# - `Topic 4`: **Mortgage/Loan**
#
# ### 💠 We create a dictionary and map the above names to the 5 topics

# %%
#Create the dictionary of Topic names and Topics
Topic_names = {0:"Bank Account services",
               1:"Credit card or prepaid card", 
               2:"Others",
               3:"Theft/Dispute Reporting",
               4:"Mortgage/Loan"}

#Replace Topics with Topic Names
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# %%
# View the feature matrix
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            complaint_POS_removed  \
# 1                                                                                                                                                                                                                                                                 morning  name  stop bank cardmember service ask debt verification statement i bank debt mail month attempt debt i right information consumer chase account thank advance  help
# 2                                                                                                                                                                                                                                                                                                                                                 i card agent upgrade date agent information order account change date  consent recording agent
# 10                                                                                                                                                                                                                                                                                                                                                                    card report application identity consent service credit identity applicant
# 11  try book  ticket i offer ticket card i information offer minute screen decision  bank i chase bank notification screen i chase representative i application state i ask information  offer  credit offer account statement use ticket i account i application representative oblige put application explicit request application chase chase fact credit account name report credit report chase information credit report application error
# 14                                                                                                                                                                                                                                                    son check deposit  chase account fund chase bank account money son check money chase bank refuse money son call chase time i check owner country time date check number claim number chase
#
#                           Topic
# 1         Bank Account services
# 2   Credit card or prepaid card
# 10  Credit card or prepaid card
# 11  Credit card or prepaid card
# 14        Bank Account services

# %% [markdown]
# # `Task 7`: Model Building 🏗️

# %% [markdown]
# ### 💠 Now that we have a label column, we can build Supervised model to predict any new complaints and assign them the relevant Topic.
#
# ### 💠 Since we will be using supervised learning technique, we have to convert the topic names to numbers (numpy arrays only understand numbers)

# %%
# Create the dictionary again of Topic names and Topic numbers
Topic_names = {"Bank Account services":0,
               "Credit card or prepaid card":1,
               "Others":2,
               "Theft/Dispute Reporting":3,
               "Mortgage/Loan":4}

# Replace Topic Names with Topic numbers
df_clean['Topic'] = df_clean['Topic'].map(Topic_names)

# View the dataframe
df_clean.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        lemmatized_complaint  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            good morning -PRON- name be xxxx xxxx and i appreciate -PRON- if -PRON- could help -PRON- put a stop to chase bank cardmember service \n in   i write to chase ask for debt verification and what -PRON- send -PRON- a statement which be not acceptable i be ask the bank to validate the debt instead i be receive mail every month from -PRON- attempt to collect a debt \n i have a right to know this information as a consumer \n\n chase account   xxxx xxxx xxxx xxxx thank in advance for -PRON- help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   i upgrade -PRON- xxxx xxxx card in   and be tell by the agent who do the upgrade -PRON- anniversary date would not change -PRON- turn the agent be give -PRON- the wrong information in order to upgrade the account xxxx    change -PRON- anniversary date from xxxxxxxx to xxxxxxxx without -PRON- consent xxxx have the recording of the agent who be mislead -PRON-
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          chase card be report on   however fraudulent application have be submit -PRON- identity without -PRON- consent to fraudulently obtain service do not extend credit without verify the identity of the applicant
# 11  on   while try to book a xxxx   xxxx   ticket i come across an offer for   to be apply towards the ticket if i apply for a reward card i put in -PRON- information for the offer and within less than a minute be notify via the screen that a decision could not be make i immediately contact xxxx and be refer to chase bank i then immediately contact chase bank within no more than   of get the notification on the screen and i be tell by the chase representative i speak with that -PRON- application be deny but -PRON- could not state why i ask for more information about the xxxx   offer and -PRON- explain that even if i have be approve the credit offer only get apply after the first account statement and could not be use to purchase the ticket i then explicitly tell -PRON- i be glad i get deny and i be absolutely no long interested in the account i ask that the application be withdraw and the representative oblige this all happen no later than   after put in the application on   notwithstanding -PRON- explicit request not to proceed with the application and contrary to what i be tell by the chase representative chase do in fact go ahead to open a credit account in -PRON- name on   this be now be report in -PRON- credit report and chase have refuse to correct this information on -PRON- credit report even though -PRON- go ahead to process an application which i do not consent to and out of -PRON- error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   -PRON- grand son give -PRON- check for   i deposit -PRON- into -PRON- chase account after fund clear -PRON- chase bank close -PRON- account never pay -PRON- -PRON- money -PRON- say -PRON- need to speek with -PRON- grand son check be clear money be take by -PRON- chase bank refuse to pay -PRON- -PRON- money -PRON- grand son call chase   time -PRON- tell -PRON- i should call not -PRON- to verify the check owner -PRON- be out the country most the time   date happen   check number xxxx claim number be xxxx with chase
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            complaint_POS_removed  \
# 1                                                                                                                                                                                                                                                                 morning  name  stop bank cardmember service ask debt verification statement i bank debt mail month attempt debt i right information consumer chase account thank advance  help
# 2                                                                                                                                                                                                                                                                                                                                                 i card agent upgrade date agent information order account change date  consent recording agent
# 10                                                                                                                                                                                                                                                                                                                                                                    card report application identity consent service credit identity applicant
# 11  try book  ticket i offer ticket card i information offer minute screen decision  bank i chase bank notification screen i chase representative i application state i ask information  offer  credit offer account statement use ticket i account i application representative oblige put application explicit request application chase chase fact credit account name report credit report chase information credit report application error
# 14                                                                                                                                                                                                                                                    son check deposit  chase account fund chase bank account money son check money chase bank refuse money son call chase time i check owner country time date check number claim number chase
#
#     Topic
# 1       0
# 2       1
# 10      1
# 11      1
# 14      0

# %% [markdown]
# ### 💠 Now that we have assigned a topic to each complaint, we can select these two columns as our training data

# %%
# Keep the columns"complaint_what_happened" & "Topic" only in the new dataframe --> training_data
training_data = df_clean[["complaint_what_happened","Topic"]]

# View the training data
training_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       complaint_what_happened  \
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning my name is xxxx xxxx and i appreciate it if you could help me put a stop to chase bank cardmember services \nin  i wrote to chase asking for debt verification and what they sent me a statement which is not acceptable i am asking the bank to validate the debt instead i been receiving mail every month from them attempting to collect a debt \ni have a right to know this information as a consumer \n\nchase account  xxxx xxxx xxxx xxxx thanks in advance for your help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i upgraded my xxxx xxxx card in  and was told by the agent who did the upgrade my anniversary date would not change it turned the agent was giving me the wrong information in order to upgrade the account xxxx   changed my anniversary date from xxxxxxxx to xxxxxxxx without my consent xxxx has the recording of the agent who was misled me
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         chase card was reported on  however fraudulent application have been submitted my identity without my consent to fraudulently obtain services do not extend credit without verifying the identity of the applicant
# 11  on  while trying to book a xxxx  xxxx  ticket i came across an offer for  to be applied towards the ticket if i applied for a rewards card i put in my information for the offer and within less than a minute was notified via the screen that a decision could not be made i immediately contacted xxxx and was referred to chase bank i then immediately contacted chase bank within no more than  of getting the notification on the screen and i was told by the chase representative i spoke with that my application was denied but she could not state why i asked for more information about the xxxx  offer and she explained that even if i had been approved the credit offer only gets applied after the first account statement and could not be used to purchase the ticket i then explicitly told her i was glad i got denied and i was absolutely no longer interested in the account i asked that the application be withdrawn and the representative obliged this all happened no later than  after putting in the application on  notwithstanding my explicit request not to proceed with the application and contrary to what i was told by the chase representative chase did in fact go ahead to open a credit account in my name on  this is now being reported in my credit report and chase has refused to correct this information on my credit report even though they went ahead to process an application which i did not consent to and out of their error
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   my grand son give me check for  i deposit it into my chase account after fund clear my chase bank closed my account never paid me my money they said they need to speek with my grand son check was clear money was taking by my chase bank refuse to pay me my money my grand son called chase  times they told him i should call not him to verify the check owner he is out the country most the time  date happen  check number xxxx claim number is xxxx with chase
#
#     Topic
# 1       0
# 2       1
# 10      1
# 11      1
# 14      0

# %%
# View dimensions of training data
training_data.shape
# Out:
# (21072, 2)

# %% [markdown]
# ### 💠 View the distribution of target variable `Topic`

# %%
# View value counts of the five topics
training_data['Topic'].value_counts()
# Out:
# 0    5194
# 1    5010
# 3    4775
# 4    3864
# 2    2229
# Name: Topic, dtype: int64

# %%
# Plot a histogram of classes (i.e. topics)
sns.histplot(data=training_data, x='Topic')
plt.title("Distribution of Topics", fontsize=20)
plt.show()

# %% [markdown]
# ### 💠 Selection of Evaluation Metric
#
# - As the distribution of target variable is not normal and there is imbalance of classes, we select **F1 Score** as our evaluation metric for comparing the performance of various models we will build.
# - Moreover, we will use a **weighted average** method for evaluating `F1 Score` due to the imbalance of classes

# %% [markdown]
# ###  💠 We can now apply the supervised models on the training data created.
#
# - In this process, we will do the following:
#     * Create the vector counts using Count Vectorizer
#     * Transform the word vector to tf-idf
#     * Create the train & test data using the train_test_split on the tf-idf & topics

# %%
# Get the Vector count
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(training_data['complaint_what_happened'])

# %%
# Save Word Vector
pickle.dump(count_vect.vocabulary_, open("count_vector.pkl","wb"))

# %%
# Transform the word vector to tf-idf
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
# Save TF-IDF
pickle.dump(tfidf_transformer, open("tfidf.pkl","wb"))

# %%
# Perform Train-Test split
X_train, X_test, y_train, y_test = train_test_split(X_train_tfidf, training_data.Topic, test_size=0.25, random_state=42)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (15804, 33599)
# Shape of y_train: (15804,)
# Shape of X_test: (5268, 33599)
# Shape of y_test: (5268,)

# %% [markdown]
# ### 💠 Now, we will try the following models one by one and evaluate them to select the best performing one
#
# 1. Naive Bayes (this will serve as a baseline model)
# 2. Logistic regression
# 3. Decision Tree
# 4. Random Forest
# 5. Support Vector Machine
# 6. XGBoost
# 7. CatBoost

# %% [markdown]
# ### 💠 Create a function to evaluate the classifiers

# %%
# Create a function to evaluate models
def eval_model(y_test, y_pred, model_name):
    """
    This function prints the classification report of a classifier 
    and plots the confusion martrix
    :param y_test: actual labels
    :param y_pred: predicted labels
    :param model_name: the name of the model being evaluated
    :return: None
    """
    
    # print classification report of classifier
    print(f"CLASSIFICATION REPORT for {model_name}\n")
    print(classification_report(y_test, y_pred, target_names=["Bank Account services", "Credit card or prepaid card", "Others", "Theft/Dispute Reporting",
"Mortgage/Loan"]))
    
    # plot confusion matrix of the classifier
    plt.figure(figsize=(10,6))
    plt.title(f"CONFUSION MATRIX for {model_name}\n")
    matrix = confusion_matrix(y_test, y_pred)
    sns.heatmap(matrix, annot=True, cbar=None, cmap="Blues", fmt='d', xticklabels=["Bank Account services", "Credit card or prepaid card", "Others", "Theft/Dispute Reporting",
"Mortgage/Loan"], yticklabels=["Bank Account services", "Credit card or prepaid card", "Others", "Theft/Dispute Reporting",
"Mortgage/Loan"])
    plt.show()
    
    return

# %% [markdown]
# ## `Model #1`: Naive Bayes 😯

# %%
# Run the Multinomial Naive Bayes with default parameters
model_name = 'NAIVE BAYES'
clf_nb = MultinomialNB()
# %time 
clf_nb.fit(X_train, y_train)
y_pred_nb = clf_nb.predict(X_test)
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.48 µs

# %%
# Calculate F1 Score using weighted average method
f1_nb = f1_score(y_test, y_pred_nb, average="weighted")
f1_nb
# Out:
# 0.6804148035407689

# %%
# # Hyperparameter tuning to improve Naive Bayes performance
# param_grid_nb = {
#     'alpha': (1, 0.1, 0.01, 0.001, 0.0001, 0.00001),
#     'fit_prior':[True, False]
# }

# grid_nb = GridSearchCV(estimator=clf_nb, 
#                        param_grid=param_grid_nb,
#                        verbose=1,
#                        scoring='f1_weighted',
#                        n_jobs=-1,
#                        cv=10)
# grid_nb.fit(X_train, y_train)
# print(grid_nb.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
#
#
# {'alpha': 0.1, 'fit_prior': False}

# %%
# Run Multinomial Naive Bayes on tuned hyperparameters
clf_nb_tuned = MultinomialNB(alpha=0.1, fit_prior=False)
# %time 
clf_nb_tuned.fit(X_train, y_train)
y_pred_nb_tuned = clf_nb_tuned.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 9.06 µs

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_nb_tuned = f1_score(y_test, y_pred_nb_tuned, average="weighted")
f1_nb_tuned
# Out:
# 0.7824670749458811

# %%
# Evaluate the tuned Naive Bayes classifier
eval_model(y_test, y_pred_nb_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for NAIVE BAYES
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.77      0.84      0.81      1301
# Credit card or prepaid card       0.80      0.75      0.78      1289
#                      Others       0.70      0.63      0.66       548
#     Theft/Dispute Reporting       0.77      0.77      0.77      1201
#               Mortgage/Loan       0.84      0.85      0.84       929
#
#                    accuracy                           0.78      5268
#                   macro avg       0.78      0.77      0.77      5268
#                weighted avg       0.78      0.78      0.78      5268

# %% [markdown]
# ### 📌 The tuned Naive Bayes model gives a moderately well F1 score of 0.78.
#
# ### 📌 However, this model performs a bit poor on classifying `Others` compared to remaining four topics.

# %% [markdown]
# ### 💠 Create a summary table to store and compare F1 Scores of all models

# %%
# Create a dataframe to store F1 Scores of all models we will build
summary = pd.DataFrame([{'Model': 'Naive Bayes','F1 Score (untuned)': round(f1_nb, 2), 'F1 Score (tuned)': round(f1_nb_tuned, 2)}])
summary
# Out:
#          Model  F1 Score (untuned)  F1 Score (tuned)
# 0  Naive Bayes                0.68              0.78

# %% [markdown]
# ## `Model #2`: Logistic Regression 📈

# %%
# Run the Logistic Regression model
model_name = 'LOGISTIC REGRESSION'
clf_lr = LogisticRegression(solver='liblinear')
# %time 
clf_lr.fit(X_train, y_train)
y_pred_lr = clf_lr.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.54 µs

# %%
# Calculate F1 Score using weighted average method
f1_lr = f1_score(y_test, y_pred_lr, average="weighted")
f1_lr
# Out:
# 0.9225722750856091

# %%
# # Hyperparameter tuning to improve Logistic Regression performance
# param_grid_lr = {
#     'penalty': ['l1', 'l2','elasticnet', 'none'],
#     'C': [0.001,0.01,0.1,1,10,100],
#     'solver':['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
# }

# grid_lr = GridSearchCV(estimator=clf_lr, 
#                        param_grid=param_grid_lr,
#                        verbose=1,
#                        scoring='f1_weighted',
#                        n_jobs=-1,
#                        cv=5)
# grid_lr.fit(X_train, y_train)
# print(grid_lr.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
#
#
# {'C': 1, 'penalty': 'l1', 'solver': 'saga'}

# %%
# Run Logistic Regression on tuned hyperparameters
clf_lr_tuned = LogisticRegression(C=1, 
                                  penalty='l1', 
                                  solver='saga')
# %time 
clf_lr_tuned.fit(X_train, y_train)
y_pred_lr_tuned = clf_lr_tuned.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.78 µs

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_lr_tuned = f1_score(y_test, y_pred_lr_tuned, average="weighted")
f1_lr_tuned
# Out:
# 0.9425630034468586

# %%
# Evaluate the tuned Logistic Regression classifier
eval_model(y_test, y_pred_lr_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for LOGISTIC REGRESSION
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.94      0.96      0.95      1301
# Credit card or prepaid card       0.95      0.95      0.95      1289
#                      Others       0.94      0.95      0.94       548
#     Theft/Dispute Reporting       0.94      0.91      0.92      1201
#               Mortgage/Loan       0.94      0.95      0.94       929
#
#                    accuracy                           0.94      5268
#                   macro avg       0.94      0.94      0.94      5268
#                weighted avg       0.94      0.94      0.94      5268

# %% [markdown]
# ### 📌 The tuned Logistic Regression model gives a pretty high F1 score of 0.94.
# ### 📌 This model performs well on all topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['Logistic Regression', round(f1_lr, 2), round(f1_lr_tuned, 2)]
summary
# Out:
#                  Model  F1 Score (untuned)  F1 Score (tuned)
# 0          Naive Bayes                0.68              0.78
# 1  Logistic Regression                0.92              0.94

# %% [markdown]
# ## `Model #3`: Decision Tree 🌴

# %%
# Run Decision Tree on default hyperparameters
model_name = 'DECISION TREE'
clf_dt = DecisionTreeClassifier()
# %time 
clf_dt.fit(X_train, y_train)
y_pred_dt = clf_dt.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.06 µs

# %%
# Calculate F1 Score using weighted average method
f1_dt = f1_score(y_test, y_pred_dt, average="weighted")
f1_dt
# Out:
# 0.7758451615519055

# %%
# # Hyperparameter tuning to improve Decision Tree performance
# param_grid_dt = {
#     'criterion': ['gini', 'entropy'],
#     'max_depth' : [5, 10, 15, 20, 25, 30],
#     'min_samples_leaf':[1,5,10,15, 20, 25],
#     'max_features':['auto','log2','sqrt',None],
# }

# grid_dt = GridSearchCV(estimator=clf_dt, 
#                        param_grid=param_grid_dt,
#                        verbose=1,
#                        scoring='f1_weighted',
#                        n_jobs=-1,
#                        cv=5)
# grid_dt.fit(X_train, y_train)
# print(grid_dt.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
#
#
# {'criterion': 'gini', 'max_depth': 30, 'max_features': None, 'min_samples_leaf': 15}

# %%
# Run Decision Tree on tuned hyperparameters
clf_dt_tuned = DecisionTreeClassifier(criterion='gini', 
                                      max_depth=30, 
                                      min_samples_leaf=15, 
                                      max_features=None)
# %time 
clf_dt_tuned.fit(X_train, y_train)
y_pred_dt_tuned = clf_dt_tuned.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10 µs

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_dt_tuned = f1_score(y_test, y_pred_dt_tuned, average="weighted")
f1_dt_tuned
# Out:
# 0.8020278499134068

# %%
# Evaluate the tuned Decision Tree classifier
eval_model(y_test, y_pred_dt_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for DECISION TREE
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.79      0.83      0.81      1301
# Credit card or prepaid card       0.83      0.84      0.83      1289
#                      Others       0.79      0.77      0.78       548
#     Theft/Dispute Reporting       0.77      0.74      0.75      1201
#               Mortgage/Loan       0.82      0.82      0.82       929
#
#                    accuracy                           0.80      5268
#                   macro avg       0.80      0.80      0.80      5268
#                weighted avg       0.80      0.80      0.80      5268

# %% [markdown]
# ### 📌 The tuned Decision Tree model gives a decent F1 score of 0.80.
# ### 📌 However, this model is not able to perform well on classifying `Others` and `Theft/Dispute Reporting` topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['Decision Tree', round(f1_dt, 2), round(f1_dt_tuned, 2)]
summary
# Out:
#                  Model  F1 Score (untuned)  F1 Score (tuned)
# 0          Naive Bayes                0.68              0.78
# 1  Logistic Regression                0.92              0.94
# 2        Decision Tree                0.78              0.80

# %% [markdown]
# ## `Model #4`: Random Forest 🌳🌳🌳

# %%
# Run the Random Forest model on default hyperparameters
model_name = 'RANDOM FOREST'
clf_rf = RandomForestClassifier()
# %time 
clf_rf.fit(X_train, y_train)
y_pred_rf = clf_rf.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.34 µs

# %%
# Calculate F1 Score using weighted average method
f1_rf = f1_score(y_test, y_pred_rf, average="weighted")
f1_rf
# Out:
# 0.8133841531738092

# %%
# # Hyperparameter tuning to improve Random Forest performance
# param_grid_rf = {
#     'n_estimators': [100, 200, 300, 500, 800],
#     'criterion':['gini','entropy'],
#     'max_depth': [10, 30, 40],
#     'min_samples_split': [1, 5, 10],
#     'min_samples_leaf': [1, 5, 10],
#     'max_features': ['log2', 'sqrt', None]    
# }

# grid_rf = RandomizedSearchCV(estimator=clf_rf, 
#                        param_distributions=param_grid_rf,
#                        scoring='f1_weighted',
#                        verbose=1,
#                        n_jobs=-1,
#                        cv=5)
# grid_rf.fit(X_train, y_train)
# print(grid_rf.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
# {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': None, 'max_depth': 30, 'criterion': 'gini'}

# %%
# Run Random Forest on tuned hyperparameters
clf_rf_tuned = RandomForestClassifier(n_estimators=100, 
                                      min_samples_split=5, 
                                      min_samples_leaf=5, 
                                      max_features=None, 
                                      max_depth=30, 
                                      criterion='gini'
)
# %time 
clf_rf_tuned.fit(X_train, y_train)
y_pred_rf_tuned = clf_rf_tuned.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.58 µs

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_rf_tuned = f1_score(y_test, y_pred_rf_tuned, average="weighted")
f1_rf_tuned
# Out:
# 0.8465564819988842

# %%
# Evaluate the tuned Random Forest classifier
eval_model(y_test, y_pred_rf_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for RANDOM FOREST
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.85      0.86      0.86      1301
# Credit card or prepaid card       0.86      0.87      0.87      1289
#                      Others       0.84      0.83      0.84       548
#     Theft/Dispute Reporting       0.83      0.79      0.81      1201
#               Mortgage/Loan       0.85      0.87      0.86       929
#
#                    accuracy                           0.85      5268
#                   macro avg       0.85      0.85      0.85      5268
#                weighted avg       0.85      0.85      0.85      5268

# %% [markdown]
# ### 📌 The tuned Random Forest model gives a pretty high F1 score of 0.85.
# ### 📌 This model performs quite well on all topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['Random Forest', round(f1_rf, 2), round(f1_rf_tuned, 2)]
summary
# Out:
#                  Model  F1 Score (untuned)  F1 Score (tuned)
# 0          Naive Bayes                0.68              0.78
# 1  Logistic Regression                0.92              0.94
# 2        Decision Tree                0.78              0.80
# 3        Random Forest                0.81              0.85

# %% [markdown]
# ## `Model #5`: Support Vector Machine 🏹

# %%
# Run the Support Vector Machine (SVM) model on default hyperparameters
model_name = 'SUPPORT VECTOR MACHINE'
clf_svm = SVC()
# %time 
clf_svm.fit(X_train, y_train)
y_pred_svm = clf_svm.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10 µs

# %%
# Calculate F1 Score using weighted average method
f1_svm = f1_score(y_test, y_pred_svm, average="weighted")
f1_svm
# Out:
# 0.9152085043602793

# %%
# # Hyperparameter tuning to improve SVM performance
# param_grid_svm = {
#     'C': [10, 15],
#     'gamma': ['scale', 0.01],
#     'kernel': ['linear', 'rbf']
# }

# grid_svm = GridSearchCV(estimator=clf_svm, 
#                        param_grid=param_grid_svm,
#                        scoring='f1_weighted',
#                        verbose=1,
#                        n_jobs=-1,
#                        cv=2)
# grid_svm.fit(X_train, y_train)
# print(grid_svm.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
# {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
# Run SVM on tuned hyperparameters
clf_svm_tuned = SVC(C=10,
                    gamma='scale',
                    kernel='rbf')
# %time 
clf_svm_tuned.fit(X_train, y_train)
y_pred_svm_tuned = clf_svm_tuned.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.3 µs

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_svm_tuned = f1_score(y_test, y_pred_svm_tuned, average="weighted")
f1_svm_tuned
# Out:
# 0.9142890514494358

# %%
# Evaluate the SVM classifier
eval_model(y_test, y_pred_svm_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for SUPPORT VECTOR MACHINE
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.91      0.94      0.92      1301
# Credit card or prepaid card       0.93      0.92      0.92      1289
#                      Others       0.94      0.89      0.91       548
#     Theft/Dispute Reporting       0.90      0.88      0.89      1201
#               Mortgage/Loan       0.91      0.93      0.92       929
#
#                    accuracy                           0.91      5268
#                   macro avg       0.92      0.91      0.91      5268
#                weighted avg       0.91      0.91      0.91      5268

# %% [markdown]
# ### 📌 The SVM model gives a pretty high F1 score of 0.92.
# ### 📌 This model performs quite well on all topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['Support Vector Machine', round(f1_svm, 2), round(f1_svm_tuned, 2)]
summary
# Out:
#                     Model  F1 Score (untuned)  F1 Score (tuned)
# 0             Naive Bayes                0.68              0.78
# 1     Logistic Regression                0.92              0.94
# 2           Decision Tree                0.78              0.80
# 3           Random Forest                0.81              0.85
# 4  Support Vector Machine                0.92              0.91

# %% [markdown]
# ## `Model #6`: XGBoost 💨

# %%
# Run XGBoost model on default hyperparameters 
################
# This uses GPU
################
model_name = 'XGBOOST'
clf_xgb = XGBClassifier(tree_method='gpu_hist', 
                        gpu_id=0, 
                        predictor="gpu_predictor")
# %time
clf_xgb.fit(X_train, y_train)
y_pred_xgb = clf_xgb.predict(X_test)
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 10.5 µs
# [11:22:55] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# Calculate F1 Score using weighted average method
f1_xgb = f1_score(y_test, y_pred_xgb, average="weighted")
f1_xgb
# Out:
# 0.9114673547099997

# %%
# # Hyperparameter tuning to improve XGBoost performance
# param_grid_xgb = {
#     'learning_rate': [0.1, 0.2],
#     'max_depth': [2, 6, 10],
#     'min_child_weight': [7, 11, 19],
#     'scale_pos_weight': [10, 12],
#     'n_estimators': [300, 500]
# }

# grid_xgb = RandomizedSearchCV(estimator=clf_xgb, 
#                               param_distributions=param_grid_xgb,
#                               scoring='f1_weighted',
#                               verbose=1,
#                               n_jobs=-1,
#                               cv=3)
# grid_xgb.fit(X_train, y_train)
# print(grid_xgb.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
#
# {'scale_pos_weight': 12, 'n_estimators': 500, 'min_child_weight': 11, 'max_depth': 2, 'learning_rate': 0.1}

# %%
# Run XGBoost on tuned hyperparameters
clf_xgb_tuned = XGBClassifier(scale_pos_weight=12, 
                              n_estimators=500, 
                              min_child_weight=11, 
                              max_depth=2, 
                              learning_rate=0.1, 
                              tree_method='gpu_hist', 
                              gpu_id=0, 
                              predictor="gpu_predictor"
)
# %time 
clf_xgb_tuned.fit(X_train, y_train)
y_pred_xgb_tuned = clf_xgb_tuned.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 6.91 µs
# [11:25:51] WARNING: ../src/learner.cc:573:
# Parameters: { "scale_pos_weight" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:25:51] WARNING: ../src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_xgb_tuned = f1_score(y_test, y_pred_xgb_tuned, average="weighted")
f1_xgb_tuned
# Out:
# 0.9163852832563436

# %%
# Evaluate the tuned XGBoost classifier
eval_model(y_test, y_pred_xgb_tuned, model_name)
# Out:
# CLASSIFICATION REPORT for XGBOOST
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.92      0.94      0.93      1301
# Credit card or prepaid card       0.92      0.92      0.92      1289
#                      Others       0.90      0.93      0.91       548
#     Theft/Dispute Reporting       0.91      0.88      0.90      1201
#               Mortgage/Loan       0.91      0.92      0.92       929
#
#                    accuracy                           0.92      5268
#                   macro avg       0.91      0.92      0.92      5268
#                weighted avg       0.92      0.92      0.92      5268

# %% [markdown]
# ### 📌 The tuned XGBoost model gives a pretty high F1 score of 0.92.
# ### 📌 This model performs quite well on all topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['XGBoost', round(f1_xgb, 2), round(f1_xgb_tuned, 2)]
summary
# Out:
#                     Model  F1 Score (untuned)  F1 Score (tuned)
# 0             Naive Bayes                0.68              0.78
# 1     Logistic Regression                0.92              0.94
# 2           Decision Tree                0.78              0.80
# 3           Random Forest                0.81              0.85
# 4  Support Vector Machine                0.92              0.91
# 5                 XGBoost                0.91              0.92

# %% [markdown]
# ## `Model #7`: CatBoost 🚅

# %%
# Run the CatBoost model on default hyperparameters
################
# This uses GPU
################
model_name = 'CATBOOST'
clf_cb = CatBoostClassifier(task_type="GPU",
                           loss_function='MultiClass')
# %time
clf_cb.fit(X_train, y_train)
y_pred_cb = clf_cb.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# Learning rate set to 0.113981
# 0:	learn: 1.4147096	total: 141ms	remaining: 2m 20s
# 1:	learn: 1.2850403	total: 232ms	remaining: 1m 55s
# 2:	learn: 1.1830123	total: 324ms	remaining: 1m 47s
# 3:	learn: 1.1046242	total: 414ms	remaining: 1m 42s
# 4:	learn: 1.0409131	total: 505ms	remaining: 1m 40s
# 5:	learn: 0.9855580	total: 587ms	remaining: 1m 37s
# 6:	learn: 0.9362138	total: 676ms	remaining: 1m 35s
# 7:	learn: 0.8964123	total: 769ms	remaining: 1m 35s
# 8:	learn: 0.8592786	total: 858ms	remaining: 1m 34s
# 9:	learn: 0.8263862	total: 949ms	remaining: 1m 33s
# 10:	learn: 0.7946045	total: 1.04s	remaining: 1m 33s
# 11:	learn: 0.7677802	total: 1.12s	remaining: 1m 32s
# 12:	learn: 0.7441204	total: 1.21s	remaining: 1m 31s
# 13:	learn: 0.7216105	total: 1.29s	remaining: 1m 31s
# 14:	learn: 0.7018939	total: 1.37s	remaining: 1m 30s
# 15:	learn: 0.6824972	total: 1.46s	remaining: 1m 29s
# 16:	learn: 0.6667184	total: 1.53s	remaining: 1m 28s
# 17:	learn: 0.6519208	total: 1.61s	remaining: 1m 27s
# 18:	learn: 0.6379323	total: 1.7s	remaining: 1m 27s
# 19:	learn: 0.6243392	total: 1.78s	remaining: 1m 27s
# 20:	learn: 0.6114138	total: 1.86s	remaining: 1m 26s
# 21:	learn: 0.5990913	total: 1.94s	remaining: 1m 26s
# 22:	learn: 0.5884592	total: 2.02s	remaining: 1m 25s
# 23:	learn: 0.5777884	total: 2.1s	remaining: 1m 25s
# 24:	learn: 0.5659681	total: 2.17s	remaining: 1m 24s
# 25:	learn: 0.5552689	total: 2.25s	remaining: 1m 24s
# 26:	learn: 0.5464362	total: 2.33s	remaining: 1m 24s
# 27:	learn: 0.5379011	total: 2.42s	remaining: 1m 23s
# 28:	learn: 0.5295043	total: 2.49s	remaining: 1m 23s
# 29:	learn: 0.5213271	total: 2.57s	remaining: 1m 23s
# 30:	learn: 0.5138547	total: 2.65s	remaining: 1m 22s
# 31:	learn: 0.5067620	total: 2.72s	remaining: 1m 22s
# 32:	learn: 0.4990136	total: 2.81s	remaining: 1m 22s
# 33:	learn: 0.4929787	total: 2.88s	remaining: 1m 21s
# 34:	learn: 0.4862619	total: 2.95s	remaining: 1m 21s
# 35:	learn: 0.4804732	total: 3.03s	remaining: 1m 21s
# 36:	learn: 0.4749738	total: 3.1s	remaining: 1m 20s
# 37:	learn: 0.4696381	total: 3.19s	remaining: 1m 20s
# 38:	learn: 0.4641541	total: 3.26s	remaining: 1m 20s
# 39:	learn: 0.4586365	total: 3.32s	remaining: 1m 19s
# 40:	learn: 0.4538863	total: 3.4s	remaining: 1m 19s
# 41:	learn: 0.4493198	total: 3.47s	remaining: 1m 19s
# 42:	learn: 0.4447556	total: 3.54s	remaining: 1m 18s
# 43:	learn: 0.4400735	total: 3.62s	remaining: 1m 18s
# 44:	learn: 0.4361738	total: 3.68s	remaining: 1m 18s
# 45:	learn: 0.4318260	total: 3.77s	remaining: 1m 18s
# 46:	learn: 0.4273073	total: 3.85s	remaining: 1m 17s
# 47:	learn: 0.4238257	total: 3.91s	remaining: 1m 17s
# 48:	learn: 0.4191123	total: 3.98s	remaining: 1m 17s
# 49:	learn: 0.4150693	total: 4.05s	remaining: 1m 17s
# 50:	learn: 0.4116011	total: 4.12s	remaining: 1m 16s
# 51:	learn: 0.4093506	total: 4.2s	remaining: 1m 16s
# 52:	learn: 0.4053350	total: 4.3s	remaining: 1m 16s
# 53:	learn: 0.4023109	total: 4.41s	remaining: 1m 17s
# 54:	learn: 0.3991184	total: 4.48s	remaining: 1m 17s
# 55:	learn: 0.3960075	total: 4.56s	remaining: 1m 16s
# 56:	learn: 0.3934646	total: 4.64s	remaining: 1m 16s
# 57:	learn: 0.3902524	total: 4.72s	remaining: 1m 16s
# 58:	learn: 0.3874064	total: 4.8s	remaining: 1m 16s
# 59:	learn: 0.3849291	total: 4.9s	remaining: 1m 16s
# 60:	learn: 0.3820553	total: 5s	remaining: 1m 16s
# 61:	learn: 0.3795118	total: 5.07s	remaining: 1m 16s
# 62:	learn: 0.3768313	total: 5.15s	remaining: 1m 16s
# 63:	learn: 0.3742352	total: 5.22s	remaining: 1m 16s
# 64:	learn: 0.3717971	total: 5.28s	remaining: 1m 16s
# 65:	learn: 0.3696692	total: 5.34s	remaining: 1m 15s
# 66:	learn: 0.3675899	total: 5.42s	remaining: 1m 15s
# 67:	learn: 0.3658036	total: 5.48s	remaining: 1m 15s
# 68:	learn: 0.3639286	total: 5.56s	remaining: 1m 15s
# 69:	learn: 0.3617542	total: 5.63s	remaining: 1m 14s
# 70:	learn: 0.3592611	total: 5.69s	remaining: 1m 14s
# 71:	learn: 0.3571513	total: 5.77s	remaining: 1m 14s
# 72:	learn: 0.3554037	total: 5.83s	remaining: 1m 14s
# 73:	learn: 0.3533088	total: 5.91s	remaining: 1m 13s
# 74:	learn: 0.3506768	total: 5.98s	remaining: 1m 13s
# 75:	learn: 0.3496626	total: 6.03s	remaining: 1m 13s
# 76:	learn: 0.3471613	total: 6.11s	remaining: 1m 13s
# 77:	learn: 0.3449392	total: 6.17s	remaining: 1m 13s
# 78:	learn: 0.3434605	total: 6.24s	remaining: 1m 12s
# 79:	learn: 0.3413250	total: 6.3s	remaining: 1m 12s
# 80:	learn: 0.3399005	total: 6.36s	remaining: 1m 12s
# 81:	learn: 0.3379982	total: 6.41s	remaining: 1m 11s
# 82:	learn: 0.3363501	total: 6.49s	remaining: 1m 11s
# 83:	learn: 0.3349320	total: 6.55s	remaining: 1m 11s
# 84:	learn: 0.3330378	total: 6.62s	remaining: 1m 11s
# 85:	learn: 0.3315197	total: 6.67s	remaining: 1m 10s
# 86:	learn: 0.3298034	total: 6.74s	remaining: 1m 10s
# 87:	learn: 0.3284557	total: 6.8s	remaining: 1m 10s
# 88:	learn: 0.3262766	total: 6.87s	remaining: 1m 10s
# 89:	learn: 0.3245347	total: 6.94s	remaining: 1m 10s
# 90:	learn: 0.3230696	total: 7s	remaining: 1m 9s
# 91:	learn: 0.3214532	total: 7.06s	remaining: 1m 9s
# 92:	learn: 0.3207073	total: 7.11s	remaining: 1m 9s
# 93:	learn: 0.3197927	total: 7.18s	remaining: 1m 9s
# 94:	learn: 0.3183255	total: 7.25s	remaining: 1m 9s
# 95:	learn: 0.3172603	total: 7.3s	remaining: 1m 8s
# 96:	learn: 0.3156019	total: 7.38s	remaining: 1m 8s
# 97:	learn: 0.3144732	total: 7.43s	remaining: 1m 8s
# 98:	learn: 0.3136272	total: 7.49s	remaining: 1m 8s
# 99:	learn: 0.3128820	total: 7.54s	remaining: 1m 7s
# 100:	learn: 0.3114493	total: 7.61s	remaining: 1m 7s
# 101:	learn: 0.3106726	total: 7.66s	remaining: 1m 7s
# 102:	learn: 0.3094944	total: 7.72s	remaining: 1m 7s
# 103:	learn: 0.3085752	total: 7.78s	remaining: 1m 7s
# 104:	learn: 0.3077941	total: 7.83s	remaining: 1m 6s
# 105:	learn: 0.3065204	total: 7.91s	remaining: 1m 6s
# 106:	learn: 0.3055186	total: 7.96s	remaining: 1m 6s
# 107:	learn: 0.3044331	total: 8.02s	remaining: 1m 6s
# 108:	learn: 0.3043833	total: 8.06s	remaining: 1m 5s
# 109:	learn: 0.3030629	total: 8.13s	remaining: 1m 5s
# 110:	learn: 0.3023312	total: 8.17s	remaining: 1m 5s
# 111:	learn: 0.3023050	total: 8.22s	remaining: 1m 5s
# 112:	learn: 0.3008292	total: 8.28s	remaining: 1m 4s
# 113:	learn: 0.3000588	total: 8.34s	remaining: 1m 4s
# 114:	learn: 0.2997799	total: 8.38s	remaining: 1m 4s
# 115:	learn: 0.2993705	total: 8.42s	remaining: 1m 4s
# 116:	learn: 0.2990372	total: 8.47s	remaining: 1m 3s
# 117:	learn: 0.2985299	total: 8.52s	remaining: 1m 3s
# 118:	learn: 0.2976076	total: 8.57s	remaining: 1m 3s
# 119:	learn: 0.2970835	total: 8.62s	remaining: 1m 3s
# 120:	learn: 0.2965046	total: 8.67s	remaining: 1m 2s
# 121:	learn: 0.2952840	total: 8.74s	remaining: 1m 2s
# 122:	learn: 0.2944459	total: 8.8s	remaining: 1m 2s
# 123:	learn: 0.2933994	total: 8.85s	remaining: 1m 2s
# 124:	learn: 0.2933771	total: 8.9s	remaining: 1m 2s
# 125:	learn: 0.2931309	total: 8.94s	remaining: 1m 2s
# 126:	learn: 0.2930993	total: 8.99s	remaining: 1m 1s
# 127:	learn: 0.2930747	total: 9.03s	remaining: 1m 1s
# 128:	learn: 0.2923104	total: 9.09s	remaining: 1m 1s
# 129:	learn: 0.2919970	total: 9.14s	remaining: 1m 1s
# 130:	learn: 0.2911222	total: 9.2s	remaining: 1m 1s
# 131:	learn: 0.2906387	total: 9.25s	remaining: 1m
# 132:	learn: 0.2901273	total: 9.29s	remaining: 1m
# 133:	learn: 0.2895413	total: 9.35s	remaining: 1m
# 134:	learn: 0.2887622	total: 9.4s	remaining: 1m
# 135:	learn: 0.2887361	total: 9.45s	remaining: 1m
# 136:	learn: 0.2882540	total: 9.5s	remaining: 59.8s
# 137:	learn: 0.2879880	total: 9.54s	remaining: 59.6s
# 138:	learn: 0.2877715	total: 9.59s	remaining: 59.4s
# 139:	learn: 0.2872162	total: 9.65s	remaining: 59.3s
# 140:	learn: 0.2871847	total: 9.7s	remaining: 59.1s
# 141:	learn: 0.2871115	total: 9.74s	remaining: 58.9s
# 142:	learn: 0.2870885	total: 9.79s	remaining: 58.6s
# 143:	learn: 0.2870061	total: 9.83s	remaining: 58.4s
# 144:	learn: 0.2862639	total: 9.88s	remaining: 58.3s
# 145:	learn: 0.2862421	total: 9.93s	remaining: 58.1s
# 146:	learn: 0.2856239	total: 9.98s	remaining: 57.9s
# 147:	learn: 0.2853610	total: 10s	remaining: 57.7s
# 148:	learn: 0.2845632	total: 10.1s	remaining: 57.5s
# 149:	learn: 0.2843521	total: 10.1s	remaining: 57.4s
# 150:	learn: 0.2843010	total: 10.2s	remaining: 57.2s
# 151:	learn: 0.2842695	total: 10.2s	remaining: 57s
# 152:	learn: 0.2839914	total: 10.3s	remaining: 56.8s
# 153:	learn: 0.2839628	total: 10.3s	remaining: 56.6s
# 154:	learn: 0.2835824	total: 10.3s	remaining: 56.4s
# 155:	learn: 0.2832303	total: 10.4s	remaining: 56.3s
# 156:	learn: 0.2829869	total: 10.4s	remaining: 56.1s
# 157:	learn: 0.2829650	total: 10.5s	remaining: 55.9s
# 158:	learn: 0.2828298	total: 10.5s	remaining: 55.7s
# 159:	learn: 0.2821232	total: 10.6s	remaining: 55.6s
# 160:	learn: 0.2820853	total: 10.6s	remaining: 55.4s
# 161:	learn: 0.2820691	total: 10.7s	remaining: 55.2s
# 162:	learn: 0.2820467	total: 10.7s	remaining: 55s
# 163:	learn: 0.2819916	total: 10.8s	remaining: 54.8s
# 164:	learn: 0.2816384	total: 10.8s	remaining: 54.6s
# 165:	learn: 0.2810215	total: 10.9s	remaining: 54.5s
# 166:	learn: 0.2805948	total: 10.9s	remaining: 54.4s
# 167:	learn: 0.2801502	total: 11s	remaining: 54.2s
# 168:	learn: 0.2799414	total: 11s	remaining: 54.1s
# 169:	learn: 0.2796819	total: 11s	remaining: 53.9s
# 170:	learn: 0.2793435	total: 11.1s	remaining: 53.7s
# 171:	learn: 0.2791231	total: 11.1s	remaining: 53.6s
# 172:	learn: 0.2791048	total: 11.2s	remaining: 53.4s
# 173:	learn: 0.2790094	total: 11.2s	remaining: 53.3s
# 174:	learn: 0.2789939	total: 11.3s	remaining: 53.1s
# 175:	learn: 0.2786228	total: 11.3s	remaining: 53s
# 176:	learn: 0.2785974	total: 11.4s	remaining: 52.8s
# 177:	learn: 0.2779902	total: 11.4s	remaining: 52.7s
# 178:	learn: 0.2774105	total: 11.5s	remaining: 52.6s
# 179:	learn: 0.2773926	total: 11.5s	remaining: 52.4s
# 180:	learn: 0.2771280	total: 11.6s	remaining: 52.3s
# 181:	learn: 0.2770988	total: 11.6s	remaining: 52.1s
# 182:	learn: 0.2768398	total: 11.6s	remaining: 52s
# 183:	learn: 0.2767855	total: 11.7s	remaining: 51.9s
# 184:	learn: 0.2767594	total: 11.7s	remaining: 51.7s
# 185:	learn: 0.2765976	total: 11.8s	remaining: 51.6s
# 186:	learn: 0.2762654	total: 11.8s	remaining: 51.4s
# 187:	learn: 0.2762362	total: 11.9s	remaining: 51.3s
# 188:	learn: 0.2761992	total: 11.9s	remaining: 51.1s
# 189:	learn: 0.2758519	total: 12s	remaining: 51s
# 190:	learn: 0.2754214	total: 12s	remaining: 50.9s
# 191:	learn: 0.2753945	total: 12.1s	remaining: 50.8s
# 192:	learn: 0.2753641	total: 12.1s	remaining: 50.6s
# 193:	learn: 0.2749488	total: 12.2s	remaining: 50.5s
# 194:	learn: 0.2747449	total: 12.2s	remaining: 50.4s
# 195:	learn: 0.2745024	total: 12.2s	remaining: 50.2s
# 196:	learn: 0.2743935	total: 12.3s	remaining: 50.1s
# 197:	learn: 0.2743734	total: 12.3s	remaining: 50s
# 198:	learn: 0.2743336	total: 12.4s	remaining: 49.8s
# 199:	learn: 0.2743129	total: 12.4s	remaining: 49.7s
# 200:	learn: 0.2742735	total: 12.5s	remaining: 49.6s
# 201:	learn: 0.2742544	total: 12.5s	remaining: 49.4s
# 202:	learn: 0.2737211	total: 12.6s	remaining: 49.3s
# 203:	learn: 0.2736929	total: 12.6s	remaining: 49.2s
# 204:	learn: 0.2734479	total: 12.7s	remaining: 49.1s
# 205:	learn: 0.2734251	total: 12.7s	remaining: 49s
# 206:	learn: 0.2730666	total: 12.7s	remaining: 48.8s
# 207:	learn: 0.2728436	total: 12.8s	remaining: 48.7s
# 208:	learn: 0.2726809	total: 12.8s	remaining: 48.6s
# 209:	learn: 0.2726572	total: 12.9s	remaining: 48.5s
# 210:	learn: 0.2724261	total: 12.9s	remaining: 48.4s
# 211:	learn: 0.2721781	total: 13s	remaining: 48.3s
# 212:	learn: 0.2718843	total: 13s	remaining: 48.1s
# 213:	learn: 0.2718555	total: 13.1s	remaining: 48s
# 214:	learn: 0.2716406	total: 13.1s	remaining: 47.9s
# 215:	learn: 0.2716122	total: 13.2s	remaining: 47.8s
# 216:	learn: 0.2715479	total: 13.2s	remaining: 47.6s
# 217:	learn: 0.2715169	total: 13.2s	remaining: 47.5s
# 218:	learn: 0.2714840	total: 13.3s	remaining: 47.4s
# 219:	learn: 0.2714553	total: 13.3s	remaining: 47.3s
# 220:	learn: 0.2714169	total: 13.4s	remaining: 47.1s
# 221:	learn: 0.2713972	total: 13.4s	remaining: 47s
# 222:	learn: 0.2713567	total: 13.5s	remaining: 46.9s
# 223:	learn: 0.2713367	total: 13.5s	remaining: 46.8s
# 224:	learn: 0.2713166	total: 13.6s	remaining: 46.7s
# 225:	learn: 0.2712881	total: 13.6s	remaining: 46.6s
# 226:	learn: 0.2712609	total: 13.6s	remaining: 46.5s
# 227:	learn: 0.2712326	total: 13.7s	remaining: 46.4s
# 228:	learn: 0.2712023	total: 13.7s	remaining: 46.2s
# 229:	learn: 0.2711644	total: 13.8s	remaining: 46.1s
# 230:	learn: 0.2711422	total: 13.8s	remaining: 46s
# 231:	learn: 0.2711150	total: 13.9s	remaining: 45.9s
# 232:	learn: 0.2708935	total: 13.9s	remaining: 45.8s
# 233:	learn: 0.2708647	total: 14s	remaining: 45.7s
# 234:	learn: 0.2707711	total: 14s	remaining: 45.6s
# 235:	learn: 0.2701997	total: 14s	remaining: 45.5s
# 236:	learn: 0.2701804	total: 14.1s	remaining: 45.3s
# 237:	learn: 0.2694157	total: 14.1s	remaining: 45.3s
# 238:	learn: 0.2693860	total: 14.2s	remaining: 45.2s
# 239:	learn: 0.2692301	total: 14.2s	remaining: 45.1s
# 240:	learn: 0.2691305	total: 14.3s	remaining: 45s
# 241:	learn: 0.2687210	total: 14.3s	remaining: 44.9s
# 242:	learn: 0.2686996	total: 14.4s	remaining: 44.8s
# 243:	learn: 0.2682214	total: 14.5s	remaining: 44.8s
# 244:	learn: 0.2679915	total: 14.5s	remaining: 44.7s
# 245:	learn: 0.2678545	total: 14.5s	remaining: 44.6s
# 246:	learn: 0.2678158	total: 14.6s	remaining: 44.5s
# 247:	learn: 0.2677958	total: 14.6s	remaining: 44.3s
# 248:	learn: 0.2673044	total: 14.7s	remaining: 44.3s
# 249:	learn: 0.2672723	total: 14.7s	remaining: 44.2s
# 250:	learn: 0.2672537	total: 14.8s	remaining: 44s
# 251:	learn: 0.2672292	total: 14.8s	remaining: 43.9s
# 252:	learn: 0.2671479	total: 14.8s	remaining: 43.8s
# 253:	learn: 0.2671274	total: 14.9s	remaining: 43.7s
# 254:	learn: 0.2671033	total: 14.9s	remaining: 43.6s
# 255:	learn: 0.2670789	total: 15s	remaining: 43.5s
# 256:	learn: 0.2670621	total: 15s	remaining: 43.4s
# 257:	learn: 0.2670317	total: 15.1s	remaining: 43.3s
# 258:	learn: 0.2669972	total: 15.1s	remaining: 43.2s
# 259:	learn: 0.2669551	total: 15.2s	remaining: 43.2s
# 260:	learn: 0.2669361	total: 15.3s	remaining: 43.2s
# 261:	learn: 0.2667911	total: 15.3s	remaining: 43.2s
# 262:	learn: 0.2663264	total: 15.4s	remaining: 43.1s
# 263:	learn: 0.2662958	total: 15.4s	remaining: 43s
# 264:	learn: 0.2659580	total: 15.5s	remaining: 43s
# 265:	learn: 0.2659341	total: 15.5s	remaining: 42.8s
# 266:	learn: 0.2657784	total: 15.6s	remaining: 42.8s
# 267:	learn: 0.2654812	total: 15.6s	remaining: 42.7s
# 268:	learn: 0.2652379	total: 15.7s	remaining: 42.6s
# 269:	learn: 0.2652187	total: 15.7s	remaining: 42.5s
# 270:	learn: 0.2652018	total: 15.8s	remaining: 42.4s
# 271:	learn: 0.2651908	total: 15.8s	remaining: 42.3s
# 272:	learn: 0.2651736	total: 15.8s	remaining: 42.2s
# 273:	learn: 0.2649201	total: 15.9s	remaining: 42.2s
# 274:	learn: 0.2645742	total: 16s	remaining: 42.2s
# 275:	learn: 0.2645428	total: 16.1s	remaining: 42.1s
# 276:	learn: 0.2645244	total: 16.1s	remaining: 42s
# 277:	learn: 0.2643536	total: 16.1s	remaining: 41.9s
# 278:	learn: 0.2643354	total: 16.2s	remaining: 41.8s
# 279:	learn: 0.2642930	total: 16.2s	remaining: 41.7s
# 280:	learn: 0.2642674	total: 16.3s	remaining: 41.6s
# 281:	learn: 0.2642451	total: 16.3s	remaining: 41.5s
# 282:	learn: 0.2642234	total: 16.4s	remaining: 41.4s
# 283:	learn: 0.2641830	total: 16.4s	remaining: 41.4s
# 284:	learn: 0.2641676	total: 16.5s	remaining: 41.3s
# 285:	learn: 0.2641480	total: 16.5s	remaining: 41.2s
# 286:	learn: 0.2641312	total: 16.5s	remaining: 41.1s
# 287:	learn: 0.2640968	total: 16.6s	remaining: 41s
# 288:	learn: 0.2640740	total: 16.6s	remaining: 40.9s
# 289:	learn: 0.2640474	total: 16.7s	remaining: 40.9s
# 290:	learn: 0.2640241	total: 16.7s	remaining: 40.8s
# 291:	learn: 0.2635042	total: 16.8s	remaining: 40.7s
# 292:	learn: 0.2634885	total: 16.8s	remaining: 40.6s
# 293:	learn: 0.2633716	total: 16.9s	remaining: 40.5s
# 294:	learn: 0.2632220	total: 16.9s	remaining: 40.4s
# 295:	learn: 0.2631944	total: 17s	remaining: 40.3s
# 296:	learn: 0.2629903	total: 17s	remaining: 40.3s
# 297:	learn: 0.2624809	total: 17.1s	remaining: 40.2s
# 298:	learn: 0.2624604	total: 17.1s	remaining: 40.2s
# 299:	learn: 0.2621912	total: 17.2s	remaining: 40.1s
# 300:	learn: 0.2621754	total: 17.2s	remaining: 40s
# 301:	learn: 0.2621181	total: 17.3s	remaining: 39.9s
# 302:	learn: 0.2621017	total: 17.3s	remaining: 39.8s
# 303:	learn: 0.2620863	total: 17.3s	remaining: 39.7s
# 304:	learn: 0.2620712	total: 17.4s	remaining: 39.6s
# 305:	learn: 0.2620504	total: 17.4s	remaining: 39.5s
# 306:	learn: 0.2620347	total: 17.5s	remaining: 39.4s
# 307:	learn: 0.2618341	total: 17.5s	remaining: 39.4s
# 308:	learn: 0.2614490	total: 17.6s	remaining: 39.3s
# 309:	learn: 0.2614291	total: 17.6s	remaining: 39.2s
# 310:	learn: 0.2612563	total: 17.7s	remaining: 39.2s
# 311:	learn: 0.2612323	total: 17.7s	remaining: 39.1s
# 312:	learn: 0.2612095	total: 17.8s	remaining: 39s
# 313:	learn: 0.2611950	total: 17.8s	remaining: 38.9s
# 314:	learn: 0.2610042	total: 17.9s	remaining: 38.8s
# 315:	learn: 0.2609694	total: 17.9s	remaining: 38.7s
# 316:	learn: 0.2608335	total: 17.9s	remaining: 38.6s
# 317:	learn: 0.2605035	total: 18s	remaining: 38.6s
# 318:	learn: 0.2600794	total: 18s	remaining: 38.5s
# 319:	learn: 0.2600559	total: 18.1s	remaining: 38.4s
# 320:	learn: 0.2600361	total: 18.1s	remaining: 38.4s
# 321:	learn: 0.2599763	total: 18.2s	remaining: 38.3s
# 322:	learn: 0.2599520	total: 18.2s	remaining: 38.2s
# 323:	learn: 0.2599332	total: 18.3s	remaining: 38.1s
# 324:	learn: 0.2595492	total: 18.3s	remaining: 38s
# 325:	learn: 0.2595307	total: 18.4s	remaining: 37.9s
# 326:	learn: 0.2594961	total: 18.4s	remaining: 37.9s
# 327:	learn: 0.2591526	total: 18.4s	remaining: 37.8s
# 328:	learn: 0.2590499	total: 18.5s	remaining: 37.7s
# 329:	learn: 0.2585551	total: 18.6s	remaining: 37.7s
# 330:	learn: 0.2585400	total: 18.6s	remaining: 37.6s
# 331:	learn: 0.2585014	total: 18.6s	remaining: 37.5s
# 332:	learn: 0.2584677	total: 18.7s	remaining: 37.4s
# 333:	learn: 0.2583182	total: 18.7s	remaining: 37.4s
# 334:	learn: 0.2583043	total: 18.8s	remaining: 37.3s
# 335:	learn: 0.2581161	total: 18.8s	remaining: 37.2s
# 336:	learn: 0.2580963	total: 18.9s	remaining: 37.1s
# 337:	learn: 0.2580691	total: 18.9s	remaining: 37.1s
# 338:	learn: 0.2579282	total: 19s	remaining: 37s
# 339:	learn: 0.2576869	total: 19s	remaining: 36.9s
# 340:	learn: 0.2576710	total: 19.1s	remaining: 36.8s
# 341:	learn: 0.2575071	total: 19.1s	remaining: 36.8s
# 342:	learn: 0.2574672	total: 19.2s	remaining: 36.7s
# 343:	learn: 0.2570847	total: 19.2s	remaining: 36.6s
# 344:	learn: 0.2570706	total: 19.2s	remaining: 36.5s
# 345:	learn: 0.2568347	total: 19.3s	remaining: 36.5s
# 346:	learn: 0.2568159	total: 19.3s	remaining: 36.4s
# 347:	learn: 0.2567942	total: 19.4s	remaining: 36.3s
# 348:	learn: 0.2567709	total: 19.4s	remaining: 36.2s
# 349:	learn: 0.2567488	total: 19.5s	remaining: 36.1s
# 350:	learn: 0.2567363	total: 19.5s	remaining: 36.1s
# 351:	learn: 0.2567138	total: 19.5s	remaining: 36s
# 352:	learn: 0.2566947	total: 19.6s	remaining: 35.9s
# 353:	learn: 0.2566763	total: 19.6s	remaining: 35.8s
# 354:	learn: 0.2566290	total: 19.7s	remaining: 35.8s
# 355:	learn: 0.2565309	total: 19.7s	remaining: 35.7s
# 356:	learn: 0.2563500	total: 19.8s	remaining: 35.6s
# 357:	learn: 0.2563070	total: 19.8s	remaining: 35.6s
# 358:	learn: 0.2562802	total: 19.9s	remaining: 35.5s
# 359:	learn: 0.2562583	total: 19.9s	remaining: 35.4s
# 360:	learn: 0.2562408	total: 20s	remaining: 35.3s
# 361:	learn: 0.2561993	total: 20s	remaining: 35.2s
# 362:	learn: 0.2560410	total: 20s	remaining: 35.2s
# 363:	learn: 0.2560255	total: 20.1s	remaining: 35.1s
# 364:	learn: 0.2560036	total: 20.1s	remaining: 35s
# 365:	learn: 0.2557957	total: 20.2s	remaining: 34.9s
# 366:	learn: 0.2556090	total: 20.2s	remaining: 34.9s
# 367:	learn: 0.2555910	total: 20.3s	remaining: 34.8s
# 368:	learn: 0.2555667	total: 20.3s	remaining: 34.7s
# 369:	learn: 0.2555304	total: 20.4s	remaining: 34.7s
# 370:	learn: 0.2554959	total: 20.4s	remaining: 34.6s
# 371:	learn: 0.2554808	total: 20.4s	remaining: 34.5s
# 372:	learn: 0.2551837	total: 20.5s	remaining: 34.4s
# 373:	learn: 0.2549263	total: 20.5s	remaining: 34.4s
# 374:	learn: 0.2549064	total: 20.6s	remaining: 34.3s
# 375:	learn: 0.2547386	total: 20.6s	remaining: 34.2s
# 376:	learn: 0.2547230	total: 20.7s	remaining: 34.1s
# 377:	learn: 0.2547103	total: 20.7s	remaining: 34.1s
# 378:	learn: 0.2543290	total: 20.8s	remaining: 34s
# 379:	learn: 0.2543137	total: 20.8s	remaining: 33.9s
# 380:	learn: 0.2542913	total: 20.8s	remaining: 33.9s
# 381:	learn: 0.2542567	total: 20.9s	remaining: 33.8s
# 382:	learn: 0.2542287	total: 20.9s	remaining: 33.7s
# 383:	learn: 0.2541647	total: 21s	remaining: 33.6s
# 384:	learn: 0.2541349	total: 21s	remaining: 33.6s
# 385:	learn: 0.2541169	total: 21.1s	remaining: 33.5s
# 386:	learn: 0.2540785	total: 21.1s	remaining: 33.4s
# 387:	learn: 0.2540475	total: 21.1s	remaining: 33.4s
# 388:	learn: 0.2540333	total: 21.2s	remaining: 33.3s
# 389:	learn: 0.2539590	total: 21.2s	remaining: 33.2s
# 390:	learn: 0.2539276	total: 21.3s	remaining: 33.2s
# 391:	learn: 0.2538605	total: 21.3s	remaining: 33.1s
# 392:	learn: 0.2538473	total: 21.4s	remaining: 33s
# 393:	learn: 0.2537789	total: 21.4s	remaining: 32.9s
# 394:	learn: 0.2537632	total: 21.5s	remaining: 32.9s
# 395:	learn: 0.2537430	total: 21.5s	remaining: 32.8s
# 396:	learn: 0.2537255	total: 21.5s	remaining: 32.7s
# 397:	learn: 0.2537040	total: 21.6s	remaining: 32.7s
# 398:	learn: 0.2536724	total: 21.6s	remaining: 32.6s
# 399:	learn: 0.2536544	total: 21.7s	remaining: 32.5s
# 400:	learn: 0.2536259	total: 21.7s	remaining: 32.4s
# 401:	learn: 0.2534854	total: 21.8s	remaining: 32.4s
# 402:	learn: 0.2534672	total: 21.8s	remaining: 32.3s
# 403:	learn: 0.2534483	total: 21.9s	remaining: 32.2s
# 404:	learn: 0.2533879	total: 21.9s	remaining: 32.2s
# 405:	learn: 0.2533700	total: 21.9s	remaining: 32.1s
# 406:	learn: 0.2533502	total: 22s	remaining: 32s
# 407:	learn: 0.2533334	total: 22s	remaining: 32s
# 408:	learn: 0.2533021	total: 22.1s	remaining: 31.9s
# 409:	learn: 0.2526232	total: 22.1s	remaining: 31.8s
# 410:	learn: 0.2526027	total: 22.2s	remaining: 31.8s
# 411:	learn: 0.2525821	total: 22.2s	remaining: 31.7s
# 412:	learn: 0.2522271	total: 22.3s	remaining: 31.6s
# 413:	learn: 0.2522078	total: 22.3s	remaining: 31.6s
# 414:	learn: 0.2521766	total: 22.3s	remaining: 31.5s
# 415:	learn: 0.2521555	total: 22.4s	remaining: 31.4s
# 416:	learn: 0.2521328	total: 22.4s	remaining: 31.4s
# 417:	learn: 0.2521153	total: 22.5s	remaining: 31.3s
# 418:	learn: 0.2520920	total: 22.5s	remaining: 31.2s
# 419:	learn: 0.2516618	total: 22.6s	remaining: 31.2s
# 420:	learn: 0.2516467	total: 22.6s	remaining: 31.1s
# 421:	learn: 0.2516305	total: 22.7s	remaining: 31s
# 422:	learn: 0.2516003	total: 22.7s	remaining: 31s
# 423:	learn: 0.2515819	total: 22.7s	remaining: 30.9s
# 424:	learn: 0.2515569	total: 22.8s	remaining: 30.8s
# 425:	learn: 0.2514358	total: 22.8s	remaining: 30.8s
# 426:	learn: 0.2514162	total: 22.9s	remaining: 30.7s
# 427:	learn: 0.2513914	total: 22.9s	remaining: 30.6s
# 428:	learn: 0.2513705	total: 23s	remaining: 30.6s
# 429:	learn: 0.2513567	total: 23s	remaining: 30.5s
# 430:	learn: 0.2511345	total: 23.1s	remaining: 30.4s
# 431:	learn: 0.2511096	total: 23.1s	remaining: 30.4s
# 432:	learn: 0.2510850	total: 23.2s	remaining: 30.3s
# 433:	learn: 0.2510679	total: 23.2s	remaining: 30.3s
# 434:	learn: 0.2508624	total: 23.2s	remaining: 30.2s
# 435:	learn: 0.2506102	total: 23.3s	remaining: 30.1s
# 436:	learn: 0.2505963	total: 23.3s	remaining: 30.1s
# 437:	learn: 0.2504316	total: 23.4s	remaining: 30s
# 438:	learn: 0.2502916	total: 23.4s	remaining: 29.9s
# 439:	learn: 0.2501636	total: 23.5s	remaining: 29.9s
# 440:	learn: 0.2499427	total: 23.5s	remaining: 29.8s
# 441:	learn: 0.2499265	total: 23.6s	remaining: 29.7s
# 442:	learn: 0.2495196	total: 23.6s	remaining: 29.7s
# 443:	learn: 0.2494940	total: 23.7s	remaining: 29.6s
# 444:	learn: 0.2494774	total: 23.7s	remaining: 29.6s
# 445:	learn: 0.2494009	total: 23.7s	remaining: 29.5s
# 446:	learn: 0.2493353	total: 23.8s	remaining: 29.4s
# 447:	learn: 0.2493171	total: 23.8s	remaining: 29.4s
# 448:	learn: 0.2493017	total: 23.9s	remaining: 29.3s
# 449:	learn: 0.2492867	total: 23.9s	remaining: 29.2s
# 450:	learn: 0.2492736	total: 24s	remaining: 29.2s
# 451:	learn: 0.2492512	total: 24s	remaining: 29.1s
# 452:	learn: 0.2492257	total: 24.1s	remaining: 29s
# 453:	learn: 0.2491269	total: 24.1s	remaining: 29s
# 454:	learn: 0.2491119	total: 24.1s	remaining: 28.9s
# 455:	learn: 0.2490807	total: 24.2s	remaining: 28.9s
# 456:	learn: 0.2490272	total: 24.2s	remaining: 28.8s
# 457:	learn: 0.2490064	total: 24.3s	remaining: 28.7s
# 458:	learn: 0.2488538	total: 24.3s	remaining: 28.7s
# 459:	learn: 0.2488340	total: 24.4s	remaining: 28.6s
# 460:	learn: 0.2487953	total: 24.4s	remaining: 28.5s
# 461:	learn: 0.2487688	total: 24.4s	remaining: 28.5s
# 462:	learn: 0.2487473	total: 24.5s	remaining: 28.4s
# 463:	learn: 0.2487091	total: 24.5s	remaining: 28.4s
# 464:	learn: 0.2486853	total: 24.6s	remaining: 28.3s
# 465:	learn: 0.2486660	total: 24.6s	remaining: 28.2s
# 466:	learn: 0.2486529	total: 24.7s	remaining: 28.2s
# 467:	learn: 0.2486287	total: 24.7s	remaining: 28.1s
# 468:	learn: 0.2486118	total: 24.8s	remaining: 28.1s
# 469:	learn: 0.2482661	total: 24.8s	remaining: 28s
# 470:	learn: 0.2482496	total: 24.9s	remaining: 27.9s
# 471:	learn: 0.2480482	total: 24.9s	remaining: 27.9s
# 472:	learn: 0.2480103	total: 25s	remaining: 27.8s
# 473:	learn: 0.2479896	total: 25s	remaining: 27.8s
# 474:	learn: 0.2479748	total: 25.1s	remaining: 27.7s
# 475:	learn: 0.2478935	total: 25.1s	remaining: 27.6s
# 476:	learn: 0.2477701	total: 25.2s	remaining: 27.6s
# 477:	learn: 0.2477501	total: 25.2s	remaining: 27.5s
# 478:	learn: 0.2477318	total: 25.2s	remaining: 27.5s
# 479:	learn: 0.2475909	total: 25.3s	remaining: 27.4s
# 480:	learn: 0.2475662	total: 25.3s	remaining: 27.3s
# 481:	learn: 0.2475520	total: 25.4s	remaining: 27.3s
# 482:	learn: 0.2475303	total: 25.4s	remaining: 27.2s
# 483:	learn: 0.2475148	total: 25.5s	remaining: 27.2s
# 484:	learn: 0.2474970	total: 25.5s	remaining: 27.1s
# 485:	learn: 0.2474836	total: 25.6s	remaining: 27s
# 486:	learn: 0.2471806	total: 25.6s	remaining: 27s
# 487:	learn: 0.2471531	total: 25.7s	remaining: 26.9s
# 488:	learn: 0.2471337	total: 25.7s	remaining: 26.9s
# 489:	learn: 0.2471083	total: 25.7s	remaining: 26.8s
# 490:	learn: 0.2470736	total: 25.8s	remaining: 26.7s
# 491:	learn: 0.2470590	total: 25.8s	remaining: 26.7s
# 492:	learn: 0.2470409	total: 25.9s	remaining: 26.6s
# 493:	learn: 0.2467773	total: 25.9s	remaining: 26.6s
# 494:	learn: 0.2467497	total: 26s	remaining: 26.5s
# 495:	learn: 0.2462118	total: 26s	remaining: 26.4s
# 496:	learn: 0.2461963	total: 26.1s	remaining: 26.4s
# 497:	learn: 0.2461700	total: 26.1s	remaining: 26.3s
# 498:	learn: 0.2454372	total: 26.2s	remaining: 26.3s
# 499:	learn: 0.2454130	total: 26.3s	remaining: 26.3s
# 500:	learn: 0.2453834	total: 26.3s	remaining: 26.2s
# 501:	learn: 0.2453701	total: 26.4s	remaining: 26.1s
# 502:	learn: 0.2453529	total: 26.4s	remaining: 26.1s
# 503:	learn: 0.2453101	total: 26.5s	remaining: 26.1s
# 504:	learn: 0.2452317	total: 26.6s	remaining: 26s
# 505:	learn: 0.2452093	total: 26.6s	remaining: 26s
# 506:	learn: 0.2451707	total: 26.7s	remaining: 25.9s
# 507:	learn: 0.2449946	total: 26.7s	remaining: 25.9s
# 508:	learn: 0.2449825	total: 26.8s	remaining: 25.8s
# 509:	learn: 0.2449564	total: 26.8s	remaining: 25.8s
# 510:	learn: 0.2449344	total: 26.9s	remaining: 25.7s
# 511:	learn: 0.2449195	total: 27s	remaining: 25.7s
# 512:	learn: 0.2448880	total: 27s	remaining: 25.7s
# 513:	learn: 0.2448673	total: 27.1s	remaining: 25.6s
# 514:	learn: 0.2448425	total: 27.1s	remaining: 25.6s
# 515:	learn: 0.2448093	total: 27.2s	remaining: 25.5s
# 516:	learn: 0.2447978	total: 27.3s	remaining: 25.5s
# 517:	learn: 0.2447720	total: 27.3s	remaining: 25.4s
# 518:	learn: 0.2447592	total: 27.4s	remaining: 25.4s
# 519:	learn: 0.2447412	total: 27.4s	remaining: 25.3s
# 520:	learn: 0.2446164	total: 27.5s	remaining: 25.3s
# 521:	learn: 0.2446024	total: 27.6s	remaining: 25.3s
# 522:	learn: 0.2445728	total: 27.7s	remaining: 25.2s
# 523:	learn: 0.2445540	total: 27.7s	remaining: 25.2s
# 524:	learn: 0.2445392	total: 27.8s	remaining: 25.2s
# 525:	learn: 0.2445246	total: 27.9s	remaining: 25.1s
# 526:	learn: 0.2445058	total: 28s	remaining: 25.1s
# 527:	learn: 0.2444930	total: 28s	remaining: 25.1s
# 528:	learn: 0.2444745	total: 28.1s	remaining: 25s
# 529:	learn: 0.2443077	total: 28.2s	remaining: 25s
# 530:	learn: 0.2440882	total: 28.2s	remaining: 24.9s
# 531:	learn: 0.2440758	total: 28.3s	remaining: 24.9s
# 532:	learn: 0.2438150	total: 28.3s	remaining: 24.8s
# 533:	learn: 0.2436775	total: 28.4s	remaining: 24.8s
# 534:	learn: 0.2436507	total: 28.4s	remaining: 24.7s
# 535:	learn: 0.2436242	total: 28.5s	remaining: 24.6s
# 536:	learn: 0.2433923	total: 28.5s	remaining: 24.6s
# 537:	learn: 0.2432142	total: 28.5s	remaining: 24.5s
# 538:	learn: 0.2431946	total: 28.6s	remaining: 24.5s
# 539:	learn: 0.2431449	total: 28.6s	remaining: 24.4s
# 540:	learn: 0.2431257	total: 28.7s	remaining: 24.3s
# 541:	learn: 0.2431110	total: 28.7s	remaining: 24.3s
# 542:	learn: 0.2428986	total: 28.8s	remaining: 24.2s
# 543:	learn: 0.2428850	total: 28.8s	remaining: 24.2s
# 544:	learn: 0.2428687	total: 28.9s	remaining: 24.1s
# 545:	learn: 0.2427911	total: 28.9s	remaining: 24.1s
# 546:	learn: 0.2427681	total: 29s	remaining: 24s
# 547:	learn: 0.2427536	total: 29s	remaining: 23.9s
# 548:	learn: 0.2425583	total: 29.1s	remaining: 23.9s
# 549:	learn: 0.2425419	total: 29.1s	remaining: 23.8s
# 550:	learn: 0.2425209	total: 29.2s	remaining: 23.8s
# 551:	learn: 0.2424966	total: 29.2s	remaining: 23.7s
# 552:	learn: 0.2424731	total: 29.3s	remaining: 23.6s
# 553:	learn: 0.2422782	total: 29.3s	remaining: 23.6s
# 554:	learn: 0.2422405	total: 29.4s	remaining: 23.5s
# 555:	learn: 0.2422243	total: 29.4s	remaining: 23.5s
# 556:	learn: 0.2422100	total: 29.4s	remaining: 23.4s
# 557:	learn: 0.2421779	total: 29.5s	remaining: 23.4s
# 558:	learn: 0.2421559	total: 29.5s	remaining: 23.3s
# 559:	learn: 0.2421411	total: 29.6s	remaining: 23.2s
# 560:	learn: 0.2420342	total: 29.6s	remaining: 23.2s
# 561:	learn: 0.2420131	total: 29.7s	remaining: 23.1s
# 562:	learn: 0.2419875	total: 29.7s	remaining: 23.1s
# 563:	learn: 0.2417377	total: 29.8s	remaining: 23s
# 564:	learn: 0.2417217	total: 29.8s	remaining: 22.9s
# 565:	learn: 0.2417043	total: 29.8s	remaining: 22.9s
# 566:	learn: 0.2416872	total: 29.9s	remaining: 22.8s
# 567:	learn: 0.2416299	total: 29.9s	remaining: 22.8s
# 568:	learn: 0.2416148	total: 30s	remaining: 22.7s
# 569:	learn: 0.2416011	total: 30s	remaining: 22.6s
# 570:	learn: 0.2415488	total: 30.1s	remaining: 22.6s
# 571:	learn: 0.2413284	total: 30.1s	remaining: 22.5s
# 572:	learn: 0.2412883	total: 30.1s	remaining: 22.5s
# 573:	learn: 0.2412750	total: 30.2s	remaining: 22.4s
# 574:	learn: 0.2410927	total: 30.2s	remaining: 22.3s
# 575:	learn: 0.2409632	total: 30.3s	remaining: 22.3s
# 576:	learn: 0.2409190	total: 30.3s	remaining: 22.2s
# 577:	learn: 0.2408942	total: 30.4s	remaining: 22.2s
# 578:	learn: 0.2408816	total: 30.4s	remaining: 22.1s
# 579:	learn: 0.2405854	total: 30.5s	remaining: 22.1s
# 580:	learn: 0.2405693	total: 30.5s	remaining: 22s
# 581:	learn: 0.2405521	total: 30.6s	remaining: 21.9s
# 582:	learn: 0.2403108	total: 30.6s	remaining: 21.9s
# 583:	learn: 0.2402880	total: 30.6s	remaining: 21.8s
# 584:	learn: 0.2402679	total: 30.7s	remaining: 21.8s
# 585:	learn: 0.2402511	total: 30.7s	remaining: 21.7s
# 586:	learn: 0.2402281	total: 30.8s	remaining: 21.7s
# 587:	learn: 0.2402139	total: 30.8s	remaining: 21.6s
# 588:	learn: 0.2401909	total: 30.9s	remaining: 21.5s
# 589:	learn: 0.2401760	total: 30.9s	remaining: 21.5s
# 590:	learn: 0.2401581	total: 31s	remaining: 21.4s
# 591:	learn: 0.2398538	total: 31s	remaining: 21.4s
# 592:	learn: 0.2398321	total: 31s	remaining: 21.3s
# 593:	learn: 0.2397730	total: 31.1s	remaining: 21.3s
# 594:	learn: 0.2397372	total: 31.1s	remaining: 21.2s
# 595:	learn: 0.2397163	total: 31.2s	remaining: 21.1s
# 596:	learn: 0.2395918	total: 31.2s	remaining: 21.1s
# 597:	learn: 0.2395761	total: 31.3s	remaining: 21s
# 598:	learn: 0.2395627	total: 31.3s	remaining: 21s
# 599:	learn: 0.2395408	total: 31.4s	remaining: 20.9s
# 600:	learn: 0.2395281	total: 31.4s	remaining: 20.8s
# 601:	learn: 0.2395123	total: 31.4s	remaining: 20.8s
# 602:	learn: 0.2394921	total: 31.5s	remaining: 20.7s
# 603:	learn: 0.2394533	total: 31.5s	remaining: 20.7s
# 604:	learn: 0.2394389	total: 31.6s	remaining: 20.6s
# 605:	learn: 0.2390782	total: 31.6s	remaining: 20.6s
# 606:	learn: 0.2390357	total: 31.7s	remaining: 20.5s
# 607:	learn: 0.2390190	total: 31.7s	remaining: 20.5s
# 608:	learn: 0.2389104	total: 31.8s	remaining: 20.4s
# 609:	learn: 0.2388726	total: 31.8s	remaining: 20.3s
# 610:	learn: 0.2388561	total: 31.9s	remaining: 20.3s
# 611:	learn: 0.2386436	total: 31.9s	remaining: 20.2s
# 612:	learn: 0.2385656	total: 32s	remaining: 20.2s
# 613:	learn: 0.2384476	total: 32s	remaining: 20.1s
# 614:	learn: 0.2384350	total: 32.1s	remaining: 20.1s
# 615:	learn: 0.2384220	total: 32.1s	remaining: 20s
# 616:	learn: 0.2384030	total: 32.1s	remaining: 19.9s
# 617:	learn: 0.2383777	total: 32.2s	remaining: 19.9s
# 618:	learn: 0.2383652	total: 32.2s	remaining: 19.8s
# 619:	learn: 0.2383031	total: 32.3s	remaining: 19.8s
# 620:	learn: 0.2382911	total: 32.3s	remaining: 19.7s
# 621:	learn: 0.2382756	total: 32.4s	remaining: 19.7s
# 622:	learn: 0.2375573	total: 32.4s	remaining: 19.6s
# 623:	learn: 0.2375428	total: 32.5s	remaining: 19.6s
# 624:	learn: 0.2375236	total: 32.5s	remaining: 19.5s
# 625:	learn: 0.2370582	total: 32.6s	remaining: 19.5s
# 626:	learn: 0.2370437	total: 32.6s	remaining: 19.4s
# 627:	learn: 0.2369780	total: 32.7s	remaining: 19.3s
# 628:	learn: 0.2369571	total: 32.7s	remaining: 19.3s
# 629:	learn: 0.2369356	total: 32.7s	remaining: 19.2s
# 630:	learn: 0.2369211	total: 32.8s	remaining: 19.2s
# 631:	learn: 0.2368845	total: 32.8s	remaining: 19.1s
# 632:	learn: 0.2368667	total: 32.9s	remaining: 19.1s
# 633:	learn: 0.2368461	total: 32.9s	remaining: 19s
# 634:	learn: 0.2368300	total: 33s	remaining: 19s
# 635:	learn: 0.2368089	total: 33s	remaining: 18.9s
# 636:	learn: 0.2367928	total: 33.1s	remaining: 18.8s
# 637:	learn: 0.2367693	total: 33.1s	remaining: 18.8s
# 638:	learn: 0.2367552	total: 33.2s	remaining: 18.7s
# 639:	learn: 0.2366173	total: 33.2s	remaining: 18.7s
# 640:	learn: 0.2366015	total: 33.2s	remaining: 18.6s
# 641:	learn: 0.2365808	total: 33.3s	remaining: 18.6s
# 642:	learn: 0.2365601	total: 33.3s	remaining: 18.5s
# 643:	learn: 0.2365486	total: 33.4s	remaining: 18.5s
# 644:	learn: 0.2364396	total: 33.4s	remaining: 18.4s
# 645:	learn: 0.2364235	total: 33.5s	remaining: 18.3s
# 646:	learn: 0.2362727	total: 33.5s	remaining: 18.3s
# 647:	learn: 0.2362588	total: 33.6s	remaining: 18.2s
# 648:	learn: 0.2362438	total: 33.6s	remaining: 18.2s
# 649:	learn: 0.2362308	total: 33.7s	remaining: 18.1s
# 650:	learn: 0.2362041	total: 33.7s	remaining: 18.1s
# 651:	learn: 0.2361909	total: 33.7s	remaining: 18s
# 652:	learn: 0.2360267	total: 33.8s	remaining: 18s
# 653:	learn: 0.2360128	total: 33.8s	remaining: 17.9s
# 654:	learn: 0.2360000	total: 33.9s	remaining: 17.8s
# 655:	learn: 0.2359791	total: 33.9s	remaining: 17.8s
# 656:	learn: 0.2359598	total: 34s	remaining: 17.7s
# 657:	learn: 0.2357505	total: 34s	remaining: 17.7s
# 658:	learn: 0.2356734	total: 34s	remaining: 17.6s
# 659:	learn: 0.2356548	total: 34.1s	remaining: 17.6s
# 660:	learn: 0.2355068	total: 34.1s	remaining: 17.5s
# 661:	learn: 0.2353879	total: 34.2s	remaining: 17.4s
# 662:	learn: 0.2353649	total: 34.2s	remaining: 17.4s
# 663:	learn: 0.2353517	total: 34.3s	remaining: 17.3s
# 664:	learn: 0.2352680	total: 34.3s	remaining: 17.3s
# 665:	learn: 0.2352540	total: 34.4s	remaining: 17.2s
# 666:	learn: 0.2352357	total: 34.4s	remaining: 17.2s
# 667:	learn: 0.2352163	total: 34.4s	remaining: 17.1s
# 668:	learn: 0.2350985	total: 34.5s	remaining: 17.1s
# 669:	learn: 0.2350846	total: 34.5s	remaining: 17s
# 670:	learn: 0.2350611	total: 34.6s	remaining: 17s
# 671:	learn: 0.2350401	total: 34.6s	remaining: 16.9s
# 672:	learn: 0.2350244	total: 34.7s	remaining: 16.8s
# 673:	learn: 0.2350076	total: 34.7s	remaining: 16.8s
# 674:	learn: 0.2347014	total: 34.8s	remaining: 16.7s
# 675:	learn: 0.2343156	total: 34.8s	remaining: 16.7s
# 676:	learn: 0.2343028	total: 34.9s	remaining: 16.6s
# 677:	learn: 0.2342883	total: 34.9s	remaining: 16.6s
# 678:	learn: 0.2342669	total: 35s	remaining: 16.5s
# 679:	learn: 0.2341482	total: 35s	remaining: 16.5s
# 680:	learn: 0.2340180	total: 35.1s	remaining: 16.4s
# 681:	learn: 0.2340013	total: 35.1s	remaining: 16.4s
# 682:	learn: 0.2339627	total: 35.1s	remaining: 16.3s
# 683:	learn: 0.2339418	total: 35.2s	remaining: 16.3s
# 684:	learn: 0.2339291	total: 35.2s	remaining: 16.2s
# 685:	learn: 0.2339043	total: 35.3s	remaining: 16.1s
# 686:	learn: 0.2338903	total: 35.3s	remaining: 16.1s
# 687:	learn: 0.2338770	total: 35.4s	remaining: 16s
# 688:	learn: 0.2336973	total: 35.4s	remaining: 16s
# 689:	learn: 0.2336829	total: 35.4s	remaining: 15.9s
# 690:	learn: 0.2335627	total: 35.5s	remaining: 15.9s
# 691:	learn: 0.2334268	total: 35.5s	remaining: 15.8s
# 692:	learn: 0.2334134	total: 35.6s	remaining: 15.8s
# 693:	learn: 0.2333979	total: 35.6s	remaining: 15.7s
# 694:	learn: 0.2333747	total: 35.7s	remaining: 15.7s
# 695:	learn: 0.2333455	total: 35.7s	remaining: 15.6s
# 696:	learn: 0.2333322	total: 35.8s	remaining: 15.6s
# 697:	learn: 0.2333181	total: 35.8s	remaining: 15.5s
# 698:	learn: 0.2333045	total: 35.9s	remaining: 15.4s
# 699:	learn: 0.2332892	total: 35.9s	remaining: 15.4s
# 700:	learn: 0.2332769	total: 36s	remaining: 15.3s
# 701:	learn: 0.2328433	total: 36s	remaining: 15.3s
# 702:	learn: 0.2328272	total: 36.1s	remaining: 15.2s
# 703:	learn: 0.2327973	total: 36.1s	remaining: 15.2s
# 704:	learn: 0.2327775	total: 36.2s	remaining: 15.1s
# 705:	learn: 0.2326628	total: 36.2s	remaining: 15.1s
# 706:	learn: 0.2326499	total: 36.2s	remaining: 15s
# 707:	learn: 0.2324486	total: 36.3s	remaining: 15s
# 708:	learn: 0.2324311	total: 36.3s	remaining: 14.9s
# 709:	learn: 0.2324185	total: 36.4s	remaining: 14.9s
# 710:	learn: 0.2324050	total: 36.4s	remaining: 14.8s
# 711:	learn: 0.2323827	total: 36.5s	remaining: 14.8s
# 712:	learn: 0.2323659	total: 36.5s	remaining: 14.7s
# 713:	learn: 0.2323522	total: 36.6s	remaining: 14.6s
# 714:	learn: 0.2323374	total: 36.6s	remaining: 14.6s
# 715:	learn: 0.2319968	total: 36.7s	remaining: 14.5s
# 716:	learn: 0.2319512	total: 36.7s	remaining: 14.5s
# 717:	learn: 0.2319372	total: 36.7s	remaining: 14.4s
# 718:	learn: 0.2316996	total: 36.8s	remaining: 14.4s
# 719:	learn: 0.2316873	total: 36.8s	remaining: 14.3s
# 720:	learn: 0.2316702	total: 36.9s	remaining: 14.3s
# 721:	learn: 0.2315796	total: 36.9s	remaining: 14.2s
# 722:	learn: 0.2315603	total: 37s	remaining: 14.2s
# 723:	learn: 0.2311938	total: 37s	remaining: 14.1s
# 724:	learn: 0.2311241	total: 37.1s	remaining: 14.1s
# 725:	learn: 0.2311101	total: 37.2s	remaining: 14s
# 726:	learn: 0.2310903	total: 37.3s	remaining: 14s
# 727:	learn: 0.2310733	total: 37.3s	remaining: 13.9s
# 728:	learn: 0.2310544	total: 37.3s	remaining: 13.9s
# 729:	learn: 0.2310414	total: 37.4s	remaining: 13.8s
# 730:	learn: 0.2308305	total: 37.4s	remaining: 13.8s
# 731:	learn: 0.2308163	total: 37.5s	remaining: 13.7s
# 732:	learn: 0.2305846	total: 37.5s	remaining: 13.7s
# 733:	learn: 0.2305722	total: 37.6s	remaining: 13.6s
# 734:	learn: 0.2305580	total: 37.6s	remaining: 13.6s
# 735:	learn: 0.2304792	total: 37.7s	remaining: 13.5s
# 736:	learn: 0.2304660	total: 37.7s	remaining: 13.5s
# 737:	learn: 0.2302475	total: 37.8s	remaining: 13.4s
# 738:	learn: 0.2300995	total: 37.9s	remaining: 13.4s
# 739:	learn: 0.2300855	total: 37.9s	remaining: 13.3s
# 740:	learn: 0.2300675	total: 38s	remaining: 13.3s
# 741:	learn: 0.2300554	total: 38s	remaining: 13.2s
# 742:	learn: 0.2300436	total: 38.1s	remaining: 13.2s
# 743:	learn: 0.2300268	total: 38.1s	remaining: 13.1s
# 744:	learn: 0.2300146	total: 38.1s	remaining: 13.1s
# 745:	learn: 0.2299985	total: 38.2s	remaining: 13s
# 746:	learn: 0.2299846	total: 38.2s	remaining: 12.9s
# 747:	learn: 0.2299704	total: 38.3s	remaining: 12.9s
# 748:	learn: 0.2299483	total: 38.3s	remaining: 12.8s
# 749:	learn: 0.2299322	total: 38.4s	remaining: 12.8s
# 750:	learn: 0.2299199	total: 38.4s	remaining: 12.7s
# 751:	learn: 0.2294127	total: 38.5s	remaining: 12.7s
# 752:	learn: 0.2293991	total: 38.5s	remaining: 12.6s
# 753:	learn: 0.2293808	total: 38.6s	remaining: 12.6s
# 754:	learn: 0.2293640	total: 38.6s	remaining: 12.5s
# 755:	learn: 0.2292565	total: 38.7s	remaining: 12.5s
# 756:	learn: 0.2292343	total: 38.7s	remaining: 12.4s
# 757:	learn: 0.2291877	total: 38.7s	remaining: 12.4s
# 758:	learn: 0.2291636	total: 38.8s	remaining: 12.3s
# 759:	learn: 0.2291467	total: 38.8s	remaining: 12.3s
# 760:	learn: 0.2291315	total: 38.9s	remaining: 12.2s
# 761:	learn: 0.2290846	total: 38.9s	remaining: 12.2s
# 762:	learn: 0.2290641	total: 39s	remaining: 12.1s
# 763:	learn: 0.2290486	total: 39s	remaining: 12s
# 764:	learn: 0.2290321	total: 39.1s	remaining: 12s
# 765:	learn: 0.2290207	total: 39.1s	remaining: 11.9s
# 766:	learn: 0.2290076	total: 39.1s	remaining: 11.9s
# 767:	learn: 0.2289895	total: 39.2s	remaining: 11.8s
# 768:	learn: 0.2289783	total: 39.2s	remaining: 11.8s
# 769:	learn: 0.2289665	total: 39.3s	remaining: 11.7s
# 770:	learn: 0.2287208	total: 39.3s	remaining: 11.7s
# 771:	learn: 0.2287039	total: 39.4s	remaining: 11.6s
# 772:	learn: 0.2286879	total: 39.4s	remaining: 11.6s
# 773:	learn: 0.2286598	total: 39.5s	remaining: 11.5s
# 774:	learn: 0.2285282	total: 39.5s	remaining: 11.5s
# 775:	learn: 0.2285142	total: 39.6s	remaining: 11.4s
# 776:	learn: 0.2285032	total: 39.6s	remaining: 11.4s
# 777:	learn: 0.2284247	total: 39.6s	remaining: 11.3s
# 778:	learn: 0.2284033	total: 39.7s	remaining: 11.3s
# 779:	learn: 0.2283700	total: 39.7s	remaining: 11.2s
# 780:	learn: 0.2283577	total: 39.8s	remaining: 11.2s
# 781:	learn: 0.2283125	total: 39.8s	remaining: 11.1s
# 782:	learn: 0.2282989	total: 39.9s	remaining: 11.1s
# 783:	learn: 0.2282815	total: 39.9s	remaining: 11s
# 784:	learn: 0.2282655	total: 40s	remaining: 10.9s
# 785:	learn: 0.2282475	total: 40s	remaining: 10.9s
# 786:	learn: 0.2282266	total: 40.1s	remaining: 10.8s
# 787:	learn: 0.2282012	total: 40.1s	remaining: 10.8s
# 788:	learn: 0.2281776	total: 40.1s	remaining: 10.7s
# 789:	learn: 0.2281652	total: 40.2s	remaining: 10.7s
# 790:	learn: 0.2281474	total: 40.2s	remaining: 10.6s
# 791:	learn: 0.2281228	total: 40.3s	remaining: 10.6s
# 792:	learn: 0.2279603	total: 40.3s	remaining: 10.5s
# 793:	learn: 0.2279385	total: 40.4s	remaining: 10.5s
# 794:	learn: 0.2279093	total: 40.4s	remaining: 10.4s
# 795:	learn: 0.2278877	total: 40.5s	remaining: 10.4s
# 796:	learn: 0.2277936	total: 40.5s	remaining: 10.3s
# 797:	learn: 0.2277302	total: 40.5s	remaining: 10.3s
# 798:	learn: 0.2277154	total: 40.6s	remaining: 10.2s
# 799:	learn: 0.2275709	total: 40.6s	remaining: 10.2s
# 800:	learn: 0.2275532	total: 40.7s	remaining: 10.1s
# 801:	learn: 0.2275353	total: 40.7s	remaining: 10.1s
# 802:	learn: 0.2275122	total: 40.8s	remaining: 10s
# 803:	learn: 0.2273991	total: 40.8s	remaining: 9.95s
# 804:	learn: 0.2272010	total: 40.9s	remaining: 9.9s
# 805:	learn: 0.2271880	total: 40.9s	remaining: 9.85s
# 806:	learn: 0.2271748	total: 41s	remaining: 9.79s
# 807:	learn: 0.2271521	total: 41s	remaining: 9.74s
# 808:	learn: 0.2271369	total: 41s	remaining: 9.69s
# 809:	learn: 0.2271245	total: 41.1s	remaining: 9.64s
# 810:	learn: 0.2271106	total: 41.1s	remaining: 9.59s
# 811:	learn: 0.2270875	total: 41.2s	remaining: 9.53s
# 812:	learn: 0.2270714	total: 41.2s	remaining: 9.48s
# 813:	learn: 0.2270450	total: 41.3s	remaining: 9.43s
# 814:	learn: 0.2270159	total: 41.3s	remaining: 9.38s
# 815:	learn: 0.2269968	total: 41.4s	remaining: 9.32s
# 816:	learn: 0.2269794	total: 41.4s	remaining: 9.27s
# 817:	learn: 0.2269663	total: 41.4s	remaining: 9.22s
# 818:	learn: 0.2269258	total: 41.5s	remaining: 9.17s
# 819:	learn: 0.2267691	total: 41.5s	remaining: 9.12s
# 820:	learn: 0.2267532	total: 41.6s	remaining: 9.06s
# 821:	learn: 0.2267396	total: 41.6s	remaining: 9.01s
# 822:	learn: 0.2267260	total: 41.7s	remaining: 8.96s
# 823:	learn: 0.2265770	total: 41.7s	remaining: 8.91s
# 824:	learn: 0.2265652	total: 41.8s	remaining: 8.86s
# 825:	learn: 0.2261781	total: 41.8s	remaining: 8.8s
# 826:	learn: 0.2261613	total: 41.8s	remaining: 8.75s
# 827:	learn: 0.2259183	total: 41.9s	remaining: 8.7s
# 828:	learn: 0.2259052	total: 41.9s	remaining: 8.65s
# 829:	learn: 0.2258907	total: 42s	remaining: 8.6s
# 830:	learn: 0.2257572	total: 42s	remaining: 8.55s
# 831:	learn: 0.2257414	total: 42.1s	remaining: 8.49s
# 832:	learn: 0.2257147	total: 42.1s	remaining: 8.44s
# 833:	learn: 0.2257029	total: 42.2s	remaining: 8.39s
# 834:	learn: 0.2256586	total: 42.2s	remaining: 8.34s
# 835:	learn: 0.2254700	total: 42.2s	remaining: 8.29s
# 836:	learn: 0.2254593	total: 42.3s	remaining: 8.23s
# 837:	learn: 0.2254466	total: 42.3s	remaining: 8.18s
# 838:	learn: 0.2254336	total: 42.4s	remaining: 8.13s
# 839:	learn: 0.2254147	total: 42.4s	remaining: 8.08s
# 840:	learn: 0.2253981	total: 42.5s	remaining: 8.03s
# 841:	learn: 0.2253194	total: 42.5s	remaining: 7.98s
# 842:	learn: 0.2253062	total: 42.6s	remaining: 7.92s
# 843:	learn: 0.2252489	total: 42.6s	remaining: 7.87s
# 844:	learn: 0.2252313	total: 42.6s	remaining: 7.82s
# 845:	learn: 0.2252178	total: 42.7s	remaining: 7.77s
# 846:	learn: 0.2250200	total: 42.7s	remaining: 7.72s
# 847:	learn: 0.2248495	total: 42.8s	remaining: 7.67s
# 848:	learn: 0.2247011	total: 42.8s	remaining: 7.62s
# 849:	learn: 0.2246739	total: 42.9s	remaining: 7.57s
# 850:	learn: 0.2246523	total: 42.9s	remaining: 7.51s
# 851:	learn: 0.2246323	total: 43s	remaining: 7.46s
# 852:	learn: 0.2246137	total: 43s	remaining: 7.41s
# 853:	learn: 0.2246013	total: 43s	remaining: 7.36s
# 854:	learn: 0.2244599	total: 43.1s	remaining: 7.31s
# 855:	learn: 0.2244438	total: 43.1s	remaining: 7.26s
# 856:	learn: 0.2244161	total: 43.2s	remaining: 7.21s
# 857:	learn: 0.2243938	total: 43.2s	remaining: 7.15s
# 858:	learn: 0.2240459	total: 43.3s	remaining: 7.1s
# 859:	learn: 0.2240174	total: 43.3s	remaining: 7.05s
# 860:	learn: 0.2240012	total: 43.4s	remaining: 7s
# 861:	learn: 0.2239824	total: 43.4s	remaining: 6.95s
# 862:	learn: 0.2239602	total: 43.5s	remaining: 6.9s
# 863:	learn: 0.2239402	total: 43.5s	remaining: 6.85s
# 864:	learn: 0.2239289	total: 43.5s	remaining: 6.79s
# 865:	learn: 0.2239137	total: 43.6s	remaining: 6.74s
# 866:	learn: 0.2238598	total: 43.6s	remaining: 6.69s
# 867:	learn: 0.2238192	total: 43.7s	remaining: 6.64s
# 868:	learn: 0.2238082	total: 43.7s	remaining: 6.59s
# 869:	learn: 0.2236668	total: 43.8s	remaining: 6.54s
# 870:	learn: 0.2236558	total: 43.8s	remaining: 6.49s
# 871:	learn: 0.2236074	total: 43.8s	remaining: 6.44s
# 872:	learn: 0.2235875	total: 43.9s	remaining: 6.38s
# 873:	learn: 0.2235677	total: 43.9s	remaining: 6.33s
# 874:	learn: 0.2234167	total: 44s	remaining: 6.28s
# 875:	learn: 0.2234051	total: 44s	remaining: 6.23s
# 876:	learn: 0.2233914	total: 44.1s	remaining: 6.18s
# 877:	learn: 0.2229000	total: 44.1s	remaining: 6.13s
# 878:	learn: 0.2228801	total: 44.2s	remaining: 6.08s
# 879:	learn: 0.2228667	total: 44.2s	remaining: 6.03s
# 880:	learn: 0.2227336	total: 44.3s	remaining: 5.98s
# 881:	learn: 0.2226877	total: 44.3s	remaining: 5.93s
# 882:	learn: 0.2226710	total: 44.3s	remaining: 5.88s
# 883:	learn: 0.2224376	total: 44.4s	remaining: 5.83s
# 884:	learn: 0.2224234	total: 44.4s	remaining: 5.78s
# 885:	learn: 0.2224047	total: 44.5s	remaining: 5.72s
# 886:	learn: 0.2223894	total: 44.5s	remaining: 5.67s
# 887:	learn: 0.2223639	total: 44.6s	remaining: 5.62s
# 888:	learn: 0.2223528	total: 44.6s	remaining: 5.57s
# 889:	learn: 0.2219958	total: 44.7s	remaining: 5.52s
# 890:	learn: 0.2218686	total: 44.7s	remaining: 5.47s
# 891:	learn: 0.2218583	total: 44.8s	remaining: 5.42s
# 892:	learn: 0.2218201	total: 44.8s	remaining: 5.37s
# 893:	learn: 0.2218059	total: 44.9s	remaining: 5.32s
# 894:	learn: 0.2216394	total: 44.9s	remaining: 5.27s
# 895:	learn: 0.2216251	total: 45s	remaining: 5.22s
# 896:	learn: 0.2215764	total: 45s	remaining: 5.17s
# 897:	learn: 0.2215605	total: 45s	remaining: 5.12s
# 898:	learn: 0.2215487	total: 45.1s	remaining: 5.07s
# 899:	learn: 0.2215367	total: 45.1s	remaining: 5.01s
# 900:	learn: 0.2215221	total: 45.2s	remaining: 4.96s
# 901:	learn: 0.2213773	total: 45.2s	remaining: 4.91s
# 902:	learn: 0.2213285	total: 45.3s	remaining: 4.86s
# 903:	learn: 0.2213144	total: 45.3s	remaining: 4.81s
# 904:	learn: 0.2213007	total: 45.4s	remaining: 4.76s
# 905:	learn: 0.2212778	total: 45.4s	remaining: 4.71s
# 906:	learn: 0.2212537	total: 45.5s	remaining: 4.66s
# 907:	learn: 0.2212388	total: 45.5s	remaining: 4.61s
# 908:	learn: 0.2212262	total: 45.5s	remaining: 4.56s
# 909:	learn: 0.2212076	total: 45.6s	remaining: 4.51s
# 910:	learn: 0.2211957	total: 45.6s	remaining: 4.46s
# 911:	learn: 0.2211831	total: 45.7s	remaining: 4.41s
# 912:	learn: 0.2211627	total: 45.7s	remaining: 4.36s
# 913:	learn: 0.2211469	total: 45.8s	remaining: 4.3s
# 914:	learn: 0.2210080	total: 45.8s	remaining: 4.25s
# 915:	learn: 0.2209296	total: 45.9s	remaining: 4.2s
# 916:	learn: 0.2209161	total: 45.9s	remaining: 4.15s
# 917:	learn: 0.2209023	total: 45.9s	remaining: 4.1s
# 918:	learn: 0.2208861	total: 46s	remaining: 4.05s
# 919:	learn: 0.2207017	total: 46s	remaining: 4s
# 920:	learn: 0.2204275	total: 46.1s	remaining: 3.95s
# 921:	learn: 0.2204061	total: 46.1s	remaining: 3.9s
# 922:	learn: 0.2203893	total: 46.2s	remaining: 3.85s
# 923:	learn: 0.2203501	total: 46.2s	remaining: 3.8s
# 924:	learn: 0.2203326	total: 46.3s	remaining: 3.75s
# 925:	learn: 0.2203195	total: 46.3s	remaining: 3.7s
# 926:	learn: 0.2202979	total: 46.3s	remaining: 3.65s
# 927:	learn: 0.2202872	total: 46.4s	remaining: 3.6s
# 928:	learn: 0.2202671	total: 46.4s	remaining: 3.55s
# 929:	learn: 0.2202560	total: 46.5s	remaining: 3.5s
# 930:	learn: 0.2202445	total: 46.5s	remaining: 3.45s
# 931:	learn: 0.2200506	total: 46.6s	remaining: 3.4s
# 932:	learn: 0.2200397	total: 46.6s	remaining: 3.35s
# 933:	learn: 0.2200257	total: 46.7s	remaining: 3.3s
# 934:	learn: 0.2200086	total: 46.7s	remaining: 3.25s
# 935:	learn: 0.2199933	total: 46.7s	remaining: 3.2s
# 936:	learn: 0.2199221	total: 46.8s	remaining: 3.15s
# 937:	learn: 0.2199093	total: 46.8s	remaining: 3.1s
# 938:	learn: 0.2198934	total: 46.9s	remaining: 3.04s
# 939:	learn: 0.2198813	total: 46.9s	remaining: 2.99s
# 940:	learn: 0.2198653	total: 47s	remaining: 2.94s
# 941:	learn: 0.2198505	total: 47s	remaining: 2.89s
# 942:	learn: 0.2198321	total: 47.1s	remaining: 2.84s
# 943:	learn: 0.2198188	total: 47.1s	remaining: 2.79s
# 944:	learn: 0.2198030	total: 47.1s	remaining: 2.74s
# 945:	learn: 0.2197852	total: 47.2s	remaining: 2.69s
# 946:	learn: 0.2197051	total: 47.2s	remaining: 2.64s
# 947:	learn: 0.2193445	total: 47.3s	remaining: 2.59s
# 948:	learn: 0.2193284	total: 47.3s	remaining: 2.54s
# 949:	learn: 0.2193161	total: 47.4s	remaining: 2.49s
# 950:	learn: 0.2192970	total: 47.4s	remaining: 2.44s
# 951:	learn: 0.2190435	total: 47.5s	remaining: 2.39s
# 952:	learn: 0.2190308	total: 47.5s	remaining: 2.34s
# 953:	learn: 0.2190124	total: 47.6s	remaining: 2.29s
# 954:	learn: 0.2188724	total: 47.6s	remaining: 2.24s
# 955:	learn: 0.2188607	total: 47.7s	remaining: 2.19s
# 956:	learn: 0.2187547	total: 47.7s	remaining: 2.14s
# 957:	learn: 0.2187347	total: 47.8s	remaining: 2.09s
# 958:	learn: 0.2187237	total: 47.8s	remaining: 2.04s
# 959:	learn: 0.2187067	total: 47.9s	remaining: 1.99s
# 960:	learn: 0.2186906	total: 47.9s	remaining: 1.94s
# 961:	learn: 0.2186594	total: 48s	remaining: 1.89s
# 962:	learn: 0.2186485	total: 48.1s	remaining: 1.85s
# 963:	learn: 0.2186321	total: 48.1s	remaining: 1.8s
# 964:	learn: 0.2186190	total: 48.2s	remaining: 1.75s
# 965:	learn: 0.2186035	total: 48.2s	remaining: 1.7s
# 966:	learn: 0.2185081	total: 48.3s	remaining: 1.65s
# 967:	learn: 0.2184972	total: 48.4s	remaining: 1.6s
# 968:	learn: 0.2184137	total: 48.4s	remaining: 1.55s
# 969:	learn: 0.2184037	total: 48.5s	remaining: 1.5s
# 970:	learn: 0.2183866	total: 48.6s	remaining: 1.45s
# 971:	learn: 0.2183718	total: 48.6s	remaining: 1.4s
# 972:	learn: 0.2183513	total: 48.7s	remaining: 1.35s
# 973:	learn: 0.2183395	total: 48.7s	remaining: 1.3s
# 974:	learn: 0.2183212	total: 48.8s	remaining: 1.25s
# 975:	learn: 0.2183028	total: 48.8s	remaining: 1.2s
# 976:	learn: 0.2182905	total: 48.9s	remaining: 1.15s
# 977:	learn: 0.2182631	total: 48.9s	remaining: 1.1s
# 978:	learn: 0.2182490	total: 49s	remaining: 1.05s
# 979:	learn: 0.2182366	total: 49s	remaining: 1s
# 980:	learn: 0.2182204	total: 49s	remaining: 950ms
# 981:	learn: 0.2180587	total: 49.1s	remaining: 900ms
# 982:	learn: 0.2180480	total: 49.1s	remaining: 850ms
# 983:	learn: 0.2179384	total: 49.2s	remaining: 800ms
# 984:	learn: 0.2179267	total: 49.2s	remaining: 750ms
# 985:	learn: 0.2178104	total: 49.3s	remaining: 700ms
# 986:	learn: 0.2177948	total: 49.3s	remaining: 650ms
# 987:	learn: 0.2177782	total: 49.4s	remaining: 600ms
# 988:	learn: 0.2177631	total: 49.4s	remaining: 550ms
# 989:	learn: 0.2177494	total: 49.5s	remaining: 500ms
# 990:	learn: 0.2174120	total: 49.5s	remaining: 450ms
# 991:	learn: 0.2172387	total: 49.5s	remaining: 400ms
# 992:	learn: 0.2171158	total: 49.6s	remaining: 350ms
# 993:	learn: 0.2170827	total: 49.6s	remaining: 300ms
# 994:	learn: 0.2169347	total: 49.7s	remaining: 250ms
# 995:	learn: 0.2169249	total: 49.7s	remaining: 200ms
# 996:	learn: 0.2169138	total: 49.8s	remaining: 150ms
# 997:	learn: 0.2168987	total: 49.8s	remaining: 99.8ms
# 998:	learn: 0.2168880	total: 49.9s	remaining: 49.9ms
# 999:	learn: 0.2168686	total: 49.9s	remaining: 0us

# %%
# Calculate F1 Score using weighted average method
f1_cb = f1_score(y_test, y_pred_cb, average="weighted")
f1_cb
# Out:
# 0.9060916603243809

# %%
# # Hyperparameter tuning to improve CatBoost performance
# param_grid_cb = {
#         'depth':[2, 3, 4],
#         'l2_leaf_reg':np.logspace(-20, -19, 3)
# }

# grid_cb = RandomizedSearchCV(estimator=clf_cb, 
#                               param_distributions=param_grid_cb,
#                               scoring='f1_weighted',
#                               verbose=1,
#                               n_jobs=-1,
#                               cv=2)
# grid_cb.fit(X_train, y_train)
# print(grid_cb.best_params_)

# %% [markdown]
# ### 📌 Best Estimator parameters
#
# {'l2_leaf_reg': 1e-20, 'depth': 2}

# %%
# Run CatBoost on tuned hyperparameters
clf_cb_tuned = CatBoostClassifier(task_type="GPU",
                                  l2_leaf_reg=1e-20,
                                  depth=2
)
# %time 
clf_cb_tuned.fit(X_train, y_train)
y_pred_cb_tuned = clf_cb_tuned.predict(X_test)
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 8.11 µs
# 0:	learn: 24.6499858	total: 46ms	remaining: 45.9s
# 1:	learn: 1185673550472784642048.0000000	total: 64.8ms	remaining: 32.3s
# 2:	learn: 8243902918326482894848.0000000	total: 83.4ms	remaining: 27.7s
# 3:	learn: 7736088705662580686848.0000000	total: 101ms	remaining: 25.2s
# 4:	learn: 6813841961523149275136.0000000	total: 120ms	remaining: 23.9s
# 5:	learn: 6108380644068223352832.0000000	total: 139ms	remaining: 23s
# 6:	learn: 8728432260228144168960.0000000	total: 158ms	remaining: 22.3s
# 7:	learn: 8582547274904644878336.0000000	total: 175ms	remaining: 21.8s
# 8:	learn: 8434457994707492405248.0000000	total: 192ms	remaining: 21.2s
# 9:	learn: 6733934667425824899072.0000000	total: 210ms	remaining: 20.8s
# 10:	learn: 7595147480432994418688.0000000	total: 227ms	remaining: 20.4s
# 11:	learn: 3158723914420043382784.0000000	total: 247ms	remaining: 20.4s
# 12:	learn: 5189140658517369159680.0000000	total: 265ms	remaining: 20.1s
# 13:	learn: 10259957896366547533824.0000000	total: 282ms	remaining: 19.9s
# 14:	learn: 6832340646884588650496.0000000	total: 300ms	remaining: 19.7s
# 15:	learn: 5814207367546270646272.0000000	total: 317ms	remaining: 19.5s
# 16:	learn: 11120410265576955445248.0000000	total: 336ms	remaining: 19.4s
# 17:	learn: 6734890620564041367552.0000000	total: 354ms	remaining: 19.3s
# 18:	learn: 6597379854764512116736.0000000	total: 370ms	remaining: 19.1s
# 19:	learn: 9048636292442316865536.0000000	total: 387ms	remaining: 19s
# 20:	learn: 6193389272952573263872.0000000	total: 404ms	remaining: 18.8s
# 21:	learn: 4748824441063192133632.0000000	total: 422ms	remaining: 18.7s
# 22:	learn: 6056547907793785454592.0000000	total: 439ms	remaining: 18.7s
# 23:	learn: 7654260167529232072704.0000000	total: 457ms	remaining: 18.6s
# 24:	learn: 3959792509701061607424.0000000	total: 474ms	remaining: 18.5s
# 25:	learn: 6504062954283308417024.0000000	total: 491ms	remaining: 18.4s
# 26:	learn: 6627298620106790141952.0000000	total: 508ms	remaining: 18.3s
# 27:	learn: 6555082138253306888192.0000000	total: 526ms	remaining: 18.2s
# 28:	learn: 4558383752237181566976.0000000	total: 542ms	remaining: 18.2s
# 29:	learn: 4389069452682755833856.0000000	total: 560ms	remaining: 18.1s
# 30:	learn: 5014445183193150652416.0000000	total: 577ms	remaining: 18s
# 31:	learn: 4422873601430207332352.0000000	total: 595ms	remaining: 18s
# 32:	learn: 3765391151783168966656.0000000	total: 612ms	remaining: 17.9s
# 33:	learn: 8954004518688585154560.0000000	total: 629ms	remaining: 17.9s
# 34:	learn: 3335296571227212611584.0000000	total: 647ms	remaining: 17.8s
# 35:	learn: 4039899982019637018624.0000000	total: 665ms	remaining: 17.8s
# 36:	learn: 4554273970796816236544.0000000	total: 682ms	remaining: 17.8s
# 37:	learn: 4680148720924945285120.0000000	total: 699ms	remaining: 17.7s
# 38:	learn: 6774534078911261704192.0000000	total: 717ms	remaining: 17.7s
# 39:	learn: 4811319147961605160960.0000000	total: 734ms	remaining: 17.6s
# 40:	learn: 6482991716154313015296.0000000	total: 750ms	remaining: 17.6s
# 41:	learn: 5658636207476145389568.0000000	total: 768ms	remaining: 17.5s
# 42:	learn: 5676146257540796121088.0000000	total: 785ms	remaining: 17.5s
# 43:	learn: 4975872065539145728000.0000000	total: 802ms	remaining: 17.4s
# 44:	learn: 3668243143624420229120.0000000	total: 820ms	remaining: 17.4s
# 45:	learn: 3506015619990238003200.0000000	total: 836ms	remaining: 17.3s
# 46:	learn: 2932479337268988346368.0000000	total: 852ms	remaining: 17.3s
# 47:	learn: 4616567624059017232384.0000000	total: 869ms	remaining: 17.2s
# 48:	learn: 2601931401866938679296.0000000	total: 886ms	remaining: 17.2s
# 49:	learn: 2516312316949271412736.0000000	total: 904ms	remaining: 17.2s
# 50:	learn: 2948713032319428460544.0000000	total: 922ms	remaining: 17.2s
# 51:	learn: 2611729046118692552704.0000000	total: 940ms	remaining: 17.1s
# 52:	learn: 2222077907282490556416.0000000	total: 957ms	remaining: 17.1s
# 53:	learn: 3092674147362018951168.0000000	total: 975ms	remaining: 17.1s
# 54:	learn: 3045074626037550678016.0000000	total: 993ms	remaining: 17.1s
# 55:	learn: 2241246285089658109952.0000000	total: 1.01s	remaining: 17s
# 56:	learn: 3558502291241093300224.0000000	total: 1.03s	remaining: 17s
# 57:	learn: 3140997345054855528448.0000000	total: 1.04s	remaining: 17s
# 58:	learn: 2593085917288567144448.0000000	total: 1.06s	remaining: 16.9s
# 59:	learn: 2844098901757017456640.0000000	total: 1.08s	remaining: 16.9s
# 60:	learn: 2438701819906555904000.0000000	total: 1.1s	remaining: 16.9s
# 61:	learn: 3003187770948386816000.0000000	total: 1.11s	remaining: 16.9s
# 62:	learn: 4349058320051606126592.0000000	total: 1.13s	remaining: 16.8s
# 63:	learn: 2714522605365679357952.0000000	total: 1.15s	remaining: 16.8s
# 64:	learn: 2430539450803325763584.0000000	total: 1.17s	remaining: 16.8s
# 65:	learn: 2673864541077806514176.0000000	total: 1.18s	remaining: 16.7s
# 66:	learn: 3314606138606572535808.0000000	total: 1.2s	remaining: 16.7s
# 67:	learn: 2629255729067617419264.0000000	total: 1.22s	remaining: 16.7s
# 68:	learn: 2487849658493348347904.0000000	total: 1.24s	remaining: 16.7s
# 69:	learn: 4454900949610321149952.0000000	total: 1.25s	remaining: 16.6s
# 70:	learn: 5477131170969565528064.0000000	total: 1.27s	remaining: 16.6s
# 71:	learn: 2651453626252367233024.0000000	total: 1.29s	remaining: 16.6s
# 72:	learn: 2376024880793608257536.0000000	total: 1.31s	remaining: 16.6s
# 73:	learn: 2184498093805070188544.0000000	total: 1.32s	remaining: 16.6s
# 74:	learn: 2850063979306289201152.0000000	total: 1.34s	remaining: 16.5s
# 75:	learn: 2782758283583159795712.0000000	total: 1.36s	remaining: 16.5s
# 76:	learn: 3682962370791055818752.0000000	total: 1.38s	remaining: 16.5s
# 77:	learn: 2660996524750256209920.0000000	total: 1.39s	remaining: 16.5s
# 78:	learn: 2777410081776925147136.0000000	total: 1.41s	remaining: 16.4s
# 79:	learn: 2466602461957044305920.0000000	total: 1.43s	remaining: 16.4s
# 80:	learn: 2083382850942225612800.0000000	total: 1.44s	remaining: 16.4s
# 81:	learn: 2304565486979533242368.0000000	total: 1.46s	remaining: 16.4s
# 82:	learn: 2918456356801920106496.0000000	total: 1.48s	remaining: 16.3s
# 83:	learn: 2441580913813213413376.0000000	total: 1.49s	remaining: 16.3s
# 84:	learn: 2390412325689745735680.0000000	total: 1.51s	remaining: 16.3s
# 85:	learn: 1983018422311563821056.0000000	total: 1.53s	remaining: 16.3s
# 86:	learn: 2059215707801049628672.0000000	total: 1.55s	remaining: 16.3s
# 87:	learn: 2102903437368998494208.0000000	total: 1.57s	remaining: 16.3s
# 88:	learn: 1627325942963559464960.0000000	total: 1.59s	remaining: 16.3s
# 89:	learn: 1832938448491423203328.0000000	total: 1.61s	remaining: 16.3s
# 90:	learn: 1740363753995279269888.0000000	total: 1.63s	remaining: 16.2s
# 91:	learn: 1792620191111197753344.0000000	total: 1.64s	remaining: 16.2s
# 92:	learn: 1749212302526017175552.0000000	total: 1.66s	remaining: 16.2s
# 93:	learn: 2309832712901807570944.0000000	total: 1.68s	remaining: 16.2s
# 94:	learn: 2146833510978854846464.0000000	total: 1.7s	remaining: 16.2s
# 95:	learn: 2161123930716733702144.0000000	total: 1.72s	remaining: 16.2s
# 96:	learn: 1906984985322416242688.0000000	total: 1.73s	remaining: 16.1s
# 97:	learn: 1892634016049684283392.0000000	total: 1.75s	remaining: 16.1s
# 98:	learn: 1682421350800389046272.0000000	total: 1.77s	remaining: 16.1s
# 99:	learn: 1717098142362198081536.0000000	total: 1.79s	remaining: 16.1s
# 100:	learn: 1762299318496495665152.0000000	total: 1.8s	remaining: 16.1s
# 101:	learn: 2080580064039733035008.0000000	total: 1.82s	remaining: 16s
# 102:	learn: 1833907095146584604672.0000000	total: 1.84s	remaining: 16s
# 103:	learn: 1572489512052909932544.0000000	total: 1.86s	remaining: 16s
# 104:	learn: 1543852208312120508416.0000000	total: 1.88s	remaining: 16s
# 105:	learn: 1675905783142678528000.0000000	total: 1.89s	remaining: 16s
# 106:	learn: 1603043390949927682048.0000000	total: 1.91s	remaining: 16s
# 107:	learn: 1544501766213728993280.0000000	total: 1.93s	remaining: 15.9s
# 108:	learn: 1613814496639132368896.0000000	total: 1.95s	remaining: 15.9s
# 109:	learn: 1542762608489745874944.0000000	total: 1.96s	remaining: 15.9s
# 110:	learn: 1528155580340705951744.0000000	total: 1.98s	remaining: 15.9s
# 111:	learn: 1739986304244277051392.0000000	total: 2s	remaining: 15.9s
# 112:	learn: 1558410942735771500544.0000000	total: 2.02s	remaining: 15.8s
# 113:	learn: 1592725750210902360064.0000000	total: 2.03s	remaining: 15.8s
# 114:	learn: 1508859829656605687808.0000000	total: 2.05s	remaining: 15.8s
# 115:	learn: 1420880771904590577664.0000000	total: 2.07s	remaining: 15.8s
# 116:	learn: 1380105547914338631680.0000000	total: 2.09s	remaining: 15.8s
# 117:	learn: 1441393787092985184256.0000000	total: 2.1s	remaining: 15.7s
# 118:	learn: 1428224482116103569408.0000000	total: 2.12s	remaining: 15.7s
# 119:	learn: 1367261605498235650048.0000000	total: 2.14s	remaining: 15.7s
# 120:	learn: 1352195276299271143424.0000000	total: 2.16s	remaining: 15.7s
# 121:	learn: 1473233504666299924480.0000000	total: 2.17s	remaining: 15.6s
# 122:	learn: 1398382023777990475776.0000000	total: 2.19s	remaining: 15.6s
# 123:	learn: 1316557862719450251264.0000000	total: 2.21s	remaining: 15.6s
# 124:	learn: 1335409048505481953280.0000000	total: 2.23s	remaining: 15.6s
# 125:	learn: 1310367219915037605888.0000000	total: 2.24s	remaining: 15.6s
# 126:	learn: 1341475236482834497536.0000000	total: 2.26s	remaining: 15.5s
# 127:	learn: 1271952844174095024128.0000000	total: 2.28s	remaining: 15.5s
# 128:	learn: 1287851109391696396288.0000000	total: 2.29s	remaining: 15.5s
# 129:	learn: 1278894447113183952896.0000000	total: 2.31s	remaining: 15.5s
# 130:	learn: 1265729665113604751360.0000000	total: 2.33s	remaining: 15.4s
# 131:	learn: 1241641747026465783808.0000000	total: 2.35s	remaining: 15.4s
# 132:	learn: 1278126270484260323328.0000000	total: 2.36s	remaining: 15.4s
# 133:	learn: 1229066994711096721408.0000000	total: 2.38s	remaining: 15.4s
# 134:	learn: 1235145876205394198528.0000000	total: 2.39s	remaining: 15.3s
# 135:	learn: 1248039717274316177408.0000000	total: 2.41s	remaining: 15.3s
# 136:	learn: 1202051543089417551872.0000000	total: 2.43s	remaining: 15.3s
# 137:	learn: 1210223468805980160000.0000000	total: 2.44s	remaining: 15.3s
# 138:	learn: 1212460737643191205888.0000000	total: 2.46s	remaining: 15.2s
# 139:	learn: 1253305484171654201344.0000000	total: 2.47s	remaining: 15.2s
# 140:	learn: 1254408069315961290752.0000000	total: 2.49s	remaining: 15.2s
# 141:	learn: 1203115682926654914560.0000000	total: 2.51s	remaining: 15.1s
# 142:	learn: 1197388499393234862080.0000000	total: 2.53s	remaining: 15.2s
# 143:	learn: 1192698828491966119936.0000000	total: 2.55s	remaining: 15.1s
# 144:	learn: 1191757611505605935104.0000000	total: 2.56s	remaining: 15.1s
# 145:	learn: 1194132612296796798976.0000000	total: 2.58s	remaining: 15.1s
# 146:	learn: 1207785584040037842944.0000000	total: 2.59s	remaining: 15.1s
# 147:	learn: 1160110849980107194368.0000000	total: 2.61s	remaining: 15s
# 148:	learn: 1161056881748757053440.0000000	total: 2.63s	remaining: 15s
# 149:	learn: 1158578144284600434688.0000000	total: 2.64s	remaining: 15s
# 150:	learn: 1138996132908012404736.0000000	total: 2.66s	remaining: 15s
# 151:	learn: 1134224027097846775808.0000000	total: 2.67s	remaining: 14.9s
# 152:	learn: 1127698756924310421504.0000000	total: 2.69s	remaining: 14.9s
# 153:	learn: 1127672640377951879168.0000000	total: 2.71s	remaining: 14.9s
# 154:	learn: 1122192834522469236736.0000000	total: 2.72s	remaining: 14.8s
# 155:	learn: 1117503163621200494592.0000000	total: 2.74s	remaining: 14.8s
# 156:	learn: 1116021159042227634176.0000000	total: 2.75s	remaining: 14.8s
# 157:	learn: 1132746983203656957952.0000000	total: 2.77s	remaining: 14.8s
# 158:	learn: 1143867160608854114304.0000000	total: 2.79s	remaining: 14.7s
# 159:	learn: 1142235168266437001216.0000000	total: 2.81s	remaining: 14.7s
# 160:	learn: 1120838275771675836416.0000000	total: 2.82s	remaining: 14.7s
# 161:	learn: 1118029288013204160512.0000000	total: 2.84s	remaining: 14.7s
# 162:	learn: 1104621067703015309312.0000000	total: 2.85s	remaining: 14.7s
# 163:	learn: 1103351278301016621056.0000000	total: 2.87s	remaining: 14.6s
# 164:	learn: 1103312905945193775104.0000000	total: 2.88s	remaining: 14.6s
# 165:	learn: 1102834637571098542080.0000000	total: 2.9s	remaining: 14.6s
# 166:	learn: 1101614965675659231232.0000000	total: 2.92s	remaining: 14.5s
# 167:	learn: 1107854558766682341376.0000000	total: 2.93s	remaining: 14.5s
# 168:	learn: 1106685733890270560256.0000000	total: 2.95s	remaining: 14.5s
# 169:	learn: 1105533395995638235136.0000000	total: 2.96s	remaining: 14.5s
# 170:	learn: 1102124894890870702080.0000000	total: 2.98s	remaining: 14.4s
# 171:	learn: 1101653775738962837504.0000000	total: 2.99s	remaining: 14.4s
# 172:	learn: 1100768804163894247424.0000000	total: 3.01s	remaining: 14.4s
# 173:	learn: 1096255456426168549376.0000000	total: 3.02s	remaining: 14.4s
# 174:	learn: 1094355149397979168768.0000000	total: 3.04s	remaining: 14.3s
# 175:	learn: 1094345665735893712896.0000000	total: 3.06s	remaining: 14.3s
# 176:	learn: 1091073072803935813632.0000000	total: 3.07s	remaining: 14.3s
# 177:	learn: 1090166507659810963456.0000000	total: 3.09s	remaining: 14.3s
# 178:	learn: 1090028192095856623616.0000000	total: 3.1s	remaining: 14.2s
# 179:	learn: 1089710562367239880704.0000000	total: 3.12s	remaining: 14.2s
# 180:	learn: 1089209752057879855104.0000000	total: 3.13s	remaining: 14.2s
# 181:	learn: 1089208220081696800768.0000000	total: 3.15s	remaining: 14.2s
# 182:	learn: 1086778068147916636160.0000000	total: 3.17s	remaining: 14.1s
# 183:	learn: 1082543248270516682752.0000000	total: 3.18s	remaining: 14.1s
# 184:	learn: 1082474965903501295616.0000000	total: 3.2s	remaining: 14.1s
# 185:	learn: 1081154037677487816704.0000000	total: 3.21s	remaining: 14.1s
# 186:	learn: 1080948971722701144064.0000000	total: 3.23s	remaining: 14s
# 187:	learn: 1080404317714007457792.0000000	total: 3.24s	remaining: 14s
# 188:	learn: 1080403880006526566400.0000000	total: 3.26s	remaining: 14s
# 189:	learn: 1080364413382001557504.0000000	total: 3.27s	remaining: 13.9s
# 190:	learn: 1080254840609290977280.0000000	total: 3.29s	remaining: 13.9s
# 191:	learn: 1076834010743812259840.0000000	total: 3.3s	remaining: 13.9s
# 192:	learn: 1076237853154869772288.0000000	total: 3.32s	remaining: 13.9s
# 193:	learn: 1076199407847800176640.0000000	total: 3.33s	remaining: 13.8s
# 194:	learn: 1076174750326377938944.0000000	total: 3.35s	remaining: 13.8s
# 195:	learn: 1076117118841397051392.0000000	total: 3.37s	remaining: 13.8s
# 196:	learn: 1075254105591618469888.0000000	total: 3.38s	remaining: 13.8s
# 197:	learn: 1071156944716951715840.0000000	total: 3.4s	remaining: 13.8s
# 198:	learn: 1070975660868625498112.0000000	total: 3.41s	remaining: 13.7s
# 199:	learn: 1070036997175903649792.0000000	total: 3.43s	remaining: 13.7s
# 200:	learn: 1069997895307612651520.0000000	total: 3.44s	remaining: 13.7s
# 201:	learn: 1069935084284108079104.0000000	total: 3.46s	remaining: 13.7s
# 202:	learn: 1069897295538259886080.0000000	total: 3.47s	remaining: 13.6s
# 203:	learn: 1069858777279943409664.0000000	total: 3.49s	remaining: 13.6s
# 204:	learn: 1069224976847646228480.0000000	total: 3.5s	remaining: 13.6s
# 205:	learn: 1068766040553955917824.0000000	total: 3.53s	remaining: 13.6s
# 206:	learn: 1068471317516837978112.0000000	total: 3.55s	remaining: 13.6s
# 207:	learn: 1068418938521627525120.0000000	total: 3.57s	remaining: 13.6s
# 208:	learn: 1067885154248708718592.0000000	total: 3.59s	remaining: 13.6s
# 209:	learn: 1067823656347646689280.0000000	total: 3.61s	remaining: 13.6s
# 210:	learn: 1064909399940026204160.0000000	total: 3.63s	remaining: 13.6s
# 211:	learn: 1064167339857460985856.0000000	total: 3.65s	remaining: 13.6s
# 212:	learn: 1064166537393746083840.0000000	total: 3.67s	remaining: 13.6s
# 213:	learn: 1064125538793038020608.0000000	total: 3.69s	remaining: 13.5s
# 214:	learn: 1063107795948772655104.0000000	total: 3.7s	remaining: 13.5s
# 215:	learn: 1062840429629209051136.0000000	total: 3.73s	remaining: 13.5s
# 216:	learn: 1062252515531156226048.0000000	total: 3.77s	remaining: 13.6s
# 217:	learn: 1061637828325523718144.0000000	total: 3.8s	remaining: 13.6s
# 218:	learn: 1061636442251834294272.0000000	total: 3.83s	remaining: 13.7s
# 219:	learn: 1060656415202170372096.0000000	total: 3.86s	remaining: 13.7s
# 220:	learn: 1060655831592195850240.0000000	total: 3.93s	remaining: 13.9s
# 221:	learn: 1057830502754438348800.0000000	total: 3.98s	remaining: 13.9s
# 222:	learn: 1057350994209147322368.0000000	total: 4.03s	remaining: 14s
# 223:	learn: 1057288766795617140736.0000000	total: 4.08s	remaining: 14.1s
# 224:	learn: 1055005757526655500288.0000000	total: 4.12s	remaining: 14.2s
# 225:	learn: 1054967312219585904640.0000000	total: 4.17s	remaining: 14.3s
# 226:	learn: 1054919820957911613440.0000000	total: 4.21s	remaining: 14.3s
# 227:	learn: 1040432943512369889280.0000000	total: 4.29s	remaining: 14.5s
# 228:	learn: 1039529150515623886848.0000000	total: 4.32s	remaining: 14.5s
# 229:	learn: 1039527399685700452352.0000000	total: 4.34s	remaining: 14.5s
# 230:	learn: 1038032045028560994304.0000000	total: 4.37s	remaining: 14.5s
# 231:	learn: 1036149465153346863104.0000000	total: 4.41s	remaining: 14.6s
# 232:	learn: 1032648826623856607232.0000000	total: 4.44s	remaining: 14.6s
# 233:	learn: 1031655668349766729728.0000000	total: 4.47s	remaining: 14.7s
# 234:	learn: 1031593440936236548096.0000000	total: 4.51s	remaining: 14.7s
# 235:	learn: 1031531213522706497536.0000000	total: 4.54s	remaining: 14.7s
# 236:	learn: 1031530411058991595520.0000000	total: 4.58s	remaining: 14.8s
# 237:	learn: 1031138298107380498432.0000000	total: 4.61s	remaining: 14.8s
# 238:	learn: 1029511339400993308672.0000000	total: 4.65s	remaining: 14.8s
# 239:	learn: 1029509880376057135104.0000000	total: 4.69s	remaining: 14.8s
# 240:	learn: 1029171824298333175808.0000000	total: 4.71s	remaining: 14.8s
# 241:	learn: 1028389932835008937984.0000000	total: 4.74s	remaining: 14.8s
# 242:	learn: 1028350685064224440320.0000000	total: 4.76s	remaining: 14.8s
# 243:	learn: 1020085600605483827200.0000000	total: 4.79s	remaining: 14.8s
# 244:	learn: 1020047082347167481856.0000000	total: 4.82s	remaining: 14.8s
# 245:	learn: 1019984709031143669760.0000000	total: 4.84s	remaining: 14.8s
# 246:	learn: 1019946482577814585344.0000000	total: 4.87s	remaining: 14.8s
# 247:	learn: 1019908037270744989696.0000000	total: 4.89s	remaining: 14.8s
# 248:	learn: 1018638612624980312064.0000000	total: 4.92s	remaining: 14.8s
# 249:	learn: 1018591194314553032704.0000000	total: 4.94s	remaining: 14.8s
# 250:	learn: 1017474164823377313792.0000000	total: 4.96s	remaining: 14.8s
# 251:	learn: 1017435646565060968448.0000000	total: 4.99s	remaining: 14.8s
# 252:	learn: 1017115463542805889024.0000000	total: 5.01s	remaining: 14.8s
# 253:	learn: 1016836497974999121920.0000000	total: 5.04s	remaining: 14.8s
# 254:	learn: 1016319857245081042944.0000000	total: 5.06s	remaining: 14.8s
# 255:	learn: 1014705373201898668032.0000000	total: 5.07s	remaining: 14.7s
# 256:	learn: 1014191796424346697728.0000000	total: 5.09s	remaining: 14.7s
# 257:	learn: 1014129350157076135936.0000000	total: 5.11s	remaining: 14.7s
# 258:	learn: 1014080837577946562560.0000000	total: 5.12s	remaining: 14.7s
# 259:	learn: 1013513933438975475712.0000000	total: 5.14s	remaining: 14.6s
# 260:	learn: 1012375164476249997312.0000000	total: 5.15s	remaining: 14.6s
# 261:	learn: 1012314614941396500480.0000000	total: 5.17s	remaining: 14.6s
# 262:	learn: 1011841015447097180160.0000000	total: 5.18s	remaining: 14.5s
# 263:	learn: 1011839045763433234432.0000000	total: 5.2s	remaining: 14.5s
# 264:	learn: 1010721578564776755200.0000000	total: 5.21s	remaining: 14.5s
# 265:	learn: 1010693784139741659136.0000000	total: 5.23s	remaining: 14.4s
# 266:	learn: 1010689552967426506752.0000000	total: 5.24s	remaining: 14.4s
# 267:	learn: 1010684300477656072192.0000000	total: 5.26s	remaining: 14.4s
# 268:	learn: 1010443269558191390720.0000000	total: 5.28s	remaining: 14.3s
# 269:	learn: 1010438017068420956160.0000000	total: 5.29s	remaining: 14.3s
# 270:	learn: 1010404167689900523520.0000000	total: 5.31s	remaining: 14.3s
# 271:	learn: 1009927212438247702528.0000000	total: 5.32s	remaining: 14.2s
# 272:	learn: 1009891466327310204928.0000000	total: 5.34s	remaining: 14.2s
# 273:	learn: 1009866735854641086464.0000000	total: 5.35s	remaining: 14.2s
# 274:	learn: 1009850832482836283392.0000000	total: 5.37s	remaining: 14.2s
# 275:	learn: 1009846455408027631616.0000000	total: 5.38s	remaining: 14.1s
# 276:	learn: 1007133909197840449536.0000000	total: 5.4s	remaining: 14.1s
# 277:	learn: 1006605377414692208640.0000000	total: 5.42s	remaining: 14.1s
# 278:	learn: 1006601510998611197952.0000000	total: 5.43s	remaining: 14s
# 279:	learn: 1005620681485232373760.0000000	total: 5.45s	remaining: 14s
# 280:	learn: 1005596096915056885760.0000000	total: 5.46s	remaining: 14s
# 281:	learn: 1005576910737145462784.0000000	total: 5.48s	remaining: 14s
# 282:	learn: 1005556703241778757632.0000000	total: 5.5s	remaining: 13.9s
# 283:	learn: 1005555317168089333760.0000000	total: 5.51s	remaining: 13.9s
# 284:	learn: 1004776343754637574144.0000000	total: 5.53s	remaining: 13.9s
# 285:	learn: 1004765619921356324864.0000000	total: 5.54s	remaining: 13.8s
# 286:	learn: 1004751686233215336448.0000000	total: 5.56s	remaining: 13.8s
# 287:	learn: 1004749716549551390720.0000000	total: 5.57s	remaining: 13.8s
# 288:	learn: 1004627450259895615488.0000000	total: 5.59s	remaining: 13.8s
# 289:	learn: 1004346660910918664192.0000000	total: 5.6s	remaining: 13.7s
# 290:	learn: 1004151297471957827584.0000000	total: 5.62s	remaining: 13.7s
# 291:	learn: 1003168717128655437824.0000000	total: 5.64s	remaining: 13.7s
# 292:	learn: 1002756104876690374656.0000000	total: 5.65s	remaining: 13.6s
# 293:	learn: 1002089914090808934400.0000000	total: 5.67s	remaining: 13.6s
# 294:	learn: 1001826195333585829888.0000000	total: 5.68s	remaining: 13.6s
# 295:	learn: 1000040421762890465280.0000000	total: 5.7s	remaining: 13.6s
# 296:	learn: 999180910172958883840.0000000	total: 5.71s	remaining: 13.5s
# 297:	learn: 999161286287566569472.0000000	total: 5.73s	remaining: 13.5s
# 298:	learn: 999157492822732439552.0000000	total: 5.74s	remaining: 13.5s
# 299:	learn: 997617929710025310208.0000000	total: 5.76s	remaining: 13.4s
# 300:	learn: 997616543636335886336.0000000	total: 5.78s	remaining: 13.4s
# 301:	learn: 997615887075114614784.0000000	total: 5.79s	remaining: 13.4s
# 302:	learn: 997372448764505096192.0000000	total: 5.8s	remaining: 13.4s
# 303:	learn: 996873097480081244160.0000000	total: 5.82s	remaining: 13.3s
# 304:	learn: 996863030208021266432.0000000	total: 5.84s	remaining: 13.3s
# 305:	learn: 993261864860424994816.0000000	total: 5.85s	remaining: 13.3s
# 306:	learn: 993155501942574022656.0000000	total: 5.87s	remaining: 13.2s
# 307:	learn: 993050087390931582976.0000000	total: 5.88s	remaining: 13.2s
# 308:	learn: 993036007800296964096.0000000	total: 5.9s	remaining: 13.2s
# 309:	learn: 993012809303811031040.0000000	total: 5.92s	remaining: 13.2s
# 310:	learn: 992963640163460055040.0000000	total: 5.93s	remaining: 13.1s
# 311:	learn: 992960795064834457600.0000000	total: 5.95s	remaining: 13.1s
# 312:	learn: 992531404026102808576.0000000	total: 5.96s	remaining: 13.1s
# 313:	learn: 992503463698573950976.0000000	total: 5.98s	remaining: 13.1s
# 314:	learn: 992500399746207973376.0000000	total: 5.99s	remaining: 13s
# 315:	learn: 992499597282493071360.0000000	total: 6.01s	remaining: 13s
# 316:	learn: 992489675912926724096.0000000	total: 6.02s	remaining: 13s
# 317:	learn: 992470781540002562048.0000000	total: 6.04s	remaining: 12.9s
# 318:	learn: 991734776410922680320.0000000	total: 6.05s	remaining: 12.9s
# 319:	learn: 991503083251049693184.0000000	total: 6.07s	remaining: 12.9s
# 320:	learn: 991499362737462312960.0000000	total: 6.09s	remaining: 12.9s
# 321:	learn: 991496298785096335360.0000000	total: 6.1s	remaining: 12.8s
# 322:	learn: 991490973344079020032.0000000	total: 6.12s	remaining: 12.8s
# 323:	learn: 985356794804698480640.0000000	total: 6.13s	remaining: 12.8s
# 324:	learn: 984457232980267499520.0000000	total: 6.15s	remaining: 12.8s
# 325:	learn: 984121657244935127040.0000000	total: 6.16s	remaining: 12.7s
# 326:	learn: 984106483385598345216.0000000	total: 6.18s	remaining: 12.7s
# 327:	learn: 983841816262166708224.0000000	total: 6.19s	remaining: 12.7s
# 328:	learn: 983718163898821509120.0000000	total: 6.21s	remaining: 12.7s
# 329:	learn: 982899942714585251840.0000000	total: 6.22s	remaining: 12.6s
# 330:	learn: 981943843673875415040.0000000	total: 6.24s	remaining: 12.6s
# 331:	learn: 979960299273074376704.0000000	total: 6.25s	remaining: 12.6s
# 332:	learn: 979920467892315357184.0000000	total: 6.27s	remaining: 12.6s
# 333:	learn: 979898363664531456000.0000000	total: 6.29s	remaining: 12.5s
# 334:	learn: 979871225800717631488.0000000	total: 6.3s	remaining: 12.5s
# 335:	learn: 979865900359700447232.0000000	total: 6.32s	remaining: 12.5s
# 336:	learn: 979855249477665947648.0000000	total: 6.33s	remaining: 12.5s
# 337:	learn: 979229546633764929536.0000000	total: 6.34s	remaining: 12.4s
# 338:	learn: 979228817121296777216.0000000	total: 6.36s	remaining: 12.4s
# 339:	learn: 979214737530662158336.0000000	total: 6.38s	remaining: 12.4s
# 340:	learn: 978538698326461251584.0000000	total: 6.39s	remaining: 12.3s
# 341:	learn: 978526807273230958592.0000000	total: 6.41s	remaining: 12.3s
# 342:	learn: 977869516539460583424.0000000	total: 6.42s	remaining: 12.3s
# 343:	learn: 972044432432819732480.0000000	total: 6.43s	remaining: 12.3s
# 344:	learn: 972025173303661559808.0000000	total: 6.45s	remaining: 12.2s
# 345:	learn: 971991761632621887488.0000000	total: 6.47s	remaining: 12.2s
# 346:	learn: 971963018841378258944.0000000	total: 6.48s	remaining: 12.2s
# 347:	learn: 969927606104094277632.0000000	total: 6.5s	remaining: 12.2s
# 348:	learn: 969902146118957137920.0000000	total: 6.51s	remaining: 12.1s
# 349:	learn: 969877561548781649920.0000000	total: 6.53s	remaining: 12.1s
# 350:	learn: 969837730168022630400.0000000	total: 6.54s	remaining: 12.1s
# 351:	learn: 969828903067158446080.0000000	total: 6.56s	remaining: 12.1s
# 352:	learn: 969827371090975391744.0000000	total: 6.57s	remaining: 12s
# 353:	learn: 969826568627260489728.0000000	total: 6.59s	remaining: 12s
# 354:	learn: 968245277401377275904.0000000	total: 6.6s	remaining: 12s
# 355:	learn: 968220546928708288512.0000000	total: 6.62s	remaining: 12s
# 356:	learn: 968218723147537973248.0000000	total: 6.63s	remaining: 11.9s
# 357:	learn: 968208874729218506752.0000000	total: 6.65s	remaining: 11.9s
# 358:	learn: 967773063980767379456.0000000	total: 6.67s	remaining: 11.9s
# 359:	learn: 967759203243873140736.0000000	total: 6.68s	remaining: 11.9s
# 360:	learn: 967748114654357880832.0000000	total: 6.7s	remaining: 11.9s
# 361:	learn: 967522695301710741504.0000000	total: 6.71s	remaining: 11.8s
# 362:	learn: 967521965789242589184.0000000	total: 6.73s	remaining: 11.8s
# 363:	learn: 966809596864129662976.0000000	total: 6.74s	remaining: 11.8s
# 364:	learn: 966801061568252739584.0000000	total: 6.76s	remaining: 11.8s
# 365:	learn: 966794714809780142080.0000000	total: 6.78s	remaining: 11.7s
# 366:	learn: 966792818077362946048.0000000	total: 6.79s	remaining: 11.7s
# 367:	learn: 966228321329536696320.0000000	total: 6.8s	remaining: 11.7s
# 368:	learn: 966153619252801830912.0000000	total: 6.82s	remaining: 11.7s
# 369:	learn: 965836281329172348928.0000000	total: 6.83s	remaining: 11.6s
# 370:	learn: 965824171422201675776.0000000	total: 6.85s	remaining: 11.6s
# 371:	learn: 965822201738537730048.0000000	total: 6.87s	remaining: 11.6s
# 372:	learn: 965558264127574245376.0000000	total: 6.88s	remaining: 11.6s
# 373:	learn: 965556367395157180416.0000000	total: 6.9s	remaining: 11.5s
# 374:	learn: 965554616565233614848.0000000	total: 6.91s	remaining: 11.5s
# 375:	learn: 965474005437507174400.0000000	total: 6.93s	remaining: 11.5s
# 376:	learn: 965273097703788642304.0000000	total: 6.94s	remaining: 11.5s
# 377:	learn: 965271638678852337664.0000000	total: 6.96s	remaining: 11.5s
# 378:	learn: 964684964751995305984.0000000	total: 6.97s	remaining: 11.4s
# 379:	learn: 964158256750017249280.0000000	total: 6.99s	remaining: 11.4s
# 380:	learn: 964144614866863521792.0000000	total: 7s	remaining: 11.4s
# 381:	learn: 964142499280706076672.0000000	total: 7.02s	remaining: 11.4s
# 382:	learn: 963880896109640417280.0000000	total: 7.03s	remaining: 11.3s
# 383:	learn: 963842450802570821632.0000000	total: 7.05s	remaining: 11.3s
# 384:	learn: 963725072246451339264.0000000	total: 7.06s	remaining: 11.3s
# 385:	learn: 963460842830500593664.0000000	total: 7.08s	remaining: 11.3s
# 386:	learn: 963088207861788180480.0000000	total: 7.09s	remaining: 11.2s
# 387:	learn: 962832513741714358272.0000000	total: 7.11s	remaining: 11.2s
# 388:	learn: 961108967584548913152.0000000	total: 7.12s	remaining: 11.2s
# 389:	learn: 961104006899765739520.0000000	total: 7.14s	remaining: 11.2s
# 390:	learn: 961102183118595555328.0000000	total: 7.15s	remaining: 11.1s
# 391:	learn: 961097951946280402944.0000000	total: 7.17s	remaining: 11.1s
# 392:	learn: 961089343699156729856.0000000	total: 7.18s	remaining: 11.1s
# 393:	learn: 961088468284194947072.0000000	total: 7.2s	remaining: 11.1s
# 394:	learn: 961080954305773436928.0000000	total: 7.21s	remaining: 11s
# 395:	learn: 960796444443209105408.0000000	total: 7.23s	remaining: 11s
# 396:	learn: 960739761324436619264.0000000	total: 7.24s	remaining: 11s
# 397:	learn: 960736186713342869504.0000000	total: 7.26s	remaining: 11s
# 398:	learn: 960732393248508739584.0000000	total: 7.27s	remaining: 11s
# 399:	learn: 960726994856244674560.0000000	total: 7.29s	remaining: 10.9s
# 400:	learn: 960721377610240098304.0000000	total: 7.3s	remaining: 10.9s
# 401:	learn: 960705911945916186624.0000000	total: 7.32s	remaining: 10.9s
# 402:	learn: 960703139798537338880.0000000	total: 7.33s	remaining: 10.9s
# 403:	learn: 960043514624868876288.0000000	total: 7.35s	remaining: 10.8s
# 404:	learn: 960034030962783420416.0000000	total: 7.36s	remaining: 10.8s
# 405:	learn: 960031696522885464064.0000000	total: 7.38s	remaining: 10.8s
# 406:	learn: 958233156483998023680.0000000	total: 7.39s	remaining: 10.8s
# 407:	learn: 958227903994227589120.0000000	total: 7.41s	remaining: 10.8s
# 408:	learn: 956568263129269010432.0000000	total: 7.42s	remaining: 10.7s
# 409:	learn: 956532444067084632064.0000000	total: 7.44s	remaining: 10.7s
# 410:	learn: 956530985042148458496.0000000	total: 7.45s	remaining: 10.7s
# 411:	learn: 956530255529680306176.0000000	total: 7.47s	remaining: 10.7s
# 412:	learn: 956511142303015763968.0000000	total: 7.49s	remaining: 10.6s
# 413:	learn: 956204820017654792192.0000000	total: 7.5s	remaining: 10.6s
# 414:	learn: 956189500255824379904.0000000	total: 7.52s	remaining: 10.6s
# 415:	learn: 956183372351092293632.0000000	total: 7.53s	remaining: 10.6s
# 416:	learn: 956181621521168728064.0000000	total: 7.55s	remaining: 10.6s
# 417:	learn: 956178557568802750464.0000000	total: 7.56s	remaining: 10.5s
# 418:	learn: 956176660836385554432.0000000	total: 7.58s	remaining: 10.5s
# 419:	learn: 956134203210741448704.0000000	total: 7.59s	remaining: 10.5s
# 420:	learn: 956133327795779665920.0000000	total: 7.61s	remaining: 10.5s
# 421:	learn: 956130263843413557248.0000000	total: 7.63s	remaining: 10.4s
# 422:	learn: 956126032671098535936.0000000	total: 7.64s	remaining: 10.4s
# 423:	learn: 956113193251659710464.0000000	total: 7.66s	remaining: 10.4s
# 424:	learn: 955526957032283570176.0000000	total: 7.67s	remaining: 10.4s
# 425:	learn: 955515941394015059968.0000000	total: 7.69s	remaining: 10.4s
# 426:	learn: 955487855163992702976.0000000	total: 7.7s	remaining: 10.3s
# 427:	learn: 955454516444199911424.0000000	total: 7.72s	remaining: 10.3s
# 428:	learn: 955287385137755062272.0000000	total: 7.73s	remaining: 10.3s
# 429:	learn: 955283445770427170816.0000000	total: 7.75s	remaining: 10.3s
# 430:	learn: 955264843202490269696.0000000	total: 7.76s	remaining: 10.3s
# 431:	learn: 955254994784170803200.0000000	total: 7.78s	remaining: 10.2s
# 432:	learn: 955228148725344239616.0000000	total: 7.79s	remaining: 10.2s
# 433:	learn: 955213558475981979648.0000000	total: 7.81s	remaining: 10.2s
# 434:	learn: 955212901914760577024.0000000	total: 7.83s	remaining: 10.2s
# 435:	learn: 955121785807493267456.0000000	total: 7.84s	remaining: 10.1s
# 436:	learn: 955121056295025115136.0000000	total: 7.86s	remaining: 10.1s
# 437:	learn: 955104058654518018048.0000000	total: 7.87s	remaining: 10.1s
# 438:	learn: 955093407772483649536.0000000	total: 7.88s	remaining: 10.1s
# 439:	learn: 955084872476606726144.0000000	total: 7.9s	remaining: 10.1s
# 440:	learn: 953662104310044557312.0000000	total: 7.92s	remaining: 10s
# 441:	learn: 953660207577627492352.0000000	total: 7.93s	remaining: 10s
# 442:	learn: 953492930368689012736.0000000	total: 7.95s	remaining: 9.99s
# 443:	learn: 953217904168210137088.0000000	total: 7.96s	remaining: 9.97s
# 444:	learn: 953216007435793072128.0000000	total: 7.98s	remaining: 9.95s
# 445:	learn: 953215350874571800576.0000000	total: 7.99s	remaining: 9.93s
# 446:	learn: 953214621362103648256.0000000	total: 8.01s	remaining: 9.91s
# 447:	learn: 953045958079475744768.0000000	total: 8.03s	remaining: 9.89s
# 448:	learn: 952136912592959307776.0000000	total: 8.04s	remaining: 9.87s
# 449:	learn: 952043534997040791552.0000000	total: 8.05s	remaining: 9.84s
# 450:	learn: 952033759529968074752.0000000	total: 8.07s	remaining: 9.82s
# 451:	learn: 952028725893938020352.0000000	total: 8.08s	remaining: 9.8s
# 452:	learn: 951962267308092948480.0000000	total: 8.1s	remaining: 9.78s
# 453:	learn: 951959568111960850432.0000000	total: 8.11s	remaining: 9.76s
# 454:	learn: 951754137400940036096.0000000	total: 8.13s	remaining: 9.74s
# 455:	learn: 951750270984859156480.0000000	total: 8.15s	remaining: 9.72s
# 456:	learn: 951735826637990395904.0000000	total: 8.16s	remaining: 9.7s
# 457:	learn: 951732762685624418304.0000000	total: 8.18s	remaining: 9.68s
# 458:	learn: 951728531513309265920.0000000	total: 8.19s	remaining: 9.65s
# 459:	learn: 950401694236304211968.0000000	total: 8.21s	remaining: 9.63s
# 460:	learn: 950388708914371756032.0000000	total: 8.22s	remaining: 9.61s
# 461:	learn: 950387979401903603712.0000000	total: 8.24s	remaining: 9.59s
# 462:	learn: 950372805542566821888.0000000	total: 8.25s	remaining: 9.57s
# 463:	learn: 950246526934336405504.0000000	total: 8.27s	remaining: 9.55s
# 464:	learn: 950242733469502144512.0000000	total: 8.28s	remaining: 9.53s
# 465:	learn: 950044014273188069376.0000000	total: 8.3s	remaining: 9.51s
# 466:	learn: 949999222207645876224.0000000	total: 8.31s	remaining: 9.49s
# 467:	learn: 949943852211316064256.0000000	total: 8.33s	remaining: 9.47s
# 468:	learn: 948807782444722552832.0000000	total: 8.34s	remaining: 9.45s
# 469:	learn: 948713456482595504128.0000000	total: 8.36s	remaining: 9.43s
# 470:	learn: 948711049091450667008.0000000	total: 8.37s	remaining: 9.4s
# 471:	learn: 948707255626616537088.0000000	total: 8.39s	remaining: 9.38s
# 472:	learn: 948676032492981321728.0000000	total: 8.4s	remaining: 9.36s
# 473:	learn: 948650426605350420480.0000000	total: 8.42s	remaining: 9.34s
# 474:	learn: 948649770044129148928.0000000	total: 8.43s	remaining: 9.32s
# 475:	learn: 948647873311712083968.0000000	total: 8.45s	remaining: 9.3s
# 476:	learn: 948645538871814127616.0000000	total: 8.46s	remaining: 9.28s
# 477:	learn: 948574192552432631808.0000000	total: 8.48s	remaining: 9.26s
# 478:	learn: 948573535991211360256.0000000	total: 8.49s	remaining: 9.24s
# 479:	learn: 948572806478743207936.0000000	total: 8.51s	remaining: 9.22s
# 480:	learn: 948559529351823491072.0000000	total: 8.52s	remaining: 9.2s
# 481:	learn: 948555371130755219456.0000000	total: 8.54s	remaining: 9.18s
# 482:	learn: 948554495715793567744.0000000	total: 8.55s	remaining: 9.15s
# 483:	learn: 948549607982257143808.0000000	total: 8.57s	remaining: 9.13s
# 484:	learn: 948501460159361712128.0000000	total: 8.58s	remaining: 9.12s
# 485:	learn: 948457470557534420992.0000000	total: 8.6s	remaining: 9.1s
# 486:	learn: 948295154033379115008.0000000	total: 8.62s	remaining: 9.07s
# 487:	learn: 948024869663943032832.0000000	total: 8.63s	remaining: 9.05s
# 488:	learn: 948024359005215260672.0000000	total: 8.64s	remaining: 9.03s
# 489:	learn: 948022462272798195712.0000000	total: 8.66s	remaining: 9.01s
# 490:	learn: 948004224461095436288.0000000	total: 8.68s	remaining: 8.99s
# 491:	learn: 947998096556363218944.0000000	total: 8.69s	remaining: 8.97s
# 492:	learn: 947987226820588339200.0000000	total: 8.71s	remaining: 8.95s
# 493:	learn: 947985548941911654400.0000000	total: 8.72s	remaining: 8.93s
# 494:	learn: 947941486388837613568.0000000	total: 8.73s	remaining: 8.91s
# 495:	learn: 947934993727871385600.0000000	total: 8.75s	remaining: 8.89s
# 496:	learn: 947902311569299865600.0000000	total: 8.77s	remaining: 8.87s
# 497:	learn: 947838187423352750080.0000000	total: 8.78s	remaining: 8.85s
# 498:	learn: 947836509544676065280.0000000	total: 8.8s	remaining: 8.83s
# 499:	learn: 947811997925747458048.0000000	total: 8.81s	remaining: 8.81s
# 500:	learn: 947795292090227621888.0000000	total: 8.83s	remaining: 8.79s
# 501:	learn: 947783182183256948736.0000000	total: 8.84s	remaining: 8.77s
# 502:	learn: 947778732157201416192.0000000	total: 8.86s	remaining: 8.75s
# 503:	learn: 947777273132265242624.0000000	total: 8.87s	remaining: 8.73s
# 504:	learn: 947717526061126778880.0000000	total: 8.89s	remaining: 8.71s
# 505:	learn: 947716650646164996096.0000000	total: 8.9s	remaining: 8.69s
# 506:	learn: 947679080754057183232.0000000	total: 8.92s	remaining: 8.67s
# 507:	learn: 947092552729693782016.0000000	total: 8.93s	remaining: 8.65s
# 508:	learn: 947088467459872260096.0000000	total: 8.95s	remaining: 8.63s
# 509:	learn: 947073001795548348416.0000000	total: 8.96s	remaining: 8.61s
# 510:	learn: 946975028271080669184.0000000	total: 8.98s	remaining: 8.59s
# 511:	learn: 946943002673730420736.0000000	total: 8.99s	remaining: 8.57s
# 512:	learn: 946940011672611192832.0000000	total: 9.01s	remaining: 8.55s
# 513:	learn: 946898283559435108352.0000000	total: 9.02s	remaining: 8.53s
# 514:	learn: 946890915483507097600.0000000	total: 9.04s	remaining: 8.51s
# 515:	learn: 945881270227637764096.0000000	total: 9.05s	remaining: 8.49s
# 516:	learn: 945834143722197614592.0000000	total: 9.07s	remaining: 8.47s
# 517:	learn: 945820793644031148032.0000000	total: 9.08s	remaining: 8.45s
# 518:	learn: 945818896911614083072.0000000	total: 9.1s	remaining: 8.43s
# 519:	learn: 945815905910494855168.0000000	total: 9.11s	remaining: 8.41s
# 520:	learn: 945812914909375496192.0000000	total: 9.13s	remaining: 8.39s
# 521:	learn: 945156426639320023040.0000000	total: 9.14s	remaining: 8.37s
# 522:	learn: 945151757759524110336.0000000	total: 9.16s	remaining: 8.35s
# 523:	learn: 944714633888630439936.0000000	total: 9.17s	remaining: 8.33s
# 524:	learn: 944704566616570462208.0000000	total: 9.19s	remaining: 8.31s
# 525:	learn: 944670352481815887872.0000000	total: 9.2s	remaining: 8.29s
# 526:	learn: 944666194260747616256.0000000	total: 9.22s	remaining: 8.27s
# 527:	learn: 944663203259628388352.0000000	total: 9.23s	remaining: 8.26s
# 528:	learn: 944661306527211323392.0000000	total: 9.25s	remaining: 8.23s
# 529:	learn: 944543636166104580096.0000000	total: 9.26s	remaining: 8.21s
# 530:	learn: 944533714796538232832.0000000	total: 9.28s	remaining: 8.2s
# 531:	learn: 944529483624223211520.0000000	total: 9.29s	remaining: 8.18s
# 532:	learn: 944502053955422126080.0000000	total: 9.31s	remaining: 8.16s
# 533:	learn: 944500521979239071744.0000000	total: 9.32s	remaining: 8.14s
# 534:	learn: 944497530978119843840.0000000	total: 9.34s	remaining: 8.12s
# 535:	learn: 944492570293336670208.0000000	total: 9.35s	remaining: 8.1s
# 536:	learn: 944486515339851202560.0000000	total: 9.37s	remaining: 8.08s
# 537:	learn: 944117090225998528512.0000000	total: 9.38s	remaining: 8.06s
# 538:	learn: 944108700832615235584.0000000	total: 9.4s	remaining: 8.04s
# 539:	learn: 944102427025389387776.0000000	total: 9.41s	remaining: 8.02s
# 540:	learn: 944070474379286020096.0000000	total: 9.43s	remaining: 8s
# 541:	learn: 944059531692264390656.0000000	total: 9.45s	remaining: 7.98s
# 542:	learn: 944046181614097793024.0000000	total: 9.46s	remaining: 7.96s
# 543:	learn: 944019262604024479744.0000000	total: 9.48s	remaining: 7.94s
# 544:	learn: 943735628156421799936.0000000	total: 9.49s	remaining: 7.92s
# 545:	learn: 943725779738102333440.0000000	total: 9.51s	remaining: 7.91s
# 546:	learn: 943713523928638029824.0000000	total: 9.52s	remaining: 7.88s
# 547:	learn: 943681863087521923072.0000000	total: 9.54s	remaining: 7.87s
# 548:	learn: 943608547084476481536.0000000	total: 9.55s	remaining: 7.85s
# 549:	learn: 943604680668395470848.0000000	total: 9.57s	remaining: 7.83s
# 550:	learn: 943602783935978405888.0000000	total: 9.58s	remaining: 7.81s
# 551:	learn: 943597458494961090560.0000000	total: 9.6s	remaining: 7.79s
# 552:	learn: 942500782401645838336.0000000	total: 9.61s	remaining: 7.77s
# 553:	learn: 942500125840424566784.0000000	total: 9.63s	remaining: 7.75s
# 554:	learn: 942495602863122284544.0000000	total: 9.64s	remaining: 7.73s
# 555:	learn: 942492903666990186496.0000000	total: 9.66s	remaining: 7.71s
# 556:	learn: 940732663032678711296.0000000	total: 9.68s	remaining: 7.7s
# 557:	learn: 940717051465861169152.0000000	total: 9.69s	remaining: 7.68s
# 558:	learn: 940713914562248179712.0000000	total: 9.71s	remaining: 7.66s
# 559:	learn: 940710121097414049792.0000000	total: 9.72s	remaining: 7.64s
# 560:	learn: 940708151413750104064.0000000	total: 9.74s	remaining: 7.62s
# 561:	learn: 940699324312885919744.0000000	total: 9.75s	remaining: 7.6s
# 562:	learn: 940697427580468854784.0000000	total: 9.77s	remaining: 7.58s
# 563:	learn: 940695895604285800448.0000000	total: 9.78s	remaining: 7.56s
# 564:	learn: 940687506210902507520.0000000	total: 9.8s	remaining: 7.54s
# 565:	learn: 940528180687866429440.0000000	total: 9.82s	remaining: 7.53s
# 566:	learn: 940527378224151527424.0000000	total: 9.83s	remaining: 7.51s
# 567:	learn: 940522125734381092864.0000000	total: 9.85s	remaining: 7.49s
# 568:	learn: 940517821610819321856.0000000	total: 9.86s	remaining: 7.47s
# 569:	learn: 940504690386393235456.0000000	total: 9.88s	remaining: 7.45s
# 570:	learn: 940137818566178897920.0000000	total: 9.89s	remaining: 7.43s
# 571:	learn: 940103604431424323584.0000000	total: 9.91s	remaining: 7.41s
# 572:	learn: 940100686381551845376.0000000	total: 9.92s	remaining: 7.39s
# 573:	learn: 940080114129950998528.0000000	total: 9.94s	remaining: 7.38s
# 574:	learn: 940077196080078651392.0000000	total: 9.95s	remaining: 7.36s
# 575:	learn: 940031601550821556224.0000000	total: 9.97s	remaining: 7.34s
# 576:	learn: 940027370378506403840.0000000	total: 9.98s	remaining: 7.32s
# 577:	learn: 935606743675478081536.0000000	total: 10s	remaining: 7.3s
# 578:	learn: 935602220698175668224.0000000	total: 10s	remaining: 7.28s
# 579:	learn: 935599156745809690624.0000000	total: 10s	remaining: 7.26s
# 580:	learn: 935597405915886125056.0000000	total: 10s	remaining: 7.25s
# 581:	learn: 935590475547439136768.0000000	total: 10.1s	remaining: 7.23s
# 582:	learn: 935573988565659680768.0000000	total: 10.1s	remaining: 7.21s
# 583:	learn: 935309686198462185472.0000000	total: 10.1s	remaining: 7.19s
# 584:	learn: 935309029637240782848.0000000	total: 10.1s	remaining: 7.17s
# 585:	learn: 935304141903704489984.0000000	total: 10.1s	remaining: 7.15s
# 586:	learn: 935294366436631773184.0000000	total: 10.1s	remaining: 7.13s
# 587:	learn: 935261319521826242560.0000000	total: 10.2s	remaining: 7.12s
# 588:	learn: 935258328520706883584.0000000	total: 10.2s	remaining: 7.1s
# 589:	learn: 935256796544523960320.0000000	total: 10.2s	remaining: 7.08s
# 590:	learn: 935254899812106764288.0000000	total: 10.2s	remaining: 7.06s
# 591:	learn: 935254170299638743040.0000000	total: 10.2s	remaining: 7.04s
# 592:	learn: 935252638323455688704.0000000	total: 10.2s	remaining: 7.02s
# 593:	learn: 934421796573520986112.0000000	total: 10.2s	remaining: 7s
# 594:	learn: 934417857206193225728.0000000	total: 10.3s	remaining: 6.99s
# 595:	learn: 934406987470418345984.0000000	total: 10.3s	remaining: 6.97s
# 596:	learn: 934397139052098748416.0000000	total: 10.3s	remaining: 6.95s
# 597:	learn: 934371314310727467008.0000000	total: 10.3s	remaining: 6.93s
# 598:	learn: 934365915918463533056.0000000	total: 10.3s	remaining: 6.91s
# 599:	learn: 934360517526199468032.0000000	total: 10.3s	remaining: 6.89s
# 600:	learn: 934358620793782403072.0000000	total: 10.4s	remaining: 6.87s
# 601:	learn: 934285231839490080768.0000000	total: 10.4s	remaining: 6.86s
# 602:	learn: 934284429375775178752.0000000	total: 10.4s	remaining: 6.84s
# 603:	learn: 934273778493740679168.0000000	total: 10.4s	remaining: 6.82s
# 604:	learn: 934268380101476745216.0000000	total: 10.4s	remaining: 6.8s
# 605:	learn: 934266264515319169024.0000000	total: 10.4s	remaining: 6.78s
# 606:	learn: 933999190000742694912.0000000	total: 10.4s	remaining: 6.76s
# 607:	learn: 933974751333060968448.0000000	total: 10.5s	remaining: 6.74s
# 608:	learn: 933948561835455676416.0000000	total: 10.5s	remaining: 6.72s
# 609:	learn: 933946665103038611456.0000000	total: 10.5s	remaining: 6.71s
# 610:	learn: 933916098530624536576.0000000	total: 10.5s	remaining: 6.69s
# 611:	learn: 933911721455815884800.0000000	total: 10.5s	remaining: 6.67s
# 612:	learn: 933845408772464312320.0000000	total: 10.5s	remaining: 6.65s
# 613:	learn: 933833225914246889472.0000000	total: 10.6s	remaining: 6.63s
# 614:	learn: 933828921790684987392.0000000	total: 10.6s	remaining: 6.61s
# 615:	learn: 933825784887072129024.0000000	total: 10.6s	remaining: 6.6s
# 616:	learn: 933819948787327172608.0000000	total: 10.6s	remaining: 6.58s
# 617:	learn: 933814477443816357888.0000000	total: 10.6s	remaining: 6.56s
# 618:	learn: 933813602028854575104.0000000	total: 10.6s	remaining: 6.54s
# 619:	learn: 933409670975260065792.0000000	total: 10.6s	remaining: 6.52s
# 620:	learn: 933403980778008739840.0000000	total: 10.7s	remaining: 6.5s
# 621:	learn: 933395591384625446912.0000000	total: 10.7s	remaining: 6.49s
# 622:	learn: 932457876058112131072.0000000	total: 10.7s	remaining: 6.47s
# 623:	learn: 932453644885797109760.0000000	total: 10.7s	remaining: 6.45s
# 624:	learn: 932452988324575838208.0000000	total: 10.7s	remaining: 6.43s
# 625:	learn: 932448465347273555968.0000000	total: 10.7s	remaining: 6.41s
# 626:	learn: 932440805466358284288.0000000	total: 10.7s	remaining: 6.39s
# 627:	learn: 932440003002643382272.0000000	total: 10.8s	remaining: 6.38s
# 628:	learn: 932436209537809252352.0000000	total: 10.8s	remaining: 6.36s
# 629:	learn: 932434385756638937088.0000000	total: 10.8s	remaining: 6.34s
# 630:	learn: 932432853780455882752.0000000	total: 10.8s	remaining: 6.32s
# 631:	learn: 932431394755519709184.0000000	total: 10.8s	remaining: 6.3s
# 632:	learn: 931534313273480314880.0000000	total: 10.8s	remaining: 6.28s
# 633:	learn: 931519139414143533056.0000000	total: 10.9s	remaining: 6.26s
# 634:	learn: 931494481892721295360.0000000	total: 10.9s	remaining: 6.25s
# 635:	learn: 931469021907584155648.0000000	total: 10.9s	remaining: 6.23s
# 636:	learn: 931423865085807820800.0000000	total: 10.9s	remaining: 6.21s
# 637:	learn: 931009356101425692672.0000000	total: 10.9s	remaining: 6.19s
# 638:	learn: 930875344661033123840.0000000	total: 10.9s	remaining: 6.17s
# 639:	learn: 930696395252604862464.0000000	total: 10.9s	remaining: 6.16s
# 640:	learn: 930305741325930070016.0000000	total: 11s	remaining: 6.14s
# 641:	learn: 930303844593512873984.0000000	total: 11s	remaining: 6.12s
# 642:	learn: 930301874909849059328.0000000	total: 11s	remaining: 6.1s
# 643:	learn: 930295528151376461824.0000000	total: 11s	remaining: 6.08s
# 644:	learn: 930278457559622615040.0000000	total: 11s	remaining: 6.07s
# 645:	learn: 930060698087890616320.0000000	total: 11s	remaining: 6.05s
# 646:	learn: 930058874306720301056.0000000	total: 11.1s	remaining: 6.03s
# 647:	learn: 930015395363620782080.0000000	total: 11.1s	remaining: 6.01s
# 648:	learn: 930014957656139890688.0000000	total: 11.1s	remaining: 5.99s
# 649:	learn: 930013498631203717120.0000000	total: 11.1s	remaining: 5.97s
# 650:	learn: 930000586260518141952.0000000	total: 11.1s	remaining: 5.96s
# 651:	learn: 929999856748049989632.0000000	total: 11.1s	remaining: 5.94s
# 652:	learn: 929998981333088206848.0000000	total: 11.1s	remaining: 5.92s
# 653:	learn: 929985339449934479360.0000000	total: 11.2s	remaining: 5.9s
# 654:	learn: 929914284935540244480.0000000	total: 11.2s	remaining: 5.88s
# 655:	learn: 929912898861850820608.0000000	total: 11.2s	remaining: 5.87s
# 656:	learn: 929831704124149727232.0000000	total: 11.2s	remaining: 5.85s
# 657:	learn: 929824408999468597248.0000000	total: 11.2s	remaining: 5.83s
# 658:	learn: 929699516464927604736.0000000	total: 11.2s	remaining: 5.81s
# 659:	learn: 929695795951340224512.0000000	total: 11.2s	remaining: 5.79s
# 660:	learn: 929686312289254768640.0000000	total: 11.3s	remaining: 5.78s
# 661:	learn: 929472711038591041536.0000000	total: 11.3s	remaining: 5.76s
# 662:	learn: 929446886297219760128.0000000	total: 11.3s	remaining: 5.74s
# 663:	learn: 929442728076151619584.0000000	total: 11.3s	remaining: 5.72s
# 664:	learn: 929438205098849206272.0000000	total: 11.3s	remaining: 5.7s
# ...
# 778:	learn: 915869564996922245120.0000000	total: 13.1s	remaining: 3.71s
# 779:	learn: 915841551718146637824.0000000	total: 13.1s	remaining: 3.69s
# 780:	learn: 915840749254431735808.0000000	total: 13.1s	remaining: 3.68s
# 781:	learn: 915836955789597474816.0000000	total: 13.1s	remaining: 3.66s
# 782:	learn: 915830390177384497152.0000000	total: 13.1s	remaining: 3.64s
# 783:	learn: 915810255633264541696.0000000	total: 13.2s	remaining: 3.63s
# 784:	learn: 915809380218302758912.0000000	total: 13.2s	remaining: 3.61s
# 785:	learn: 915804492484766466048.0000000	total: 13.2s	remaining: 3.59s
# 786:	learn: 915799458848736411648.0000000	total: 13.2s	remaining: 3.57s
# 787:	learn: 915795373578915020800.0000000	total: 13.2s	remaining: 3.56s
# 788:	learn: 915792455529042542592.0000000	total: 13.2s	remaining: 3.54s
# 789:	learn: 915394944185167380480.0000000	total: 13.3s	remaining: 3.52s
# 790:	learn: 915394141721452478464.0000000	total: 13.3s	remaining: 3.5s
# 791:	learn: 915366930906391904256.0000000	total: 13.3s	remaining: 3.49s
# 792:	learn: 915365982540183371776.0000000	total: 13.3s	remaining: 3.47s
# 793:	learn: 915355112804408492032.0000000	total: 13.3s	remaining: 3.45s
# 794:	learn: 915352194754536013824.0000000	total: 13.3s	remaining: 3.44s
# 795:	learn: 915349495558403915776.0000000	total: 13.3s	remaining: 3.42s
# 796:	learn: 915347307020999589888.0000000	total: 13.4s	remaining: 3.4s
# 797:	learn: 914919593860944625664.0000000	total: 13.4s	remaining: 3.39s
# 798:	learn: 914916092201097625600.0000000	total: 13.4s	remaining: 3.37s
# 799:	learn: 914911569223795343360.0000000	total: 13.4s	remaining: 3.35s
# 800:	learn: 914907775758961082368.0000000	total: 13.4s	remaining: 3.33s
# 801:	learn: 914902815074177908736.0000000	total: 13.4s	remaining: 3.32s
# 802:	learn: 914868090280695693312.0000000	total: 13.5s	remaining: 3.3s
# 803:	learn: 914864296815861563392.0000000	total: 13.5s	remaining: 3.28s
# 804:	learn: 914861597619729596416.0000000	total: 13.5s	remaining: 3.27s
# 805:	learn: 914859700887312400384.0000000	total: 13.5s	remaining: 3.25s
# 806:	learn: 914854667251282477056.0000000	total: 13.5s	remaining: 3.23s
# 807:	learn: 914853937738814324736.0000000	total: 13.5s	remaining: 3.21s
# 808:	learn: 914852332811384520704.0000000	total: 13.5s	remaining: 3.2s
# 809:	learn: 914850509030214205440.0000000	total: 13.6s	remaining: 3.18s
# 810:	learn: 914843724564260716544.0000000	total: 13.6s	remaining: 3.16s
# 811:	learn: 914839931099426586624.0000000	total: 13.6s	remaining: 3.15s
# 812:	learn: 914829936778613358592.0000000	total: 13.6s	remaining: 3.13s
# 813:	learn: 914805352208438001664.0000000	total: 13.6s	remaining: 3.11s
# 814:	learn: 914797692327522729984.0000000	total: 13.6s	remaining: 3.1s
# 815:	learn: 914792220984011915264.0000000	total: 13.7s	remaining: 3.08s
# 816:	learn: 914511504586281844736.0000000	total: 13.7s	remaining: 3.06s
# 817:	learn: 914387122710468362240.0000000	total: 13.7s	remaining: 3.04s
# 818:	learn: 913462392705887502336.0000000	total: 13.7s	remaining: 3.03s
# 819:	learn: 913461590242172600320.0000000	total: 13.7s	remaining: 3.01s
# 820:	learn: 913459693509755535360.0000000	total: 13.7s	remaining: 2.99s
# 821:	learn: 913456702508636176384.0000000	total: 13.7s	remaining: 2.98s
# 822:	learn: 913433431060903362560.0000000	total: 13.8s	remaining: 2.96s
# 823:	learn: 913428324473626558464.0000000	total: 13.8s	remaining: 2.94s
# 824:	learn: 913426500692456374272.0000000	total: 13.8s	remaining: 2.92s
# 825:	learn: 913238870085657427968.0000000	total: 13.8s	remaining: 2.91s
# 826:	learn: 913238140573189406720.0000000	total: 13.8s	remaining: 2.89s
# 827:	learn: 913234347108355145728.0000000	total: 13.8s	remaining: 2.87s
# 828:	learn: 913232085619704070144.0000000	total: 13.8s	remaining: 2.86s
# 829:	learn: 913199768217366560768.0000000	total: 13.9s	remaining: 2.84s
# 830:	learn: 913137321950096130048.0000000	total: 13.9s	remaining: 2.82s
# 831:	learn: 913135352266432184320.0000000	total: 13.9s	remaining: 2.81s
# 832:	learn: 912612510680535138304.0000000	total: 13.9s	remaining: 2.79s
# 833:	learn: 912513953546092937216.0000000	total: 13.9s	remaining: 2.77s
# 834:	learn: 912508482202582122496.0000000	total: 13.9s	remaining: 2.75s
# 835:	learn: 912505126445228752896.0000000	total: 14s	remaining: 2.74s
# 836:	learn: 912500238711692460032.0000000	total: 14s	remaining: 2.72s
# 837:	learn: 912497101808079470592.0000000	total: 14s	remaining: 2.7s
# 838:	learn: 912496372295611449344.0000000	total: 14s	remaining: 2.69s
# 839:	learn: 912238270784392790016.0000000	total: 14s	remaining: 2.67s
# 840:	learn: 912235133880779931648.0000000	total: 14s	remaining: 2.65s
# 841:	learn: 912231996977166942208.0000000	total: 14s	remaining: 2.63s
# 842:	learn: 912231267464698920960.0000000	total: 14.1s	remaining: 2.62s
# 843:	learn: 912218355094013214720.0000000	total: 14.1s	remaining: 2.6s
# 844:	learn: 912216896069077041152.0000000	total: 14.1s	remaining: 2.58s
# 845:	learn: 912215364092893986816.0000000	total: 14.1s	remaining: 2.57s
# 846:	learn: 912211205871825715200.0000000	total: 14.1s	remaining: 2.55s
# 847:	learn: 911920276299542036480.0000000	total: 14.1s	remaining: 2.53s
# 848:	learn: 911919619738320764928.0000000	total: 14.2s	remaining: 2.52s
# 849:	learn: 911916336932214276096.0000000	total: 14.2s	remaining: 2.5s
# 850:	learn: 911911376247431102464.0000000	total: 14.2s	remaining: 2.48s
# 851:	learn: 911908750002545885184.0000000	total: 14.2s	remaining: 2.47s
# 852:	learn: 911906853270128689152.0000000	total: 14.2s	remaining: 2.45s
# 853:	learn: 911903789317762711552.0000000	total: 14.2s	remaining: 2.43s
# 854:	learn: 911902986854047678464.0000000	total: 14.2s	remaining: 2.42s
# 855:	learn: 911898099120511385600.0000000	total: 14.3s	remaining: 2.4s
# 856:	learn: 911897296656796483584.0000000	total: 14.3s	remaining: 2.38s
# 857:	learn: 911893503191962222592.0000000	total: 14.3s	remaining: 2.37s
# 858:	learn: 911672606816617496576.0000000	total: 14.3s	remaining: 2.35s
# 859:	learn: 911628179507309314048.0000000	total: 14.3s	remaining: 2.33s
# 860:	learn: 911626209823645368320.0000000	total: 14.3s	remaining: 2.31s
# 861:	learn: 911615485990364119040.0000000	total: 14.4s	remaining: 2.3s
# 862:	learn: 911610014646853304320.0000000	total: 14.4s	remaining: 2.28s
# 863:	learn: 911608044963189358592.0000000	total: 14.4s	remaining: 2.27s
# 864:	learn: 911603740839627456512.0000000	total: 14.4s	remaining: 2.25s
# 865:	learn: 911583387441767120896.0000000	total: 14.4s	remaining: 2.23s
# 866:	learn: 911579229220698849280.0000000	total: 14.5s	remaining: 2.22s
# 867:	learn: 911571569339783708672.0000000	total: 14.5s	remaining: 2.2s
# 868:	learn: 911568432436170850304.0000000	total: 14.5s	remaining: 2.19s
# 869:	learn: 911565587337545121792.0000000	total: 14.5s	remaining: 2.17s
# 870:	learn: 911563544702634426368.0000000	total: 14.5s	remaining: 2.15s
# 871:	learn: 911559751237800296448.0000000	total: 14.6s	remaining: 2.14s
# 872:	learn: 911499128751700049920.0000000	total: 14.6s	remaining: 2.12s
# 873:	learn: 911497159068036104192.0000000	total: 14.6s	remaining: 2.1s
# 874:	learn: 911494168066916876288.0000000	total: 14.6s	remaining: 2.09s
# 875:	learn: 911492125432006049792.0000000	total: 14.7s	remaining: 2.08s
# 876:	learn: 911484684404831289344.0000000	total: 14.7s	remaining: 2.06s
# 877:	learn: 911392765833849077760.0000000	total: 14.7s	remaining: 2.04s
# 878:	learn: 910983655241730883584.0000000	total: 14.7s	remaining: 2.03s
# 879:	learn: 910399680511005949952.0000000	total: 14.8s	remaining: 2.01s
# 880:	learn: 910395814094924939264.0000000	total: 14.8s	remaining: 1.99s
# 881:	learn: 910395084582456786944.0000000	total: 14.8s	remaining: 1.98s
# 882:	learn: 910393260801286471680.0000000	total: 14.8s	remaining: 1.96s
# 883:	learn: 910361381106429984768.0000000	total: 14.8s	remaining: 1.94s
# 884:	learn: 910359484374012788736.0000000	total: 14.8s	remaining: 1.93s
# 885:	learn: 910357879446582984704.0000000	total: 14.8s	remaining: 1.91s
# 886:	learn: 910357222885361713152.0000000	total: 14.9s	remaining: 1.89s
# 887:	learn: 910353064664293441536.0000000	total: 14.9s	remaining: 1.88s
# 888:	learn: 910346936759561224192.0000000	total: 14.9s	remaining: 1.86s
# 889:	learn: 910342705587246202880.0000000	total: 14.9s	remaining: 1.84s
# 890:	learn: 910339787537373724672.0000000	total: 14.9s	remaining: 1.82s
# 891:	learn: 910279602758754369536.0000000	total: 14.9s	remaining: 1.81s
# 892:	learn: 910277997831324565504.0000000	total: 15s	remaining: 1.79s
# 893:	learn: 910273110097788141568.0000000	total: 15s	remaining: 1.77s
# 894:	learn: 910269608437941272576.0000000	total: 15s	remaining: 1.76s
# 895:	learn: 910243929599063621632.0000000	total: 15s	remaining: 1.74s
# 896:	learn: 910242032866646556672.0000000	total: 15s	remaining: 1.72s
# 897:	learn: 910166455374949908480.0000000	total: 15s	remaining: 1.71s
# 898:	learn: 908660376884529332224.0000000	total: 15.1s	remaining: 1.69s
# 899:	learn: 908659647372061179904.0000000	total: 15.1s	remaining: 1.67s
# 900:	learn: 908609456914254921728.0000000	total: 15.1s	remaining: 1.66s
# 901:	learn: 908606028205654802432.0000000	total: 15.1s	remaining: 1.64s
# 902:	learn: 908600265057156726784.0000000	total: 15.1s	remaining: 1.62s
# 903:	learn: 908597274056037498880.0000000	total: 15.1s	remaining: 1.61s
# 904:	learn: 908589614175122227200.0000000	total: 15.1s	remaining: 1.59s
# 905:	learn: 908580568220517662720.0000000	total: 15.2s	remaining: 1.57s
# 906:	learn: 908579546903062249472.0000000	total: 15.2s	remaining: 1.56s
# 907:	learn: 908576701804436652032.0000000	total: 15.2s	remaining: 1.54s
# 908:	learn: 908495215261748297728.0000000	total: 15.2s	remaining: 1.52s
# 909:	learn: 908494485749280276480.0000000	total: 15.2s	remaining: 1.5s
# 910:	learn: 908493683285565243392.0000000	total: 15.2s	remaining: 1.49s
# 911:	learn: 908490692284446015488.0000000	total: 15.3s	remaining: 1.47s
# 912:	learn: 908486461112130994176.0000000	total: 15.3s	remaining: 1.46s
# 913:	learn: 908465961811777028096.0000000	total: 15.3s	remaining: 1.44s
# 914:	learn: 908027816623427944448.0000000	total: 15.3s	remaining: 1.42s
# 915:	learn: 907553998275388112896.0000000	total: 15.3s	remaining: 1.4s
# 916:	learn: 907553341714166710272.0000000	total: 15.3s	remaining: 1.39s
# 917:	learn: 907551226128009265152.0000000	total: 15.3s	remaining: 1.37s
# 918:	learn: 907546557248213352448.0000000	total: 15.4s	remaining: 1.35s
# 919:	learn: 907480171613615030272.0000000	total: 15.4s	remaining: 1.34s
# 920:	learn: 907478274881197834240.0000000	total: 15.4s	remaining: 1.32s
# 921:	learn: 907477472417482932224.0000000	total: 15.4s	remaining: 1.3s
# 922:	learn: 907476669953768030208.0000000	total: 15.4s	remaining: 1.29s
# 923:	learn: 907472074025218867200.0000000	total: 15.4s	remaining: 1.27s
# 924:	learn: 906861034381926858752.0000000	total: 15.5s	remaining: 1.25s
# 925:	learn: 906848924474956185600.0000000	total: 15.5s	remaining: 1.24s
# 926:	learn: 906842942472717729792.0000000	total: 15.5s	remaining: 1.22s
# 927:	learn: 906841410496534675456.0000000	total: 15.5s	remaining: 1.2s
# 928:	learn: 906809093094197166080.0000000	total: 15.5s	remaining: 1.19s
# 929:	learn: 906808363581729144832.0000000	total: 15.5s	remaining: 1.17s
# 930:	learn: 906806758654299209728.0000000	total: 15.5s	remaining: 1.15s
# 931:	learn: 906801652067022405632.0000000	total: 15.6s	remaining: 1.14s
# 932:	learn: 906800047139592601600.0000000	total: 15.6s	remaining: 1.12s
# 933:	learn: 906795815967277580288.0000000	total: 15.6s	remaining: 1.1s
# 934:	learn: 906785602792723972096.0000000	total: 15.6s	remaining: 1.08s
# 935:	learn: 906784727377762189312.0000000	total: 15.6s	remaining: 1.07s
# 936:	learn: 906691787489324564480.0000000	total: 15.6s	remaining: 1.05s
# 937:	learn: 906685805487085977600.0000000	total: 15.6s	remaining: 1.03s
# 938:	learn: 906682741534719868928.0000000	total: 15.7s	remaining: 1.02s
# 939:	learn: 906670485725255565312.0000000	total: 15.7s	remaining: 1s
# 940:	learn: 906667859480370348032.0000000	total: 15.7s	remaining: 984ms
# 941:	learn: 906643201958948110336.0000000	total: 15.7s	remaining: 967ms
# 942:	learn: 906641305226531045376.0000000	total: 15.7s	remaining: 951ms
# 943:	learn: 906409174359177297920.0000000	total: 15.7s	remaining: 934ms
# 944:	learn: 906401806283249287168.0000000	total: 15.8s	remaining: 917ms
# 945:	learn: 906246493078787981312.0000000	total: 15.8s	remaining: 900ms
# 946:	learn: 906178575468006604800.0000000	total: 15.8s	remaining: 884ms
# 947:	learn: 906175511515640496128.0000000	total: 15.8s	remaining: 867ms
# 948:	learn: 904211445097738010624.0000000	total: 15.8s	remaining: 850ms
# 949:	learn: 904210642634023108608.0000000	total: 15.8s	remaining: 834ms
# 950:	learn: 903766515443435569152.0000000	total: 15.9s	remaining: 817ms
# 951:	learn: 903759220318754439168.0000000	total: 15.9s	remaining: 800ms
# 952:	learn: 903756958830103232512.0000000	total: 15.9s	remaining: 783ms
# 953:	learn: 903756156366388330496.0000000	total: 15.9s	remaining: 767ms
# 954:	learn: 903725006183999864832.0000000	total: 15.9s	remaining: 750ms
# 955:	learn: 903716324985629310976.0000000	total: 15.9s	remaining: 733ms
# 956:	learn: 902593970053436407808.0000000	total: 15.9s	remaining: 716ms
# 957:	learn: 902592073321019342848.0000000	total: 16s	remaining: 700ms
# 958:	learn: 902515474511867412480.0000000	total: 16s	remaining: 683ms
# 959:	learn: 902513942535684358144.0000000	total: 16s	remaining: 666ms
# 960:	learn: 902507741679705391104.0000000	total: 16s	remaining: 650ms
# 961:	learn: 902502343287441326080.0000000	total: 16s	remaining: 633ms
# 962:	learn: 902500592457517891584.0000000	total: 16s	remaining: 616ms
# 963:	learn: 902498914578841206784.0000000	total: 16.1s	remaining: 600ms
# 964:	learn: 902497090797670891520.0000000	total: 16.1s	remaining: 583ms
# 965:	learn: 905842562025193340928.0000000	total: 16.1s	remaining: 566ms
# 966:	learn: 905827388165856690176.0000000	total: 16.1s	remaining: 549ms
# 967:	learn: 905825856189673635840.0000000	total: 16.1s	remaining: 533ms
# 968:	learn: 904811979761489281024.0000000	total: 16.1s	remaining: 516ms
# 969:	learn: 904798046073348292608.0000000	total: 16.1s	remaining: 499ms
# 970:	learn: 904796149340931096576.0000000	total: 16.2s	remaining: 483ms
# 971:	learn: 904562632399887925248.0000000	total: 16.2s	remaining: 466ms
# 972:	learn: 904561829936173023232.0000000	total: 16.2s	remaining: 449ms
# 973:	learn: 904553732347776991232.0000000	total: 16.2s	remaining: 433ms
# 974:	learn: 904550887249151393792.0000000	total: 16.2s	remaining: 416ms
# 975:	learn: 904476622879897419776.0000000	total: 16.2s	remaining: 399ms
# 976:	learn: 903431158561843707904.0000000	total: 16.3s	remaining: 383ms
# 977:	learn: 903417006019962208256.0000000	total: 16.3s	remaining: 366ms
# 978:	learn: 903119583786712301568.0000000	total: 16.3s	remaining: 349ms
# 979:	learn: 902818951698602655744.0000000	total: 16.3s	remaining: 333ms
# 980:	learn: 902809978695244840960.0000000	total: 16.3s	remaining: 316ms
# 981:	learn: 902805090961708548096.0000000	total: 16.3s	remaining: 299ms
# 982:	learn: 902800057325678493696.0000000	total: 16.3s	remaining: 283ms
# 983:	learn: 902798598300742320128.0000000	total: 16.4s	remaining: 266ms
# 984:	learn: 902542977131915247616.0000000	total: 16.4s	remaining: 249ms
# 985:	learn: 902528897541280628736.0000000	total: 16.4s	remaining: 233ms
# 986:	learn: 902514817950646140928.0000000	total: 16.4s	remaining: 216ms
# 987:	learn: 902506866264743608320.0000000	total: 16.4s	remaining: 199ms
# 988:	learn: 902502343287441326080.0000000	total: 16.4s	remaining: 183ms
# 989:	learn: 902499352286322098176.0000000	total: 16.5s	remaining: 166ms
# 990:	learn: 902409695203990962176.0000000	total: 16.5s	remaining: 150ms
# 991:	learn: 902406996007858864128.0000000	total: 16.5s	remaining: 133ms
# 992:	learn: 902404296811726897152.0000000	total: 16.5s	remaining: 116ms
# 993:	learn: 902368404798295638016.0000000	total: 16.5s	remaining: 99.7ms
# 994:	learn: 902362860503537942528.0000000	total: 16.5s	remaining: 83.1ms
# 995:	learn: 902359796551171964928.0000000	total: 16.5s	remaining: 66.4ms
# 996:	learn: 902355638330103693312.0000000	total: 16.6s	remaining: 49.8ms
# 997:	learn: 902346957131733139456.0000000	total: 16.6s	remaining: 33.2ms
# 998:	learn: 902339953812039270400.0000000	total: 16.6s	remaining: 16.6ms
# 999:	learn: 902337254615907172352.0000000	total: 16.6s	remaining: 0us

# %%
# Calculate F1 Score of tuned model using weighted average method
f1_cb_tuned = f1_score(y_test, y_pred_cb_tuned, average="weighted")
f1_cb_tuned
# Out:
# 0.7883500098679912

# %%
# Evaluate the untuned CatBoost classifier (as it performed better)
eval_model(y_test, y_pred_cb, model_name)
# Out:
# CLASSIFICATION REPORT for CATBOOST
#
#                              precision    recall  f1-score   support
#
#       Bank Account services       0.91      0.93      0.92      1301
# Credit card or prepaid card       0.91      0.90      0.90      1289
#                      Others       0.90      0.90      0.90       548
#     Theft/Dispute Reporting       0.90      0.87      0.89      1201
#               Mortgage/Loan       0.91      0.92      0.92       929
#
#                    accuracy                           0.91      5268
#                   macro avg       0.91      0.91      0.91      5268
#                weighted avg       0.91      0.91      0.91      5268

# %% [markdown]
# ### 📌 The untuned CatBoost model gives a pretty high F1 score of 0.91. (Note that CatBoost is designed in a way that tuning is not necessary.)
# ### 📌 This model performs quite well on all topics.

# %%
# Update the summary table
summary.loc[len(summary.index)] = ['CatBoost', round(f1_cb, 2), round(f1_cb_tuned, 2)]
summary
# Out:
#                     Model  F1 Score (untuned)  F1 Score (tuned)
# 0             Naive Bayes                0.68              0.78
# 1     Logistic Regression                0.92              0.94
# 2           Decision Tree                0.78              0.80
# 3           Random Forest                0.81              0.85
# 4  Support Vector Machine                0.92              0.91
# 5                 XGBoost                0.91              0.92
# 6                CatBoost                0.91              0.79

# %% [markdown]
# ### 📌 From the above summary table, we observe that the `tuned Logistic Regression` performs the best among all that we tried.

# %% [markdown]
# # `Task 8`: Model Inference ☑️

# %% [markdown]
# ### 💠 Now, we use this tuned Logistic Regression model - `clf_lr_tuned` to predict some new custom text.

# %%
# Save tuned Logistic Regression model as pickle file
pickle.dump(clf_lr_tuned, open("logreg_model.pkl", "wb"))

# %%
# Function to predict a topic for given text

def predict_topic(text):
    
    target_names = ["Bank Account services", "Credit card or prepaid card", "Others", "Theft/Dispute Reporting", "Mortgage/Loan"]

    loaded_vec = CountVectorizer(vocabulary=pickle.load(open("count_vector.pkl", "rb")))
    loaded_tfidf = pickle.load(open("tfidf.pkl","rb"))
    loaded_model = pickle.load(open("logreg_model.pkl","rb"))

    X_new_counts = loaded_vec.transform(text)
    X_new_tfidf = loaded_tfidf.transform(X_new_counts)
    predicted = loaded_model.predict(X_new_tfidf)

    return target_names[predicted[0]]

# %%
# Create a dataframe of some sample customer complaints
df_new = pd.DataFrame({'complaints': ["I can not get from chase who services my mortgage, who owns it and who has original loan docs", 
                                  "The bill amount of my credit card was debited twice. Please look into the matter and resolve at the earliest.",
                                  "I want to open a salary account at your downtown branch. Please provide me the procedure.",
                                  "Yesterday, I received a fraudulent email regarding renewal of my services.",
                                  "What is the procedure to know my CIBIL score?",
                                  "I need to know the number of bank branches and their locations in the city of Dubai"]})
df_new
# Out:
#                                                                                                       complaints
# 0                  I can not get from chase who services my mortgage, who owns it and who has original loan docs
# 1  The bill amount of my credit card was debited twice. Please look into the matter and resolve at the earliest.
# 2                      I want to open a salary account at your downtown branch. Please provide me the procedure.
# 3                                     Yesterday, I received a fraudulent email regarding renewal of my services.
# 4                                                                  What is the procedure to know my CIBIL score?
# 5                            I need to know the number of bank branches and their locations in the city of Dubai

# %%
# Create a new column of predicted topics of each complaint, predicted using the tuned Logistic Regression model
df_new['predicted topic'] = df_new['complaints'].apply(lambda x: predict_topic([x]))
df_new
# Out:
#                                                                                                       complaints  \
# 0                  I can not get from chase who services my mortgage, who owns it and who has original loan docs
# 1  The bill amount of my credit card was debited twice. Please look into the matter and resolve at the earliest.
# 2                      I want to open a salary account at your downtown branch. Please provide me the procedure.
# 3                                     Yesterday, I received a fraudulent email regarding renewal of my services.
# 4                                                                  What is the procedure to know my CIBIL score?
# 5                            I need to know the number of bank branches and their locations in the city of Dubai
#
#                predicted topic
# 0                Mortgage/Loan
# 1  Credit card or prepaid card
# 2        Bank Account services
# 3      Theft/Dispute Reporting
# 4                Mortgage/Loan
# 5        Bank Account services

# %% [markdown]
# ### 📌 Thus, we can conclude that our model performs very well in classifying any new text.
